# %% [markdown]
# ### An example for generating *Aggregate-Filter* for cross-sectional data
# ######  Before executing this notebook, please makes sure that data was imported earlier into the database.

# %%
! pip install --upgrade pip
! pip install fuzzy_sql-2.0.0b0-py3-none-any.whl
# Out:
# Requirement already satisfied: pip in /home/samer/miniconda3/lib/python3.9/site-packages (22.3.1)
# Collecting pip
#   Using cached pip-23.0.1-py3-none-any.whl (2.1 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3.1
#     Uninstalling pip-22.3.1:
#       Successfully uninstalled pip-22.3.1
# Successfully installed pip-23.0.1
# Processing ./fuzzy_sql-2.0.0b0-py3-none-any.whl
# Requirement already satisfied: seaborn in /home/samer/miniconda3/lib/python3.9/site-packages (from fuzzy-sql==2.0.0b0) (0.12.2)
# Collecting Jinja2
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Requirement already satisfied: scipy in /home/samer/miniconda3/lib/python3.9/site-packages (from fuzzy-sql==2.0.0b0) (1.8.1)
# Collecting jupyter
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting multiprocess
#   Using cached multiprocess-0.70.14-py39-none-any.whl (132 kB)
# Collecting jsonschema
#   Using cached jsonschema-4.17.3-py3-none-any.whl (90 kB)
# Requirement already satisfied: scikit-learn in /home/samer/miniconda3/lib/python3.9/site-packages (from fuzzy-sql==2.0.0b0) (1.2.0)
# Requirement already satisfied: pandas in /home/samer/miniconda3/lib/python3.9/site-packages (from fuzzy-sql==2.0.0b0) (1.5.2)
# Requirement already satisfied: matplotlib in /home/samer/miniconda3/lib/python3.9/site-packages (from fuzzy-sql==2.0.0b0) (3.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/samer/miniconda3/lib/python3.9/site-packages (from Jinja2->fuzzy-sql==2.0.0b0) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/samer/miniconda3/lib/python3.9/site-packages (from jsonschema->fuzzy-sql==2.0.0b0) (22.2.0)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Using cached pyrsistent-0.19.3-py3-none-any.whl (57 kB)
# Collecting qtconsole
#   Using cached qtconsole-5.4.0-py3-none-any.whl (121 kB)
# Requirement already satisfied: ipykernel in /home/samer/miniconda3/lib/python3.9/site-packages (from jupyter->fuzzy-sql==2.0.0b0) (6.19.2)
# Collecting jupyter-console
#   Downloading jupyter_console-6.6.2-py3-none-any.whl (24 kB)
# Collecting notebook
#   Using cached notebook-6.5.2-py3-none-any.whl (439 kB)
# Collecting nbconvert
#   Using cached nbconvert-7.2.9-py3-none-any.whl (274 kB)
# Collecting ipywidgets
#   Using cached ipywidgets-8.0.4-py3-none-any.whl (137 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/samer/miniconda3/lib/python3.9/site-packages (from matplotlib->fuzzy-sql==2.0.0b0) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/samer/miniconda3/lib/python3.9/site-packages (from matplotlib->fuzzy-sql==2.0.0b0) (1.0.6)
# Requirement already satisfied: numpy>=1.19 in /home/samer/miniconda3/lib/python3.9/site-packages (from matplotlib->fuzzy-sql==2.0.0b0) (1.24.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/samer/miniconda3/lib/python3.9/site-packages (from matplotlib->fuzzy-sql==2.0.0b0) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/samer/miniconda3/lib/python3.9/site-packages (from matplotlib->fuzzy-sql==2.0.0b0) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/samer/miniconda3/lib/python3.9/site-packages (from matplotlib->fuzzy-sql==2.0.0b0) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/samer/miniconda3/lib/python3.9/site-packages (from matplotlib->fuzzy-sql==2.0.0b0) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/samer/miniconda3/lib/python3.9/site-packages (from matplotlib->fuzzy-sql==2.0.0b0) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/samer/miniconda3/lib/python3.9/site-packages (from matplotlib->fuzzy-sql==2.0.0b0) (0.11.0)
# Collecting dill>=0.3.6
#   Using cached dill-0.3.6-py3-none-any.whl (110 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/samer/miniconda3/lib/python3.9/site-packages (from pandas->fuzzy-sql==2.0.0b0) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/samer/miniconda3/lib/python3.9/site-packages (from scikit-learn->fuzzy-sql==2.0.0b0) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/samer/miniconda3/lib/python3.9/site-packages (from scikit-learn->fuzzy-sql==2.0.0b0) (1.2.0)
# Requirement already satisfied: six>=1.5 in /home/samer/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->fuzzy-sql==2.0.0b0) (1.16.0)
# Requirement already satisfied: psutil in /home/samer/miniconda3/lib/python3.9/site-packages (from ipykernel->jupyter->fuzzy-sql==2.0.0b0) (5.9.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/samer/miniconda3/lib/python3.9/site-packages (from ipykernel->jupyter->fuzzy-sql==2.0.0b0) (7.4.8)
# Requirement already satisfied: pyzmq>=17 in /home/samer/miniconda3/lib/python3.9/site-packages (from ipykernel->jupyter->fuzzy-sql==2.0.0b0) (23.2.0)
# Requirement already satisfied: comm>=0.1.1 in /home/samer/miniconda3/lib/python3.9/site-packages (from ipykernel->jupyter->fuzzy-sql==2.0.0b0) (0.1.2)
# Requirement already satisfied: traitlets>=5.4.0 in /home/samer/miniconda3/lib/python3.9/site-packages (from ipykernel->jupyter->fuzzy-sql==2.0.0b0) (5.7.1)
# Requirement already satisfied: nest-asyncio in /home/samer/miniconda3/lib/python3.9/site-packages (from ipykernel->jupyter->fuzzy-sql==2.0.0b0) (1.5.6)
# Requirement already satisfied: debugpy>=1.0 in /home/samer/miniconda3/lib/python3.9/site-packages (from ipykernel->jupyter->fuzzy-sql==2.0.0b0) (1.5.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/samer/miniconda3/lib/python3.9/site-packages (from ipykernel->jupyter->fuzzy-sql==2.0.0b0) (0.1.6)
# Requirement already satisfied: ipython>=7.23.1 in /home/samer/miniconda3/lib/python3.9/site-packages (from ipykernel->jupyter->fuzzy-sql==2.0.0b0) (8.7.0)
# Requirement already satisfied: tornado>=6.1 in /home/samer/miniconda3/lib/python3.9/site-packages (from ipykernel->jupyter->fuzzy-sql==2.0.0b0) (6.2)
# Collecting jupyterlab-widgets~=3.0
#   Using cached jupyterlab_widgets-3.0.5-py3-none-any.whl (384 kB)
# Collecting widgetsnbextension~=4.0
#   Using cached widgetsnbextension-4.0.5-py3-none-any.whl (2.0 MB)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /home/samer/miniconda3/lib/python3.9/site-packages (from jupyter-console->jupyter->fuzzy-sql==2.0.0b0) (3.0.36)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/samer/miniconda3/lib/python3.9/site-packages (from jupyter-console->jupyter->fuzzy-sql==2.0.0b0) (5.1.1)
# Requirement already satisfied: pygments in /home/samer/miniconda3/lib/python3.9/site-packages (from jupyter-console->jupyter->fuzzy-sql==2.0.0b0) (2.11.2)
# Collecting bleach
#   Using cached bleach-6.0.0-py3-none-any.whl (162 kB)
# Collecting mistune<3,>=2.0.3
#   Using cached mistune-2.0.5-py2.py3-none-any.whl (24 kB)
# Collecting pandocfilters>=1.4.1
#   Using cached pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting jupyterlab-pygments
#   Using cached jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: importlib-metadata>=3.6 in /home/samer/miniconda3/lib/python3.9/site-packages (from nbconvert->jupyter->fuzzy-sql==2.0.0b0) (4.13.0)
# Collecting nbformat>=5.1
#   Using cached nbformat-5.7.3-py3-none-any.whl (78 kB)
# Collecting tinycss2
#   Using cached tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.11.2-py3-none-any.whl (129 kB)
# Collecting nbclient>=0.5.0
#   Using cached nbclient-0.7.2-py3-none-any.whl (71 kB)
# Collecting defusedxml
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting prometheus-client
#   Using cached prometheus_client-0.16.0-py3-none-any.whl (122 kB)
# Collecting Send2Trash>=1.8.0
#   Using cached Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Collecting nbclassic>=0.4.7
#   Using cached nbclassic-0.5.2-py3-none-any.whl (10.0 MB)
# Collecting ipython-genutils
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting terminado>=0.8.3
#   Using cached terminado-0.17.1-py3-none-any.whl (17 kB)
# Collecting argon2-cffi
#   Using cached argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting qtpy>=2.0.1
#   Using cached QtPy-2.3.0-py3-none-any.whl (83 kB)
# Requirement already satisfied: zipp>=0.5 in /home/samer/miniconda3/lib/python3.9/site-packages (from importlib-metadata>=3.6->nbconvert->jupyter->fuzzy-sql==2.0.0b0) (3.11.0)
# Requirement already satisfied: backcall in /home/samer/miniconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->fuzzy-sql==2.0.0b0) (0.2.0)
# Requirement already satisfied: pickleshare in /home/samer/miniconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->fuzzy-sql==2.0.0b0) (0.7.5)
# Requirement already satisfied: stack-data in /home/samer/miniconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->fuzzy-sql==2.0.0b0) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/samer/miniconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->fuzzy-sql==2.0.0b0) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /home/samer/miniconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->fuzzy-sql==2.0.0b0) (0.18.1)
# Requirement already satisfied: decorator in /home/samer/miniconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->fuzzy-sql==2.0.0b0) (5.1.1)
# Requirement already satisfied: entrypoints in /home/samer/miniconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->fuzzy-sql==2.0.0b0) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /home/samer/miniconda3/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter->fuzzy-sql==2.0.0b0) (2.5.2)
# Collecting jupyter-server>=1.8
#   Using cached jupyter_server-2.3.0-py3-none-any.whl (365 kB)
# Collecting notebook-shim>=0.1.0
#   Using cached notebook_shim-0.2.2-py3-none-any.whl (13 kB)
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.16.3-py3-none-any.whl (23 kB)
# Requirement already satisfied: wcwidth in /home/samer/miniconda3/lib/python3.9/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->fuzzy-sql==2.0.0b0) (0.2.5)
# Requirement already satisfied: ptyprocess in /home/samer/miniconda3/lib/python3.9/site-packages (from terminado>=0.8.3->notebook->jupyter->fuzzy-sql==2.0.0b0) (0.7.0)
# Collecting argon2-cffi-bindings
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.4-py3-none-any.whl (37 kB)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/samer/miniconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->fuzzy-sql==2.0.0b0) (0.8.3)
# Collecting pyzmq>=17
#   Downloading pyzmq-25.0.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.5 MB/s eta 0:00:00a 0:00:01
# Collecting websocket-client
#   Using cached websocket_client-1.5.1-py3-none-any.whl (55 kB)
# Collecting anyio>=3.1.0
#   Using cached anyio-3.6.2-py3-none-any.whl (80 kB)
# Collecting jupyter-server-terminals
#   Using cached jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Collecting jupyter-events>=0.4.0
#   Using cached jupyter_events-0.6.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: cffi>=1.0.1 in /home/samer/miniconda3/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->fuzzy-sql==2.0.0b0) (1.15.1)
# Requirement already satisfied: executing in /home/samer/miniconda3/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->fuzzy-sql==2.0.0b0) (0.8.3)
# Requirement already satisfied: pure-eval in /home/samer/miniconda3/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->fuzzy-sql==2.0.0b0) (0.2.2)
# Requirement already satisfied: asttokens in /home/samer/miniconda3/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->fuzzy-sql==2.0.0b0) (2.0.5)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: idna>=2.8 in /home/samer/miniconda3/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->fuzzy-sql==2.0.0b0) (3.4)
# Requirement already satisfied: pycparser in /home/samer/miniconda3/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->fuzzy-sql==2.0.0b0) (2.21)
# Collecting python-json-logger>=2.0.4
#   Using cached python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: pyyaml>=5.3 in /home/samer/miniconda3/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->fuzzy-sql==2.0.0b0) (6.0)
# Collecting rfc3986-validator>=0.1.1
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting rfc3339-validator
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting isoduration
#   Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting uri-template
#   Using cached uri_template-1.2.0-py3-none-any.whl (10 kB)
# Collecting webcolors>=1.11
#   Using cached webcolors-1.12-py3-none-any.whl (9.9 kB)
# Collecting jsonpointer>1.13
#   Using cached jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Collecting fqdn
#   Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting arrow>=0.15.0
#   Using cached arrow-1.2.3-py3-none-any.whl (66 kB)
# Installing collected packages: webencodings, Send2Trash, mistune, ipython-genutils, fastjsonschema, widgetsnbextension, websocket-client, webcolors, uri-template, tinycss2, terminado, soupsieve, sniffio, rfc3986-validator, rfc3339-validator, qtpy, pyzmq, python-json-logger, pyrsistent, prometheus-client, pandocfilters, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, Jinja2, fqdn, dill, defusedxml, bleach, multiprocess, jupyter-server-terminals, jsonschema, beautifulsoup4, arrow, argon2-cffi-bindings, anyio, nbformat, isoduration, argon2-cffi, nbclient, qtconsole, nbconvert, jupyter-events, jupyter-console, ipywidgets, jupyter-server, notebook-shim, nbclassic, notebook, jupyter, fuzzy-sql
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 23.2.0
#     Uninstalling pyzmq-23.2.0:
#       Successfully uninstalled pyzmq-23.2.0
# Successfully installed Jinja2-3.1.2 Send2Trash-1.8.0 anyio-3.6.2 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 arrow-1.2.3 beautifulsoup4-4.11.2 bleach-6.0.0 defusedxml-0.7.1 dill-0.3.6 fastjsonschema-2.16.3 fqdn-1.5.1 fuzzy-sql-2.0.0b0 ipython-genutils-0.2.0 ipywidgets-8.0.4 isoduration-20.11.0 jsonpointer-2.3 jsonschema-4.17.3 jupyter-1.0.0 jupyter-console-6.6.2 jupyter-events-0.6.3 jupyter-server-2.3.0 jupyter-server-terminals-0.4.4 jupyterlab-pygments-0.2.2 jupyterlab-widgets-3.0.5 mistune-2.0.5 multiprocess-0.70.14 nbclassic-0.5.2 nbclient-0.7.2 nbconvert-7.2.9 nbformat-5.7.3 notebook-6.5.2 notebook-shim-0.2.2 pandocfilters-1.5.0 prometheus-client-0.16.0 pyrsistent-0.19.3 python-json-logger-2.0.7 pyzmq-25.0.0 qtconsole-5.4.0 qtpy-2.3.0 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 sniffio-1.3.0 soupsieve-2.4 terminado-0.17.1 tinycss2-1.2.1 uri-template-1.2.0 webcolors-1.12 webencodings-0.5.1 websocket-client-1.5.1 widgetsnbextension-4.0.5

# %%
import json
import os
from pathlib import Path

from fuzzy_sql.generate import gen_aggfltr_queries
from fuzzy_sql.report import Report

DATASET_NAME='sdgd'

# %%
# set directories
DATA_DIR=os.path.join(os.getcwd(),'data')
DB_DIR=os.path.join(os.getcwd(),'databases')

metadata_dir = os.path.join(DATA_DIR, DATASET_NAME,'metadata')
db_path = os.path.join(DB_DIR, f'{DATASET_NAME}.db')

# %% [markdown]
# ### GENERATING RANDOM QUERIES

# %%
# Create lists with table names. Table names shall be identical to the names initially created in the database.
real_tbl_lst=['C1']
syn_tbl_lst=['C1_syn_default_1']

# Read metadata from the provided json files into a list of dictionaries. 
# Note 1: Both real and synthetic data should have the same metadata file.
# Note 2: Each input table in real_tbl_lst above shall have its own metadata file.
# Note 2: The json file name shall match that of the real data file name in real_tbl_lst. 
metadata_lst = []
for tbl_name in real_tbl_lst:
    with open(os.path.join(metadata_dir, tbl_name+'.json'), 'r') as f:
        metadata_lst.append(json.load(f))

# %%
rnd_queries=gen_aggfltr_queries(10,db_path, real_tbl_lst, metadata_lst,  syn_tbl_lst )
# Out:
# Generated Random Aggregate Filter Query - 1 in 0.5 seconds.
# Generated Random Aggregate Filter Query - 2 in 0.6 seconds.
# Generated Random Aggregate Filter Query - 3 in 0.5 seconds.
# Generated Random Aggregate Filter Query - 4 in 0.5 seconds.
# Generated Random Aggregate Filter Query - 5 in 0.5 seconds.
# Generated Random Aggregate Filter Query - 6 in 0.5 seconds.
# Generated Random Aggregate Filter Query - 7 in 0.5 seconds.
# Generated Random Aggregate Filter Query - 8 in 0.7 seconds.
# Generated Random Aggregate Filter Query - 9 in 0.7 seconds.
# Generated Random Aggregate Filter Query - 10 in 0.5 seconds.

# %% [markdown]
# ### REPORTING

# %%
rprtr=Report(real_tbl_lst, rnd_queries)
rprtr.print_html_mltpl(f'{DATASET_NAME}.html')
rprtr.plot_violin('Hellinger',f'{DATASET_NAME}_hlngr.png' )
rprtr.plot_violin('Euclidean',f'{DATASET_NAME}_ecldn.png' )
