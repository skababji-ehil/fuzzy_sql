# %%
import os
import sys
from pathlib import Path

sys.path.append('/home/samer/projects/fuzzy_sql/src') #This will enable reading the modules
from fuzzy_sql.fuzzy_sql import *
from fuzzy_sql.tabular_query import TABULAR_QUERY

# %%
def setup_class_inputs(conn,real_file_path, metadata_file_path, syn_file_path='None', ) -> dict:
    class_inputs={}
    if os.path.isfile(real_file_path):
        real=load_csv(real_file_path)
        real_name=Path(real_file_path).stem

        make_table(real_name, real, conn)
        class_inputs['real_data_name']=copy.deepcopy(real_name)
        class_inputs['real_data']=copy.deepcopy(real)
    else:
        raise Exception('The file {} does not exist !'.format(real_file_path))

    if os.path.isfile(metadata_file_path):
        metadata=get_metadata(metadata_file_path)
        class_inputs['metadata_dict']=copy.deepcopy(metadata)
    else:
        raise Exception('The file {} does not exist'.format(metadata_file_path))

    if syn_file_path != 'None':
        if os.path.isfile(syn_file_path):
            syn=load_csv(syn_file_path)
            syn_name=Path(syn_file_path).stem
            # Load syn data into the database
            make_table(syn_name, syn, conn)
            class_inputs['syn_data_name']=copy.deepcopy(syn_name)
            class_inputs['syn_data']=copy.deepcopy(syn)
        else:
            raise Exception('The file {}.csv does not exist!'.format(syn_file_path))

    return class_inputs

# %%
#set paths
root_dir=Path(os.getcwd()).parent
real_path=os.path.join(root_dir,'data/sdgd/processed/real/C1.csv')
meta_path=os.path.join(root_dir,'data/sdgd/processed/metadata/C1.json')
syn_path=os.path.join(root_dir,'data/sdgd/processed/synthetic/C1_syn_default_1.csv')
runs_dir=os.path.join(root_dir,'.runs')

# %%
agg_fntn=True
conn = sqlite3.connect('fuzzy_sql.db')
class_inputs=setup_class_inputs(conn,real_path,meta_path,syn_path)
testq=TABULAR_QUERY(conn,class_inputs['real_data_name'], class_inputs['metadata_dict'])
# Out:
# Table C1 already exists in the database
# Table C1_syn_default_1 is created in the database

# %%
#where_vars=['age','education','income','capital']
#testq._gen_single_aggfltr_expr(where_vars, agg_fntn=True)
queries=testq.gen_twin_aggfltr_queries(100, class_inputs['syn_data_name'], agg_fntn=agg_fntn)
scored_queries=testq.get_agg_metrics(queries)
# Out:
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated Conditioned Aggregate Query 3
# Generated Conditioned Aggregate Query 4
# Generated Conditioned Aggregate Query 5
# Generated Conditioned Aggregate Query 6
# Generated Conditioned Aggregate Query 7
# Generated Conditioned Aggregate Query 8
# Generated Conditioned Aggregate Query 9
# Generated Conditioned Aggregate Query 10
# Generated Conditioned Aggregate Query 11
# Generated Conditioned Aggregate Query 12
# Generated Conditioned Aggregate Query 13
# Generated Conditioned Aggregate Query 14
# Generated Conditioned Aggregate Query 15
# Generated Conditioned Aggregate Query 16
# Generated Conditioned Aggregate Query 17
# Generated Conditioned Aggregate Query 18
# Generated Conditioned Aggregate Query 19
# Generated Conditioned Aggregate Query 20
# Generated Conditioned Aggregate Query 21
# Generated Conditioned Aggregate Query 22
# Generated Conditioned Aggregate Query 23
# Generated Conditioned Aggregate Query 24
# Generated Conditioned Aggregate Query 25
# Generated Conditioned Aggregate Query 26
# Generated Conditioned Aggregate Query 27
# Generated Conditioned Aggregate Query 28
# Generated Conditioned Aggregate Query 29
# Generated Conditioned Aggregate Query 30
# Generated Conditioned Aggregate Query 31
# Generated Conditioned Aggregate Query 32
# Generated Conditioned Aggregate Query 33
# Generated Conditioned Aggregate Query 34
# Generated Conditioned Aggregate Query 35
# Generated Conditioned Aggregate Query 36
# Generated Conditioned Aggregate Query 37
# Generated Conditioned Aggregate Query 38
# Generated Conditioned Aggregate Query 39
# Generated Conditioned Aggregate Query 40
# Generated Conditioned Aggregate Query 41
# Generated Conditioned Aggregate Query 42
# Generated Conditioned Aggregate Query 43
# Generated Conditioned Aggregate Query 44
# Generated Conditioned Aggregate Query 45
# Generated Conditioned Aggregate Query 46
# Generated Conditioned Aggregate Query 47
# Generated Conditioned Aggregate Query 48
# Generated Conditioned Aggregate Query 49
# Generated Conditioned Aggregate Query 50
# Generated Conditioned Aggregate Query 51
# Generated Conditioned Aggregate Query 52
# Generated Conditioned Aggregate Query 53
# Generated Conditioned Aggregate Query 54
# Generated Conditioned Aggregate Query 55
# Generated Conditioned Aggregate Query 56
# Generated Conditioned Aggregate Query 57
# Generated Conditioned Aggregate Query 58
# Generated Conditioned Aggregate Query 59
# Generated Conditioned Aggregate Query 60
# Generated Conditioned Aggregate Query 61
# Generated Conditioned Aggregate Query 62
# Generated Conditioned Aggregate Query 63
# Generated Conditioned Aggregate Query 64
# Generated Conditioned Aggregate Query 65
# Generated Conditioned Aggregate Query 66
# Generated Conditioned Aggregate Query 67
# Generated Conditioned Aggregate Query 68
# Generated Conditioned Aggregate Query 69
# Generated Conditioned Aggregate Query 70
# Generated Conditioned Aggregate Query 71
# Generated Conditioned Aggregate Query 72
# Generated Conditioned Aggregate Query 73
# Generated Conditioned Aggregate Query 74
# Generated Conditioned Aggregate Query 75
# Generated Conditioned Aggregate Query 76
# Generated Conditioned Aggregate Query 77
# Generated Conditioned Aggregate Query 78
# Generated Conditioned Aggregate Query 79
# Generated Conditioned Aggregate Query 80
# Generated Conditioned Aggregate Query 81
# Generated Conditioned Aggregate Query 82
# Generated Conditioned Aggregate Query 83
# Generated Conditioned Aggregate Query 84
# Generated Conditioned Aggregate Query 85
# Generated Conditioned Aggregate Query 86
# Generated Conditioned Aggregate Query 87
# Generated Conditioned Aggregate Query 88
# Generated Conditioned Aggregate Query 89
# Generated Conditioned Aggregate Query 90
# Generated Conditioned Aggregate Query 91
# Generated Conditioned Aggregate Query 92
# Generated Conditioned Aggregate Query 93
# Generated Conditioned Aggregate Query 94
# Generated Conditioned Aggregate Query 95
# Generated Conditioned Aggregate Query 96
# Generated Conditioned Aggregate Query 97
# Generated Conditioned Aggregate Query 98
# Generated Conditioned Aggregate Query 99

# %%
with open(runs_dir+'/sql.html', 'w') as file_writer:
    print_twin_agg_queries(scored_queries, file_writer)
# if os.name=='posix':
#     pdf.from_file('sql.html','sql.pdf')
hlngr_stats=calc_stats(scored_queries['hlngr_dist'])
fig=plot_violin(np.array(scored_queries['hlngr_dist']),'Hellinger Dist.','Real-Synthetic Query Comparison for {} Dataset'.format(testq.REAL_TBL_NAME),hlngr_stats)
fig.savefig(runs_dir+'/hlngr.png')
if agg_fntn:
    ecldn_stats=calc_stats(scored_queries['ecldn_dist'])
    fig=plot_violin(np.array(scored_queries['ecldn_dist']),'Euclidean Dist.','Real-Synthetic Query Comparison for {} Dataset'.format(testq.REAL_TBL_NAME),ecldn_stats)
    fig.savefig(runs_dir+'/ecldn.png')

# %% [markdown]
# # Testing fuzz_tabular

# %%
import os
import sys
from pathlib import Path

sys.path.append('/home/samer/projects/fuzzy_sql/src') #This will enable reading the modules
from fuzzy_sql.fuzzy_sql import *
from fuzzy_sql.tabular_query import TABULAR_QUERY

# %%
#set paths
root_dir=Path(os.getcwd()).parent
real_path=os.path.join(root_dir,'data/tabular/ready/real/C1.csv')
meta_path=os.path.join(root_dir,'data/tabular/ready/metadata/C1.json')
syn_path=os.path.join(root_dir,'data/tabular/ready/synthetic/C1_syn_default_1.csv')
runs_dir=os.path.join(root_dir,'.runs')

# %%
# Test fuzz tabular
fuzz_tabular(100, 'single_fltr', real_path, meta_path,syn_path,run_folder='../.runs', printme=True)
# Out:
# Table C1 already exists in the database
# Table C1_syn_default_1 already exists in the database
# Generated Filter Query 0
# Generated Filter Query 1
# Generated Filter Query 2
# Generated Filter Query 3
# Generated Filter Query 4
# Generated Filter Query 5
# Generated Filter Query 6
# Generated Filter Query 7
# Generated Filter Query 8
# Generated Filter Query 9
# Generated Filter Query 10
# Generated Filter Query 11
# Generated Filter Query 12
# Generated Filter Query 13
# Generated Filter Query 14
# Generated Filter Query 15
# Generated Filter Query 16
# Generated Filter Query 17
# Generated Filter Query 18
# Generated Filter Query 19
# Generated Filter Query 20
# Generated Filter Query 21
# Generated Filter Query 22
# Generated Filter Query 23
# Generated Filter Query 24
# Generated Filter Query 25
# Generated Filter Query 26
# Generated Filter Query 27
# Generated Filter Query 28
# Generated Filter Query 29
# Generated Filter Query 30
# Generated Filter Query 31
# Generated Filter Query 32
# Generated Filter Query 33
# Generated Filter Query 34
# Generated Filter Query 35
# Generated Filter Query 36
# Generated Filter Query 37
# Generated Filter Query 38
# Generated Filter Query 39
# Generated Filter Query 40
# Generated Filter Query 41
# Generated Filter Query 42
# Generated Filter Query 43
# Generated Filter Query 44
# Generated Filter Query 45
# Generated Filter Query 46
# Generated Filter Query 47
# Generated Filter Query 48
# Generated Filter Query 49
# Generated Filter Query 50
# Generated Filter Query 51
# Generated Filter Query 52
# Generated Filter Query 53
# Generated Filter Query 54
# Generated Filter Query 55
# Generated Filter Query 56
# Generated Filter Query 57
# Generated Filter Query 58
# Generated Filter Query 59
# Generated Filter Query 60
# Generated Filter Query 61
# Generated Filter Query 62
# Generated Filter Query 63
# Generated Filter Query 64
# Generated Filter Query 65
# Generated Filter Query 66
# Generated Filter Query 67
# Generated Filter Query 68
# Generated Filter Query 69
# Generated Filter Query 70
# Generated Filter Query 71
# Generated Filter Query 72
# Generated Filter Query 73
# Generated Filter Query 74
# Generated Filter Query 75
# Generated Filter Query 76
# Generated Filter Query 77
# Generated Filter Query 78
# Generated Filter Query 79
# Generated Filter Query 80
# Generated Filter Query 81
# Generated Filter Query 82
# Generated Filter Query 83
# Generated Filter Query 84
# Generated Filter Query 85
# Generated Filter Query 86
# Generated Filter Query 87
# Generated Filter Query 88
# Generated Filter Query 89
# Generated Filter Query 90
# Generated Filter Query 91
# Generated Filter Query 92
# Generated Filter Query 93
# Generated Filter Query 94
# Generated Filter Query 95
# Generated Filter Query 96
# Generated Filter Query 97
# Generated Filter Query 98
# Generated Filter Query 99
# Generated 100 random queries and saved results in: ../.runs/C1_1665144549
# {'query_real': [      age         workclass  fnlwgt  education      marital.status  \
#   0      39         State-gov   77516  Bachelors       Never-married
#   1      50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
#   2      38           Private  215646    HS-grad            Divorced
#   3      53           Private  234721       11th  Married-civ-spouse
#   4      28           Private  338409  Bachelors  Married-civ-spouse
#   ...    ..               ...     ...        ...                 ...
#   48837  39           Private  215419  Bachelors            Divorced
#   48838  64                 ?  321403    HS-grad             Widowed
#   48839  38           Private  374983  Bachelors  Married-civ-spouse
#   48840  44           Private   83891  Bachelors            Divorced
#   48841  35      Self-emp-inc  182148  Bachelors  Married-civ-spouse
#
#                 occupation    relationship                race     sex  \
#   0           Adm-clerical   Not-in-family               White    Male
#   1        Exec-managerial         Husband               White    Male
#   2      Handlers-cleaners   Not-in-family               White    Male
#   3      Handlers-cleaners         Husband               Black    Male
#   4         Prof-specialty            Wife               Black  Female
#   ...                  ...             ...                 ...     ...
#   48837     Prof-specialty   Not-in-family               White  Female
#   48838                  ?  Other-relative               Black    Male
#   48839     Prof-specialty         Husband               White    Male
#   48840       Adm-clerical       Own-child  Asian-Pac-Islander    Male
#   48841    Exec-managerial         Husband               White    Male
#
#         hours.per.week native.country capital income
#   0                 40  United-States    2174  <=50K
#   1                 13  United-States       0  <=50K
#   2                 40  United-States       0  <=50K
#   3                 40  United-States       0  <=50K
#   4                 40           Cuba       0  <=50K
#   ...              ...            ...     ...    ...
#   48837             36  United-States       0  <=50K
#   48838             40  United-States       0  <=50K
#   48839             50  United-States       0  <=50K
#   48840             40  United-States    5455  <=50K
#   48841             60  United-States       0   >50K
#
#   [48842 rows x 13 columns],
#         age         workclass  fnlwgt  education      marital.status  \
#   0      39         State-gov   77516  Bachelors       Never-married
#   1      50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
#   2      38           Private  215646    HS-grad            Divorced
#   3      53           Private  234721       11th  Married-civ-spouse
#   4      28           Private  338409  Bachelors  Married-civ-spouse
#   ...    ..               ...     ...        ...                 ...
#   46923  39           Private  215419  Bachelors            Divorced
#   46924  64                 ?  321403    HS-grad             Widowed
#   46925  38           Private  374983  Bachelors  Married-civ-spouse
#   46926  44           Private   83891  Bachelors            Divorced
#   46927  35      Self-emp-inc  182148  Bachelors  Married-civ-spouse
#
#                 occupation    relationship                race     sex  \
#   0           Adm-clerical   Not-in-family               White    Male
#   1        Exec-managerial         Husband               White    Male
#   2      Handlers-cleaners   Not-in-family               White    Male
#   3      Handlers-cleaners         Husband               Black    Male
#   4         Prof-specialty            Wife               Black  Female
#   ...                  ...             ...                 ...     ...
#   46923     Prof-specialty   Not-in-family               White  Female
#   46924                  ?  Other-relative               Black    Male
#   46925     Prof-specialty         Husband               White    Male
#   46926       Adm-clerical       Own-child  Asian-Pac-Islander    Male
#   46927    Exec-managerial         Husband               White    Male
#
#         hours.per.week native.country capital income
#   0                 40  United-States    2174  <=50K
#   1                 13  United-States       0  <=50K
#   2                 40  United-States       0  <=50K
#   3                 40  United-States       0  <=50K
#   4                 40           Cuba       0  <=50K
#   ...              ...            ...     ...    ...
#   46923             36  United-States       0  <=50K
#   46924             40  United-States       0  <=50K
#   46925             50  United-States       0  <=50K
#   46926             40  United-States    5455  <=50K
#   46927             60  United-States       0   >50K
#
#   [46928 rows x 13 columns],
#         age         workclass  fnlwgt  education      marital.status  \
#   0      39         State-gov   77516  Bachelors       Never-married
#   1      50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
#   2      38           Private  215646    HS-grad            Divorced
#   3      37           Private  284582    Masters  Married-civ-spouse
#   4      23           Private  122272  Bachelors       Never-married
#   ...    ..               ...     ...        ...                 ...
#   30855  25           Private  350977    HS-grad       Never-married
#   30856  48         Local-gov  349230    Masters            Divorced
#   30857  33           Private  245211  Bachelors       Never-married
#   30858  39           Private  215419  Bachelors            Divorced
#   30859  38           Private  374983  Bachelors  Married-civ-spouse
#
#                 occupation   relationship   race     sex hours.per.week  \
#   0           Adm-clerical  Not-in-family  White    Male             40
#   1        Exec-managerial        Husband  White    Male             13
#   2      Handlers-cleaners  Not-in-family  White    Male             40
#   3        Exec-managerial           Wife  White  Female             40
#   4           Adm-clerical      Own-child  White  Female             30
#   ...                  ...            ...    ...     ...            ...
#   30855      Other-service      Own-child  White  Female             40
#   30856      Other-service  Not-in-family  White    Male             40
#   30857     Prof-specialty      Own-child  White    Male             40
#   30858     Prof-specialty  Not-in-family  White  Female             36
#   30859     Prof-specialty        Husband  White    Male             50
#
#         native.country capital income
#   0      United-States    2174  <=50K
#   1      United-States       0  <=50K
#   2      United-States       0  <=50K
#   3      United-States       0  <=50K
#   4      United-States       0  <=50K
#   ...              ...     ...    ...
#   30855  United-States       0  <=50K
#   30856  United-States       0  <=50K
#   30857  United-States       0  <=50K
#   30858  United-States       0  <=50K
#   30859  United-States       0  <=50K
#
#   [30860 rows x 13 columns],
#         age         workclass  fnlwgt  education      marital.status  \
#   0      39         State-gov   77516  Bachelors       Never-married
#   1      50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
#   2      38           Private  215646    HS-grad            Divorced
#   3      53           Private  234721       11th  Married-civ-spouse
#   4      28           Private  338409  Bachelors  Married-civ-spouse
#   ...    ..               ...     ...        ...                 ...
#   48837  39           Private  215419  Bachelors            Divorced
#   48838  64                 ?  321403    HS-grad             Widowed
#   48839  38           Private  374983  Bachelors  Married-civ-spouse
#   48840  44           Private   83891  Bachelors            Divorced
#   48841  35      Self-emp-inc  182148  Bachelors  Married-civ-spouse
#
#                 occupation    relationship                race     sex  \
#   0           Adm-clerical   Not-in-family               White    Male
#   1        Exec-managerial         Husband               White    Male
#   2      Handlers-cleaners   Not-in-family               White    Male
#   3      Handlers-cleaners         Husband               Black    Male
#   4         Prof-specialty            Wife               Black  Female
#   ...                  ...             ...                 ...     ...
#   48837     Prof-specialty   Not-in-family               White  Female
#   48838                  ?  Other-relative               Black    Male
#   48839     Prof-specialty         Husband               White    Male
#   48840       Adm-clerical       Own-child  Asian-Pac-Islander    Male
#   48841    Exec-managerial         Husband               White    Male
#
#         hours.per.week native.country capital income
#   0                 40  United-States    2174  <=50K
#   1                 13  United-States       0  <=50K
#   2                 40  United-States       0  <=50K
#   3                 40  United-States       0  <=50K
#   4                 40           Cuba       0  <=50K
#   ...              ...            ...     ...    ...
#   48837             36  United-States       0  <=50K
#   48838             40  United-States       0  <=50K
#   48839             50  United-States       0  <=50K
#   48840             40  United-States    5455  <=50K
#   48841             60  United-States       0   >50K
#
#   [48842 rows x 13 columns],
#         age         workclass  fnlwgt  education      marital.status  \
#   0      39         State-gov   77516  Bachelors       Never-married
#   1      50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
#   2      38           Private  215646    HS-grad            Divorced
#   3      53           Private  234721       11th  Married-civ-spouse
#   4      28           Private  338409  Bachelors  Married-civ-spouse
#   ...    ..               ...     ...        ...                 ...
#   44393  33           Private  245211  Bachelors       Never-married
#   44394  39           Private  215419  Bachelors            Divorced
#   44395  38           Private  374983  Bachelors  Married-civ-spouse
#   44396  44           Private   83891  Bachelors            Divorced
#   44397  35      Self-emp-inc  182148  Bachelors  Married-civ-spouse
#
#                 occupation   relationship                race     sex  \
#   0           Adm-clerical  Not-in-family               White    Male
#   1        Exec-managerial        Husband               White    Male
#   2      Handlers-cleaners  Not-in-family               White    Male
#   3      Handlers-cleaners        Husband               Black    Male
#   4         Prof-specialty           Wife               Black  Female
#   ...                  ...            ...                 ...     ...
#   44393     Prof-specialty      Own-child               White    Male
#   44394     Prof-specialty  Not-in-family               White  Female
#   44395     Prof-specialty        Husband               White    Male
#   44396       Adm-clerical      Own-child  Asian-Pac-Islander    Male
#   44397    Exec-managerial        Husband               White    Male
#
#         hours.per.week native.country capital income
#   0                 40  United-States    2174  <=50K
#   1                 13  United-States       0  <=50K
#   2                 40  United-States       0  <=50K
#   3                 40  United-States       0  <=50K
#   4                 40           Cuba       0  <=50K
#   ...              ...            ...     ...    ...
#   44393             40  United-States       0  <=50K
#   44394             36  United-States       0  <=50K
#   44395             50  United-States       0  <=50K
#   44396             40  United-States    5455  <=50K
#   44397             60  United-States       0   >50K
#
#   [44398 rows x 13 columns],
#     age workclass  fnlwgt  education      marital.status        occupation  \
#   0  36   Private  592930    HS-grad  Married-civ-spouse  Transport-moving
#   1  27   Private   55743  Bachelors  Married-civ-spouse   Exec-managerial
#   2  41   Private  529216  Bachelors            Divorced      Tech-support
#   3  46   Private  471990    HS-grad  Married-civ-spouse  Transport-moving
#   4  36   Private  659504  Bachelors  Married-civ-spouse   Exec-managerial
#   5  32   Private  447066  Bachelors  Married-civ-spouse             Sales
#   6  39   Private  560313    Masters  Married-civ-spouse    Prof-specialty
#   7  39   Private  430336    HS-grad  Married-civ-spouse   Exec-managerial
#   8  39   Private  433592    HS-grad  Married-civ-spouse  Transport-moving
#
#     relationship   race     sex hours.per.week native.country capital income
#   0      Husband  Black    Male             50  United-States       0   >50K
#   1         Wife  Black  Female             45  United-States       0   >50K
#   2    Unmarried  Black    Male             45              ?    7430   >50K
#   3      Husband  Black    Male             46  United-States       0   >50K
#   4      Husband  Black    Male             45  United-States       0   >50K
#   5      Husband  Black    Male             50  United-States   15024   >50K
#   6      Husband  Black    Male             45  United-States       0   >50K
#   7      Husband  Black    Male             45  United-States    7688   >50K
#   8      Husband  Black    Male             45  United-States       0   >50K  ,
#       age     workclass  fnlwgt  education marital.status         occupation  \
#   0    17             ?  304873       10th  Never-married                  ?
#   1    17       Private  191260        9th  Never-married      Other-service
#   2    17       Private  175024       11th  Never-married  Handlers-cleaners
#   3    26     Local-gov  208122  Bachelors  Never-married     Prof-specialty
#   4    22       Private  240817    HS-grad  Never-married              Sales
#   ..   ..           ...     ...        ...            ...                ...
#   293  31  Self-emp-inc  162442    Masters  Never-married              Sales
#   294  34   Federal-gov  174724  Assoc-voc       Divorced       Adm-clerical
#   295  25       Private   96862    HS-grad  Never-married       Adm-clerical
#   296  37       Private  422933    Masters  Never-married    Exec-managerial
#   297  44       Private   83891  Bachelors       Divorced       Adm-clerical
#
#       relationship                race     sex hours.per.week native.country  \
#   0      Own-child               White  Female             32  United-States
#   1      Own-child               White    Male             24  United-States
#   2      Own-child               White    Male             18  United-States
#   3      Own-child               White    Male             40  United-States
#   4      Own-child               White  Female             40  United-States
#   ..           ...                 ...     ...            ...            ...
#   293    Own-child               White  Female             40  United-States
#   294    Own-child               Black  Female             40  United-States
#   295    Own-child               White  Female             40  United-States
#   296    Own-child               White    Male             40  United-States
#   297    Own-child  Asian-Pac-Islander    Male             40  United-States
#
#       capital income
#   0     34095  <=50K
#   1      1055  <=50K
#   2      2176  <=50K
#   3      1055  <=50K
#   4      2597  <=50K
#   ..      ...    ...
#   293   27828   >50K
#   294    1831  <=50K
#   295    2174  <=50K
#   296       0   >50K
#   297    5455  <=50K
#
#   [298 rows x 13 columns],
#         age         workclass  fnlwgt   education      marital.status  \
#   0      39         State-gov   77516   Bachelors       Never-married
#   1      50  Self-emp-not-inc   83311   Bachelors  Married-civ-spouse
#   2      38           Private  215646     HS-grad            Divorced
#   3      53           Private  234721        11th  Married-civ-spouse
#   4      32           Private  205019  Assoc-acdm       Never-married
#   ...    ..               ...     ...         ...                 ...
#   24312  48         Local-gov  349230     Masters            Divorced
#   24313  33           Private  245211   Bachelors       Never-married
#   24314  64                 ?  321403     HS-grad             Widowed
#   24315  38           Private  374983   Bachelors  Married-civ-spouse
#   24316  44           Private   83891   Bachelors            Divorced
#
#                 occupation    relationship                race   sex  \
#   0           Adm-clerical   Not-in-family               White  Male
#   1        Exec-managerial         Husband               White  Male
#   2      Handlers-cleaners   Not-in-family               White  Male
#   3      Handlers-cleaners         Husband               Black  Male
#   4                  Sales   Not-in-family               Black  Male
#   ...                  ...             ...                 ...   ...
#   24312      Other-service   Not-in-family               White  Male
#   24313     Prof-specialty       Own-child               White  Male
#   24314                  ?  Other-relative               Black  Male
#   24315     Prof-specialty         Husband               White  Male
#   24316       Adm-clerical       Own-child  Asian-Pac-Islander  Male
#
#         hours.per.week native.country capital income
#   0                 40  United-States    2174  <=50K
#   1                 13  United-States       0  <=50K
#   2                 40  United-States       0  <=50K
#   3                 40  United-States       0  <=50K
#   4                 50  United-States       0  <=50K
#   ...              ...            ...     ...    ...
#   24312             40  United-States       0  <=50K
#   24313             40  United-States       0  <=50K
#   24314             40  United-States       0  <=50K
#   24315             50  United-States       0  <=50K
#   24316             40  United-States    5455  <=50K
#
#   [24317 rows x 13 columns],
#         age workclass  fnlwgt  education         marital.status  \
#   0      38   Private  215646    HS-grad               Divorced
#   1      53   Private  234721       11th     Married-civ-spouse
#   2      28   Private  338409  Bachelors     Married-civ-spouse
#   3      37   Private  284582    Masters     Married-civ-spouse
#   4      49   Private  160187        9th  Married-spouse-absent
#   ...    ..       ...     ...        ...                    ...
#   44417  33   Private  245211  Bachelors          Never-married
#   44418  39   Private  215419  Bachelors               Divorced
#   44419  64         ?  321403    HS-grad                Widowed
#   44420  38   Private  374983  Bachelors     Married-civ-spouse
#   44421  44   Private   83891  Bachelors               Divorced
#
#                 occupation    relationship                race     sex  \
#   0      Handlers-cleaners   Not-in-family               White    Male
#   1      Handlers-cleaners         Husband               Black    Male
#   2         Prof-specialty            Wife               Black  Female
#   3        Exec-managerial            Wife               White  Female
#   4          Other-service   Not-in-family               Black  Female
#   ...                  ...             ...                 ...     ...
#   44417     Prof-specialty       Own-child               White    Male
#   44418     Prof-specialty   Not-in-family               White  Female
#   44419                  ?  Other-relative               Black    Male
#   44420     Prof-specialty         Husband               White    Male
#   44421       Adm-clerical       Own-child  Asian-Pac-Islander    Male
#
#         hours.per.week native.country capital income
#   0                 40  United-States       0  <=50K
#   1                 40  United-States       0  <=50K
#   2                 40           Cuba       0  <=50K
#   3                 40  United-States       0  <=50K
#   4                 16        Jamaica       0  <=50K
#   ...              ...            ...     ...    ...
#   44417             40  United-States       0  <=50K
#   44418             36  United-States       0  <=50K
#   44419             40  United-States       0  <=50K
#   44420             50  United-States       0  <=50K
#   44421             40  United-States    5455  <=50K
#
#   [44422 rows x 13 columns],
#         age         workclass  fnlwgt     education      marital.status  \
#   0      50  Self-emp-not-inc   83311     Bachelors  Married-civ-spouse
#   1      53           Private  234721          11th  Married-civ-spouse
#   2      52  Self-emp-not-inc  209642       HS-grad  Married-civ-spouse
#   3      42           Private  159449     Bachelors  Married-civ-spouse
#   4      37           Private  280464  Some-college  Married-civ-spouse
#   ...    ..               ...     ...           ...                 ...
#   19894  48           Private  285570       HS-grad  Married-civ-spouse
#   19895  61           Private   89686       HS-grad  Married-civ-spouse
#   19896  31           Private  440129       HS-grad  Married-civ-spouse
#   19897  38           Private  374983     Bachelors  Married-civ-spouse
#   19898  35      Self-emp-inc  182148     Bachelors  Married-civ-spouse
#
#                 occupation relationship   race   sex hours.per.week  \
#   0        Exec-managerial      Husband  White  Male             13
#   1      Handlers-cleaners      Husband  Black  Male             40
#   2        Exec-managerial      Husband  White  Male             45
#   3        Exec-managerial      Husband  White  Male             40
#   4        Exec-managerial      Husband  Black  Male             80
#   ...                  ...          ...    ...   ...            ...
#   19894       Adm-clerical      Husband  White  Male             40
#   19895              Sales      Husband  White  Male             48
#   19896       Craft-repair      Husband  White  Male             40
#   19897     Prof-specialty      Husband  White  Male             50
#   19898    Exec-managerial      Husband  White  Male             60
#
#         native.country capital income
#   0      United-States       0  <=50K
#   1      United-States       0  <=50K
#   2      United-States       0   >50K
#   3      United-States    5178   >50K
#   4      United-States       0   >50K
#   ...              ...     ...    ...
#   19894  United-States       0  <=50K
#   19895  United-States       0  <=50K
#   19896  United-States       0  <=50K
#   19897  United-States       0  <=50K
#   19898  United-States       0   >50K
#
#   [19899 rows x 13 columns],
#         age         workclass  fnlwgt  education      marital.status  \
#   0      39         State-gov   77516  Bachelors       Never-married
#   1      50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
#   2      38           Private  215646    HS-grad            Divorced
#   3      53           Private  234721       11th  Married-civ-spouse
#   4      28           Private  338409  Bachelors  Married-civ-spouse
#   ...    ..               ...     ...        ...                 ...
#   46990  39           Private  215419  Bachelors            Divorced
#   46991  64                 ?  321403    HS-grad             Widowed
#   46992  38           Private  374983  Bachelors  Married-civ-spouse
#   46993  44           Private   83891  Bachelors            Divorced
#   46994  35      Self-emp-inc  182148  Bachelors  Married-civ-spouse
#
#                 occupation    relationship                race     sex  \
#   0           Adm-clerical   Not-in-family               White    Male
#   1        Exec-managerial         Husband               White    Male
#   2      Handlers-cleaners   Not-in-family               White    Male
#   3      Handlers-cleaners         Husband               Black    Male
#   4         Prof-specialty            Wife               Black  Female
#   ...                  ...             ...                 ...     ...
#   46990     Prof-specialty   Not-in-family               White  Female
#   46991                  ?  Other-relative               Black    Male
#   46992     Prof-specialty         Husband               White    Male
#   46993       Adm-clerical       Own-child  Asian-Pac-Islander    Male
#   46994    Exec-managerial         Husband               White    Male
#
#         hours.per.week native.country capital income
#   0                 40  United-States    2174  <=50K
#   1                 13  United-States       0  <=50K
#   2                 40  United-States       0  <=50K
#   3                 40  United-States       0  <=50K
#   4                 40           Cuba       0  <=50K
#   ...              ...            ...     ...    ...
#   46990             36  United-States       0  <=50K
#   46991             40  United-States       0  <=50K
#   46992             50  United-States       0  <=50K
#   46993             40  United-States    5455  <=50K
#   46994             60  United-States       0   >50K
#
#   [46995 rows x 13 columns],
#         age         workclass  fnlwgt  education      marital.status  \
#   0      50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
#   1      53           Private  234721       11th  Married-civ-spouse
#   2      28           Private  338409  Bachelors  Married-civ-spouse
#   3      37           Private  284582    Masters  Married-civ-spouse
#   4      52  Self-emp-not-inc  209642    HS-grad  Married-civ-spouse
#   ...    ..               ...     ...        ...                 ...
#   23245  48           Private  285570    HS-grad  Married-civ-spouse
#   23246  61           Private   89686    HS-grad  Married-civ-spouse
#   23247  31           Private  440129    HS-grad  Married-civ-spouse
#   23248  38           Private  374983  Bachelors  Married-civ-spouse
#   23249  35      Self-emp-inc  182148  Bachelors  Married-civ-spouse
#
#                 occupation relationship   race     sex hours.per.week  \
#   0        Exec-managerial      Husband  White    Male             13
#   1      Handlers-cleaners      Husband  Black    Male             40
#   2         Prof-specialty         Wife  Black  Female             40
#   3        Exec-managerial         Wife  White  Female             40
#   4        Exec-managerial      Husband  White    Male             45
#   ...                  ...          ...    ...     ...            ...
#   23245       Adm-clerical      Husband  White    Male             40
#   23246              Sales      Husband  White    Male             48
#   23247       Craft-repair      Husband  White    Male             40
#   23248     Prof-specialty      Husband  White    Male             50
#   23249    Exec-managerial      Husband  White    Male             60
#
#         native.country capital income
#   0      United-States       0  <=50K
#   1      United-States       0  <=50K
#   2               Cuba       0  <=50K
#   3      United-States       0  <=50K
#   4      United-States       0   >50K
#   ...              ...     ...    ...
#   23245  United-States       0  <=50K
#   23246  United-States       0  <=50K
#   23247  United-States       0  <=50K
#   23248  United-States       0  <=50K
#   23249  United-States       0   >50K
#
#   [23250 rows x 13 columns],
#        age     workclass  fnlwgt     education      marital.status  \
#   0     59       Private  109015       HS-grad            Divorced
#   1     53       Private  169846       HS-grad  Married-civ-spouse
#   2     53             ?  135105     Bachelors            Divorced
#   3     58  Self-emp-inc  210563       HS-grad  Married-civ-spouse
#   4     53     Local-gov  140359     Preschool       Never-married
#   ...   ..           ...     ...           ...                 ...
#   2044  51       Private  176608       HS-grad  Married-civ-spouse
#   2045  58       Private  126104          10th            Divorced
#   2046  52       Private  137984       HS-grad            Divorced
#   2047  73  Self-emp-inc  159691  Some-college            Divorced
#   2048  55       Private  224655       HS-grad           Separated
#
#                occupation   relationship   race     sex hours.per.week  \
#   0          Tech-support      Unmarried  White  Female             40
#   1          Adm-clerical           Wife  White  Female             40
#   2                     ?  Not-in-family  White  Female             50
#   3                 Sales           Wife  White  Female             35
#   4     Machine-op-inspct  Not-in-family  White  Female             35
#   ...                 ...            ...    ...     ...            ...
#   2044  Machine-op-inspct           Wife  White  Female             40
#   2045      Other-service      Unmarried  White  Female             65
#   2046       Craft-repair      Unmarried  White  Female             40
#   2047    Exec-managerial  Not-in-family  White  Female             40
#   2048    Priv-house-serv  Not-in-family  White  Female             32
#
#        native.country capital income
#   0     United-States       0  <=50K
#   1     United-States       0   >50K
#   2     United-States       0  <=50K
#   3     United-States   15024   >50K
#   4     United-States       0  <=50K
#   ...             ...     ...    ...
#   2044  United-States       0  <=50K
#   2045  United-States       0  <=50K
#   2046  United-States       0  <=50K
#   2047  United-States       0  <=50K
#   2048  United-States       0  <=50K
#
#   [2049 rows x 13 columns],
#         age         workclass  fnlwgt  education      marital.status  \
#   0      39         State-gov   77516  Bachelors       Never-married
#   1      50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
#   2      38           Private  215646    HS-grad            Divorced
#   3      53           Private  234721       11th  Married-civ-spouse
#   4      28           Private  338409  Bachelors  Married-civ-spouse
#   ...    ..               ...     ...        ...                 ...
#   33876  39           Private  215419  Bachelors            Divorced
#   33877  64                 ?  321403    HS-grad             Widowed
#   33878  38           Private  374983  Bachelors  Married-civ-spouse
#   33879  44           Private   83891  Bachelors            Divorced
#   33880  35      Self-emp-inc  182148  Bachelors  Married-civ-spouse
#
#                 occupation    relationship                race     sex  \
#   0           Adm-clerical   Not-in-family               White    Male
#   1        Exec-managerial         Husband               White    Male
#   2      Handlers-cleaners   Not-in-family               White    Male
#   3      Handlers-cleaners         Husband               Black    Male
#   4         Prof-specialty            Wife               Black  Female
#   ...                  ...             ...                 ...     ...
#   33876     Prof-specialty   Not-in-family               White  Female
#   33877                  ?  Other-relative               Black    Male
#   33878     Prof-specialty         Husband               White    Male
#   33879       Adm-clerical       Own-child  Asian-Pac-Islander    Male
#   33880    Exec-managerial         Husband               White    Male
#
#         hours.per.week native.country capital income
#   0                 40  United-States    2174  <=50K
#   1                 13  United-States       0  <=50K
#   2                 40  United-States       0  <=50K
#   3                 40  United-States       0  <=50K
#   4                 40           Cuba       0  <=50K
#   ...              ...            ...     ...    ...
#   33876             36  United-States       0  <=50K
#   33877             40  United-States       0  <=50K
#   33878             50  United-States       0  <=50K
#   33879             40  United-States    5455  <=50K
#   33880             60  United-States       0   >50K
#
#   [33881 rows x 13 columns],
#         age         workclass  fnlwgt  education      marital.status  \
#   0      39         State-gov   77516  Bachelors       Never-married
#   1      50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
#   2      38           Private  215646    HS-grad            Divorced
#   3      53           Private  234721       11th  Married-civ-spouse
#   4      37           Private  284582    Masters  Married-civ-spouse
#   ...    ..               ...     ...        ...                 ...
#   43827  39           Private  215419  Bachelors            Divorced
#   43828  64                 ?  321403    HS-grad             Widowed
#   43829  38           Private  374983  Bachelors  Married-civ-spouse
#   43830  44           Private   83891  Bachelors            Divorced
#   43831  35      Self-emp-inc  182148  Bachelors  Married-civ-spouse
#
#                 occupation    relationship                race     sex  \
#   0           Adm-clerical   Not-in-family               White    Male
#   1        Exec-managerial         Husband               White    Male
#   2      Handlers-cleaners   Not-in-family               White    Male
#   3      Handlers-cleaners         Husband               Black    Male
#   4        Exec-managerial            Wife               White  Female
#   ...                  ...             ...                 ...     ...
#   43827     Prof-specialty   Not-in-family               White  Female
#   43828                  ?  Other-relative               Black    Male
#   43829     Prof-specialty         Husband               White    Male
#   43830       Adm-clerical       Own-child  Asian-Pac-Islander    Male
#   43831    Exec-managerial         Husband               White    Male
#
#         hours.per.week native.country capital income
#   0                 40  United-States    2174  <=50K
#   1                 13  United-States       0  <=50K
#   2                 40  United-States       0  <=50K
#   3                 40  United-States       0  <=50K
#   4                 40  United-States       0  <=50K
#   ...              ...            ...     ...    ...
#   43827             36  United-States       0  <=50K
#   43828             40  United-States       0  <=50K
#   43829             50  United-States       0  <=50K
#   43830             40  United-States    5455  <=50K
#   43831             60  United-States       0   >50K
#
#   [43832 rows x 13 columns],
#   Empty DataFrame
#   Columns: [age, workclass, fnlwgt, education, marital.status, occupation, relationship, race, sex, hours.per.week, native.country, capital, income]
#   Index: [],
#        age  workclass  fnlwgt     education         marital.status  \
#   0     49    Private  160187           9th  Married-spouse-absent
#   1     30  State-gov  141297     Bachelors     Married-civ-spouse
#   2     34    Private  245487       7th-8th     Married-civ-spouse
#   3     54    Private  302146       HS-grad              Separated
#   4     20    Private  266015  Some-college          Never-married
#   ...   ..        ...     ...           ...                    ...
#   1723  39    Private  109351     Assoc-voc              Separated
#   1724  23    Private  237811  Some-college          Never-married
#   1725  39    Private  139057   Prof-school     Married-civ-spouse
#   1726  57    Private  106910     Assoc-voc               Divorced
#   1727  55    Private  224655       HS-grad              Separated
#
#               occupation    relationship                race     sex  \
#   0        Other-service   Not-in-family               Black  Female
#   1       Prof-specialty         Husband  Asian-Pac-Islander    Male
#   2     Transport-moving         Husband  Amer-Indian-Eskimo    Male
#   3        Other-service       Unmarried               Black  Female
#   4                Sales       Own-child               Black    Male
#   ...                ...             ...                 ...     ...
#   1723      Adm-clerical   Not-in-family               White  Female
#   1724      Adm-clerical       Unmarried               Black  Female
#   1725    Prof-specialty         Husband  Asian-Pac-Islander    Male
#   1726     Other-service  Other-relative  Asian-Pac-Islander  Female
#   1727   Priv-house-serv   Not-in-family               White  Female
#
#        hours.per.week              native.country capital income
#   0                16                     Jamaica       0  <=50K
#   1                40                       India       0   >50K
#   2                45                      Mexico       0  <=50K
#   3                20               United-States       0  <=50K
#   4                44               United-States       0  <=50K
#   ...             ...                         ...     ...    ...
#   1723             40               United-States       0  <=50K
#   1724             40             Trinadad&Tobago       0  <=50K
#   1725             38                       India       0  <=50K
#   1726             40  Outlying-US(Guam-USVI-etc)       0  <=50K
#   1727             32               United-States       0  <=50K
#
#   [1728 rows x 13 columns],
#        age workclass  fnlwgt     education         marital.status  \
#   0     38   Private  215646       HS-grad               Divorced
#   1     49   Private  160187           9th  Married-spouse-absent
#   2     31   Private   45781       Masters          Never-married
#   3     32   Private  205019    Assoc-acdm          Never-married
#   4     39   Private  367260       HS-grad               Divorced
#   ...   ..       ...     ...           ...                    ...
#   9110  39   Private  229647     Bachelors          Never-married
#   9111  27   Private  430340  Some-college          Never-married
#   9112  55   Private  224655       HS-grad              Separated
#   9113  58   Private  292710    Assoc-acdm               Divorced
#   9114  39   Private  215419     Bachelors               Divorced
#
#                occupation   relationship   race     sex hours.per.week  \
#   0     Handlers-cleaners  Not-in-family  White    Male             40
#   1         Other-service  Not-in-family  Black  Female             16
#   2        Prof-specialty  Not-in-family  White  Female             50
#   3                 Sales  Not-in-family  Black    Male             50
#   4       Exec-managerial  Not-in-family  White    Male             80
#   ...                 ...            ...    ...     ...            ...
#   9110       Tech-support  Not-in-family  White  Female             40
#   9111              Sales  Not-in-family  White  Female             45
#   9112    Priv-house-serv  Not-in-family  White  Female             32
#   9113     Prof-specialty  Not-in-family  White    Male             36
#   9114     Prof-specialty  Not-in-family  White  Female             36
#
#        native.country capital income
#   0     United-States       0  <=50K
#   1           Jamaica       0  <=50K
#   2     United-States   14084   >50K
#   3     United-States       0  <=50K
#   4     United-States       0  <=50K
#   ...             ...     ...    ...
#   9110  United-States   -1669  <=50K
#   9111  United-States       0  <=50K
#   9112  United-States       0  <=50K
#   9113  United-States       0  <=50K
#   9114  United-States       0  <=50K
#
#   [9115 rows x 13 columns],
#         age         workclass  fnlwgt  education      marital.status  \
#   0      39         State-gov   77516  Bachelors       Never-married
#   1      50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
#   2      38           Private  215646    HS-grad            Divorced
#   3      53           Private  234721       11th  Married-civ-spouse
#   4      28           Private  338409  Bachelors  Married-civ-spouse
#   ...    ..               ...     ...        ...                 ...
#   48837  39           Private  215419  Bachelors            Divorced
#   48838  64                 ?  321403    HS-grad             Widowed
#   48839  38           Private  374983  Bachelors  Married-civ-spouse
#   48840  44           Private   83891  Bachelors            Divorced
#   48841  35      Self-emp-inc  182148  Bachelors  Married-civ-spouse
#
#                 occupation    relationship                race     sex  \
#   0           Adm-clerical   Not-in-family               White    Male
#   1        Exec-managerial         Husband               White    Male
#   2      Handlers-cleaners   Not-in-family               White    Male
#   3      Handlers-cleaners         Husband               Black    Male
#   4         Prof-specialty            Wife               Black  Female
#   ...                  ...             ...                 ...     ...
#   48837     Prof-specialty   Not-in-family               White  Female
#   48838                  ?  Other-relative               Black    Male
#   48839     Prof-specialty         Husband               White    Male
#   48840       Adm-clerical       Own-child  Asian-Pac-Islander    Male
#   48841    Exec-managerial         Husband               White    Male
#
#         hours.per.week native.country capital income
#   0                 40  United-States    2174  <=50K
#   1                 13  United-States       0  <=50K
#   2                 40  United-States       0  <=50K
#   3                 40  United-States       0  <=50K
#   4                 40           Cuba       0  <=50K
#   ...              ...            ...     ...    ...
#   48837             36  United-States       0  <=50K
#   48838             40  United-States       0  <=50K
#   48839             50  United-States       0  <=50K
#   48840             40  United-States    5455  <=50K
#   48841             60  United-States       0   >50K
#
#   [48842 rows x 13 columns],
#         age         workclass  fnlwgt  education      marital.status  \
#   0      39         State-gov   77516  Bachelors       Never-married
#   1      50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
#   2      38           Private  215646    HS-grad            Divorced
#   3      53           Private  234721       11th  Married-civ-spouse
#   4      28           Private  338409  Bachelors  Married-civ-spouse
#   ...    ..               ...     ...        ...                 ...
#   48686  39           Private  215419  Bachelors            Divorced
#   48687  64                 ?  321403    HS-grad             Widowed
#   48688  38           Private  374983  Bachelors  Married-civ-spouse
#   48689  44           Private   83891  Bachelors            Divorced
#   48690  35      Self-emp-inc  182148  Bachelors  Married-civ-spouse
#
#                 occupation    relationship                race     sex  \
#   0           Adm-clerical   Not-in-family               White    Male
#   1        Exec-managerial         Husband               White    Male
#   2      Handlers-cleaners   Not-in-family               White    Male
#   3      Handlers-cleaners         Husband               Black    Male
#   4         Prof-specialty            Wife               Black  Female
#   ...                  ...             ...                 ...     ...
#   48686     Prof-specialty   Not-in-family               White  Female
#   48687                  ?  Other-relative               Black    Male
#   48688     Prof-specialty         Husband               White    Male
#   48689       Adm-clerical       Own-child  Asian-Pac-Islander    Male
#   48690    Exec-managerial         Husband               White    Male
#
#         hours.per.week native.country capital income
#   0                 40  United-States    2174  <=50K
#   1                 13  United-States       0  <=50K
#   2                 40  United-States       0  <=50K
#   3                 40  United-States       0  <=50K
#   4                 40           Cuba       0  <=50K
#   ...              ...            ...     ...    ...
#   48686             36  United-States       0  <=50K
#   48687             40  United-States       0  <=50K
#   48688             50  United-States       0  <=50K
#   48689             40  United-States    5455  <=50K
#   48690             60  United-States       0   >50K
#
#   [48691 rows x 13 columns],
#         age         workclass  fnlwgt  education      marital.status  \
#   0      50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
#   1      53           Private  234721       11th  Married-civ-spouse
#   2      28           Private  338409  Bachelors  Married-civ-spouse
#   3      37           Private  284582    Masters  Married-civ-spouse
#   4      52  Self-emp-not-inc  209642    HS-grad  Married-civ-spouse
# ...
#    'real_n_rcrds': 0,
#    'syn_n_rcrds': nan,
#    'query_match_vars': ['age', 'capital'],
#    'real_sql': 'SELECT * FROM C1  WHERE (`age` < 32  AND  `capital` = -1825)  ',
#    'syn_sql': nan},
#   {'query_type': 'fltr_0',
#    'real_table_name': 'C1',
#    'syn_table_name': nan,
#    'query_tmplt_idx': nan,
#    'real_query_tmplt': "SELECT * FROM C1 WHERE (`capital` < 0)  AND (`sex` LIKE 'Female'  AND  `education` <> '7th-8th')   OR (`race` LIKE 'White'  OR  `native.country` <> 'United-States')  ",
#    'syn_query_tmplt': nan,
#    'query_cat_vars': ['sex', 'education', 'race', 'native.country'],
#    'query_cnt_vars': ['capital'],
#    'query_cnt_var': nan,
#    'query_agg_op': nan,
#    'real_n_rcrds': 43576,
#    'syn_n_rcrds': nan,
#    'query_match_vars': ['sex',
#     'education',
#     'race',
#     'native.country',
#     'capital'],
#    'real_sql': "SELECT * FROM C1 WHERE (`capital` < 0)  AND (`sex` LIKE 'Female'  AND  `education` <> '7th-8th')   OR (`race` LIKE 'White'  OR  `native.country` <> 'United-States')  ",
#    'syn_sql': nan},
#   {'query_type': 'fltr_0',
#    'real_table_name': 'C1',
#    'syn_table_name': nan,
#    'query_tmplt_idx': nan,
#    'real_query_tmplt': "SELECT * FROM C1  WHERE (`workclass` LIKE '?'  OR  `native.country` = 'United-States')   AND (`education` LIKE 'Some-college'  AND  `hours.per.week` >= 50)  ",
#    'syn_query_tmplt': nan,
#    'query_cat_vars': ['workclass', 'native.country', 'education'],
#    'query_cnt_vars': ['hours.per.week'],
#    'query_cnt_var': nan,
#    'query_agg_op': nan,
#    'real_n_rcrds': 1825,
#    'syn_n_rcrds': nan,
#    'query_match_vars': ['workclass',
#     'native.country',
#     'education',
#     'hours.per.week'],
#    'real_sql': "SELECT * FROM C1  WHERE (`workclass` LIKE '?'  OR  `native.country` = 'United-States')   AND (`education` LIKE 'Some-college'  AND  `hours.per.week` >= 50)  ",
#    'syn_sql': nan},
#   {'query_type': 'fltr_0',
#    'real_table_name': 'C1',
#    'syn_table_name': nan,
#    'query_tmplt_idx': nan,
#    'real_query_tmplt': "SELECT * FROM C1  WHERE (`sex` = 'Male'  AND  `education` <> '9th')   OR (`native.country` LIKE 'United-States'  OR   `hours.per.week` BETWEEN 40 AND 70) AND (`income` IN ('>50K', '>50K')  AND  `race` IN ('Asian-Pac-Islander', 'Amer-Indian-Eskimo', 'Amer-Indian-Eskimo', 'Amer-Indian-Eskimo', 'Other'))   AND (`occupation` IN ('Craft-repair', 'Prof-specialty', 'Priv-house-serv', 'Exec-managerial', 'Handlers-cleaners', 'Tech-support', 'Exec-managerial', 'Exec-managerial', 'Adm-clerical', 'Machine-op-inspct', 'Exec-managerial', 'Other-service', 'Handlers-cleaners', 'Craft-repair', 'Farming-fishing', 'Prof-specialty')  AND  `relationship` = 'Husband')  ",
#    'syn_query_tmplt': nan,
#    'query_cat_vars': ['sex',
#     'education',
#     'native.country',
#     'income',
#     'race',
#     'occupation',
#     'relationship'],
#    'query_cnt_vars': ['hours.per.week'],
#    'query_cnt_var': nan,
#    'query_agg_op': nan,
#    'real_n_rcrds': 32114,
#    'syn_n_rcrds': nan,
#    'query_match_vars': ['sex',
#     'education',
#     'native.country',
#     'income',
#     'race',
#     'occupation',
#     'relationship',
#     'hours.per.week'],
#    'real_sql': "SELECT * FROM C1  WHERE (`sex` = 'Male'  AND  `education` <> '9th')   OR (`native.country` LIKE 'United-States'  OR   `hours.per.week` BETWEEN 40 AND 70) AND (`income` IN ('>50K', '>50K')  AND  `race` IN ('Asian-Pac-Islander', 'Amer-Indian-Eskimo', 'Amer-Indian-Eskimo', 'Amer-Indian-Eskimo', 'Other'))   AND (`occupation` IN ('Craft-repair', 'Prof-specialty', 'Priv-house-serv', 'Exec-managerial', 'Handlers-cleaners', 'Tech-support', 'Exec-managerial', 'Exec-managerial', 'Adm-clerical', 'Machine-op-inspct', 'Exec-managerial', 'Other-service', 'Handlers-cleaners', 'Craft-repair', 'Farming-fishing', 'Prof-specialty')  AND  `relationship` = 'Husband')  ",
#    'syn_sql': nan},
#   {'query_type': 'fltr_0',
#    'real_table_name': 'C1',
#    'syn_table_name': nan,
#    'query_tmplt_idx': nan,
#    'real_query_tmplt': "SELECT * FROM C1  WHERE (`native.country` <> 'United-States'  AND  `relationship` LIKE 'Unmarried')   OR  ((`fnlwgt` BETWEEN 30111 AND 73392) OR  `hours.per.week` BETWEEN 80 AND 3) AND  ((`age` BETWEEN 25 AND 40) AND `race` LIKE 'White')  ",
#    'syn_query_tmplt': nan,
#    'query_cat_vars': ['native.country', 'relationship', 'race'],
#    'query_cnt_vars': ['fnlwgt', 'hours.per.week', 'age'],
#    'query_cnt_var': nan,
#    'query_agg_op': nan,
#    'real_n_rcrds': 4472,
#    'syn_n_rcrds': nan,
#    'query_match_vars': ['native.country',
#     'relationship',
#     'race',
#     'fnlwgt',
#     'hours.per.week',
#     'age'],
#    'real_sql': "SELECT * FROM C1  WHERE (`native.country` <> 'United-States'  AND  `relationship` LIKE 'Unmarried')   OR  ((`fnlwgt` BETWEEN 30111 AND 73392) OR  `hours.per.week` BETWEEN 80 AND 3) AND  ((`age` BETWEEN 25 AND 40) AND `race` LIKE 'White')  ",
#    'syn_sql': nan},
#   {'query_type': 'fltr_0',
#    'real_table_name': 'C1',
#    'syn_table_name': nan,
#    'query_tmplt_idx': nan,
#    'real_query_tmplt': "SELECT * FROM C1  WHERE (`income` <> '<=50K'  OR  `marital.status` LIKE 'Married-civ-spouse')   AND (`age` = 34  AND  `sex` LIKE 'Female')   AND (`occupation` <> 'Adm-clerical'  AND  `race` IN ('Other', 'Amer-Indian-Eskimo', 'White'))   AND (`fnlwgt` = 126613  AND   `capital` BETWEEN 0 AND 0) AND (`native.country` <> 'United-States'  AND  `workclass` <> 'Private')   AND (`education` <> 'Masters'  AND  `hours.per.week` <= 20)  ",
#    'syn_query_tmplt': nan,
#    'query_cat_vars': ['income',
#     'marital.status',
#     'sex',
#     'occupation',
#     'race',
#     'native.country',
#     'workclass',
#     'education'],
#    'query_cnt_vars': ['age', 'fnlwgt', 'capital', 'hours.per.week'],
#    'query_cnt_var': nan,
#    'query_agg_op': nan,
#    'real_n_rcrds': 0,
#    'syn_n_rcrds': nan,
#    'query_match_vars': ['income',
#     'marital.status',
#     'sex',
#     'occupation',
#     'race',
#     'native.country',
#     'workclass',
#     'education',
#     'age',
#     'fnlwgt',
#     'capital',
#     'hours.per.week'],
#    'real_sql': "SELECT * FROM C1  WHERE (`income` <> '<=50K'  OR  `marital.status` LIKE 'Married-civ-spouse')   AND (`age` = 34  AND  `sex` LIKE 'Female')   AND (`occupation` <> 'Adm-clerical'  AND  `race` IN ('Other', 'Amer-Indian-Eskimo', 'White'))   AND (`fnlwgt` = 126613  AND   `capital` BETWEEN 0 AND 0) AND (`native.country` <> 'United-States'  AND  `workclass` <> 'Private')   AND (`education` <> 'Masters'  AND  `hours.per.week` <= 20)  ",
#    'syn_sql': nan},
#   {'query_type': 'fltr_0',
#    'real_table_name': 'C1',
#    'syn_table_name': nan,
#    'query_tmplt_idx': nan,
#    'real_query_tmplt': "SELECT * FROM C1  WHERE  ((`age` BETWEEN 32 AND 28) AND `native.country` LIKE 'United-States')   AND (`capital` <> 0  AND  `income` = '>50K')   AND  ((`hours.per.week` BETWEEN 40 AND 40) AND `marital.status` IN ('Divorced', 'Never-married', 'Married-civ-spouse', 'Divorced', 'Married-AF-spouse'))   AND (`education` <> 'HS-grad'  AND  `workclass` LIKE 'Private')   AND (`occupation` IN ('Machine-op-inspct', 'Prof-specialty', 'Farming-fishing', 'Protective-serv', '?', 'Adm-clerical', 'Handlers-cleaners', 'Prof-specialty')  AND  `relationship` = 'Other-relative')  ",
#    'syn_query_tmplt': nan,
#    'query_cat_vars': ['native.country',
#     'income',
#     'marital.status',
#     'education',
#     'workclass',
#     'occupation',
#     'relationship'],
#    'query_cnt_vars': ['age', 'capital', 'hours.per.week'],
#    'query_cnt_var': nan,
#    'query_agg_op': nan,
#    'real_n_rcrds': 0,
#    'syn_n_rcrds': nan,
#    'query_match_vars': ['native.country',
#     'income',
#     'marital.status',
#     'education',
#     'workclass',
#     'occupation',
#     'relationship',
#     'age',
#     'capital',
#     'hours.per.week'],
#    'real_sql': "SELECT * FROM C1  WHERE  ((`age` BETWEEN 32 AND 28) AND `native.country` LIKE 'United-States')   AND (`capital` <> 0  AND  `income` = '>50K')   AND  ((`hours.per.week` BETWEEN 40 AND 40) AND `marital.status` IN ('Divorced', 'Never-married', 'Married-civ-spouse', 'Divorced', 'Married-AF-spouse'))   AND (`education` <> 'HS-grad'  AND  `workclass` LIKE 'Private')   AND (`occupation` IN ('Machine-op-inspct', 'Prof-specialty', 'Farming-fishing', 'Protective-serv', '?', 'Adm-clerical', 'Handlers-cleaners', 'Prof-specialty')  AND  `relationship` = 'Other-relative')  ",
#    'syn_sql': nan},
#   {'query_type': 'fltr_0',
#    'real_table_name': 'C1',
#    'syn_table_name': nan,
#    'query_tmplt_idx': nan,
#    'real_query_tmplt': "SELECT * FROM C1  WHERE (`fnlwgt` = 78261  OR  `education` IN ('11th', '1st-4th', '5th-6th', 'Bachelors', 'Prof-school', 'Assoc-voc', 'HS-grad'))   OR (`relationship` <> 'Husband'  OR   `hours.per.week` BETWEEN 55 AND 60) OR (`income` <> '<=50K'  OR  `native.country` <> 'United-States')   AND (`age` < 19  AND  `capital` <= 0)  ",
#    'syn_query_tmplt': nan,
#    'query_cat_vars': ['education', 'relationship', 'income', 'native.country'],
#    'query_cnt_vars': ['fnlwgt', 'hours.per.week', 'age', 'capital'],
#    'query_cnt_var': nan,
#    'query_agg_op': nan,
#    'real_n_rcrds': 42265,
#    'syn_n_rcrds': nan,
#    'query_match_vars': ['education',
#     'relationship',
#     'income',
#     'native.country',
#     'fnlwgt',
#     'hours.per.week',
#     'age',
#     'capital'],
#    'real_sql': "SELECT * FROM C1  WHERE (`fnlwgt` = 78261  OR  `education` IN ('11th', '1st-4th', '5th-6th', 'Bachelors', 'Prof-school', 'Assoc-voc', 'HS-grad'))   OR (`relationship` <> 'Husband'  OR   `hours.per.week` BETWEEN 55 AND 60) OR (`income` <> '<=50K'  OR  `native.country` <> 'United-States')   AND (`age` < 19  AND  `capital` <= 0)  ",
#    'syn_sql': nan},
#   {'query_type': 'fltr_0',
#    'real_table_name': 'C1',
#    'syn_table_name': nan,
#    'query_tmplt_idx': nan,
#    'real_query_tmplt': "SELECT * FROM C1  WHERE (`sex` = 'Female'  AND  `relationship` IN ('Other-relative', 'Own-child', 'Unmarried', 'Husband'))   OR (`education` IN ('9th', '7th-8th', 'HS-grad', 'Assoc-acdm', '7th-8th', 'Masters', '9th', 'Masters', '12th', '11th', 'Assoc-acdm', '9th', '1st-4th', 'Assoc-voc')  OR  `fnlwgt` = 112383)   AND (`marital.status` <> 'Married-spouse-absent'  AND  `income` = '>50K')   AND (`race` <> 'White'  AND   `age` BETWEEN 31 AND 24) OR  ((`hours.per.week` BETWEEN 40 AND 25) OR `occupation` = 'Other-service')  ",
#    'syn_query_tmplt': nan,
#    'query_cat_vars': ['sex',
#     'relationship',
#     'education',
#     'marital.status',
#     'income',
#     'race',
#     'occupation'],
#    'query_cnt_vars': ['fnlwgt', 'age', 'hours.per.week'],
#    'query_cnt_var': nan,
#    'query_agg_op': nan,
#    'real_n_rcrds': 11355,
#    'syn_n_rcrds': nan,
#    'query_match_vars': ['sex',
#     'relationship',
#     'education',
#     'marital.status',
#     'income',
#     'race',
#     'occupation',
#     'fnlwgt',
#     'age',
#     'hours.per.week'],
#    'real_sql': "SELECT * FROM C1  WHERE (`sex` = 'Female'  AND  `relationship` IN ('Other-relative', 'Own-child', 'Unmarried', 'Husband'))   OR (`education` IN ('9th', '7th-8th', 'HS-grad', 'Assoc-acdm', '7th-8th', 'Masters', '9th', 'Masters', '12th', '11th', 'Assoc-acdm', '9th', '1st-4th', 'Assoc-voc')  OR  `fnlwgt` = 112383)   AND (`marital.status` <> 'Married-spouse-absent'  AND  `income` = '>50K')   AND (`race` <> 'White'  AND   `age` BETWEEN 31 AND 24) OR  ((`hours.per.week` BETWEEN 40 AND 25) OR `occupation` = 'Other-service')  ",
#    'syn_sql': nan},
#   {'query_type': 'fltr_0',
#    'real_table_name': 'C1',
#    'syn_table_name': nan,
#    'query_tmplt_idx': nan,
#    'real_query_tmplt': "SELECT * FROM C1 WHERE (`hours.per.week` <> 50)  AND (`capital` > 0  AND  `education` LIKE 'Masters')  ",
#    'syn_query_tmplt': nan,
#    'query_cat_vars': ['education'],
#    'query_cnt_vars': ['hours.per.week', 'capital'],
#    'query_cnt_var': nan,
#    'query_agg_op': nan,
#    'real_n_rcrds': 331,
#    'syn_n_rcrds': nan,
#    'query_match_vars': ['education', 'hours.per.week', 'capital'],
#    'real_sql': "SELECT * FROM C1 WHERE (`hours.per.week` <> 50)  AND (`capital` > 0  AND  `education` LIKE 'Masters')  ",
#    'syn_sql': nan},
#   {'query_type': 'fltr_0',
#    'real_table_name': 'C1',
#    'syn_table_name': nan,
#    'query_tmplt_idx': nan,
#    'real_query_tmplt': "SELECT * FROM C1  WHERE (`hours.per.week` = 40  OR  `native.country` LIKE 'United-States')   AND (`capital` > 0  AND  `workclass` LIKE 'Private')   OR (`occupation` = 'Machine-op-inspct'  OR  `fnlwgt` <= 107439)  ",
#    'syn_query_tmplt': nan,
#    'query_cat_vars': ['native.country', 'workclass', 'occupation'],
#    'query_cnt_vars': ['hours.per.week', 'capital', 'fnlwgt'],
#    'query_cnt_var': nan,
#    'query_agg_op': nan,
#    'real_n_rcrds': 6658,
#    'syn_n_rcrds': nan,
#    'query_match_vars': ['native.country',
#     'workclass',
#     'occupation',
#     'hours.per.week',
#     'capital',
#     'fnlwgt'],
#    'real_sql': "SELECT * FROM C1  WHERE (`hours.per.week` = 40  OR  `native.country` LIKE 'United-States')   AND (`capital` > 0  AND  `workclass` LIKE 'Private')   OR (`occupation` = 'Machine-op-inspct'  OR  `fnlwgt` <= 107439)  ",
#    'syn_sql': nan},
#   {'query_type': 'fltr_0',
#    'real_table_name': 'C1',
#    'syn_table_name': nan,
#    'query_tmplt_idx': nan,
#    'real_query_tmplt': "SELECT * FROM C1  WHERE (`education` <> '11th'  OR  `workclass` IN ('Federal-gov', 'Federal-gov', 'State-gov', 'Self-emp-not-inc'))   AND  ((`fnlwgt` BETWEEN 227392 AND 308334) AND `race` = 'Black')   OR (`hours.per.week` < 25  OR  `relationship` = 'Husband')  ",
#    'syn_query_tmplt': nan,
#    'query_cat_vars': ['education', 'workclass', 'race', 'relationship'],
#    'query_cnt_vars': ['fnlwgt', 'hours.per.week'],
#    'query_cnt_var': nan,
#    'query_agg_op': nan,
#    'real_n_rcrds': 24019,
#    'syn_n_rcrds': nan,
#    'query_match_vars': ['education',
#     'workclass',
#     'race',
#     'relationship',
#     'fnlwgt',
#     'hours.per.week'],
#    'real_sql': "SELECT * FROM C1  WHERE (`education` <> '11th'  OR  `workclass` IN ('Federal-gov', 'Federal-gov', 'State-gov', 'Self-emp-not-inc'))   AND  ((`fnlwgt` BETWEEN 227392 AND 308334) AND `race` = 'Black')   OR (`hours.per.week` < 25  OR  `relationship` = 'Husband')  ",
#    'syn_sql': nan},
#   {'query_type': 'fltr_0',
#    'real_table_name': 'C1',
#    'syn_table_name': nan,
#    'query_tmplt_idx': nan,
#    'real_query_tmplt': "SELECT * FROM C1  WHERE (`education` IN ('Some-college', 'Preschool', 'Doctorate', 'Doctorate', 'Assoc-acdm', '11th', '1st-4th', '12th', '10th')  AND  `race` <> 'White')   AND (`fnlwgt` >= 350169  AND  `income` IN ('<=50K', '<=50K'))   OR (`hours.per.week` <= 32  OR   `capital` BETWEEN 0 AND 0) OR (`native.country` IN ('India', 'Columbia', 'Germany', 'France', 'Yugoslavia', 'Thailand', 'England', 'Cuba', 'United-States', 'Vietnam', 'United-States', '?', 'Yugoslavia', 'Dominican-Republic', 'Scotland', 'Honduras', 'Greece', 'Nicaragua', 'Poland', 'Dominican-Republic', 'Columbia', 'Greece', 'Ireland', 'Haiti', 'Guatemala', 'Jamaica', 'Puerto-Rico', 'Hungary', 'Cuba', 'Laos', 'England', 'Holand-Netherlands')  OR  `sex` <> 'Female')  ",
#    'syn_query_tmplt': nan,
#    'query_cat_vars': ['education', 'race', 'income', 'native.country', 'sex'],
#    'query_cnt_vars': ['fnlwgt', 'hours.per.week', 'capital'],
#    'query_cnt_var': nan,
#    'query_agg_op': nan,
#    'real_n_rcrds': 48806,
#    'syn_n_rcrds': nan,
#    'query_match_vars': ['education',
#     'race',
#     'income',
#     'native.country',
#     'sex',
#     'fnlwgt',
#     'hours.per.week',
#     'capital'],
#    'real_sql': "SELECT * FROM C1  WHERE (`education` IN ('Some-college', 'Preschool', 'Doctorate', 'Doctorate', 'Assoc-acdm', '11th', '1st-4th', '12th', '10th')  AND  `race` <> 'White')   AND (`fnlwgt` >= 350169  AND  `income` IN ('<=50K', '<=50K'))   OR (`hours.per.week` <= 32  OR   `capital` BETWEEN 0 AND 0) OR (`native.country` IN ('India', 'Columbia', 'Germany', 'France', 'Yugoslavia', 'Thailand', 'England', 'Cuba', 'United-States', 'Vietnam', 'United-States', '?', 'Yugoslavia', 'Dominican-Republic', 'Scotland', 'Honduras', 'Greece', 'Nicaragua', 'Poland', 'Dominican-Republic', 'Columbia', 'Greece', 'Ireland', 'Haiti', 'Guatemala', 'Jamaica', 'Puerto-Rico', 'Hungary', 'Cuba', 'Laos', 'England', 'Holand-Netherlands')  OR  `sex` <> 'Female')  ",
#    'syn_sql': nan}]}
