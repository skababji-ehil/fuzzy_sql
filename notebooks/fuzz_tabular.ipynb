#   2    no    normal     ckd  0        7.5      14.0
#   3    no    normal     ckd  1       16.1       1.0
#   4    no    normal     ckd  2       13.2       1.0
#   5    no    normal     ckd  3        NaN       NaN
#   6    no    normal     ckd  5        NaN       NaN
#   7    no    normal  notckd  0       13.0     118.0
#   8    no    normal  notckd  1        NaN       NaN
#   9    no    normal  notckd  2        NaN       NaN
#   10   no    normal  notckd  3        NaN       NaN
#   11   no    normal  notckd  4        NaN       NaN
#   12   no    normal  notckd  5        NaN       NaN
#   13  yes  abnormal     ckd  0        7.1      13.0
#   14  yes  abnormal     ckd  2        5.6       5.0
#   15  yes  abnormal     ckd  3        8.1       4.0
#   16  yes  abnormal     ckd  4       12.5       1.0
#   17  yes    normal     ckd  0        7.6      21.0
#   18  yes    normal  notckd  0        NaN       NaN,
#               pcc  cad   pe  ane   dm al su appet     sg          ba  SUM(bp)  \
#   0    notpresent   no   no   no   no  0  0  good  1.005  notpresent      NaN
#   1    notpresent   no   no   no   no  0  0  good   1.01  notpresent    130.0
#   2    notpresent   no   no   no   no  0  0  good  1.015  notpresent    250.0
#   3    notpresent   no   no   no   no  0  0  good   1.02  notpresent   4280.0
#   4    notpresent   no   no   no   no  0  0  good  1.025  notpresent   4280.0
#   ..          ...  ...  ...  ...  ... .. ..   ...    ...         ...      ...
#   98      present   no  yes   no  yes  4  0  poor  1.015  notpresent      NaN
#   99      present   no  yes  yes  yes  0  4  good   1.02  notpresent      NaN
#   100     present  yes   no   no   no  0  0  good   1.02  notpresent      NaN
#   101     present  yes   no   no   no  2  0  good   1.02     present      NaN
#   102     present  yes   no  yes   no  3  0  good   1.02  notpresent      NaN
#
#        COUNT(*)
#   0         NaN
#   1         2.0
#   2         3.0
#   3        60.0
#   4        59.0
#   ..        ...
#   98        NaN
#   99        NaN
#   100       NaN
#   101       NaN
#   102       NaN
#
#   [103 rows x 12 columns],
#       pe appet  SUM(pcv)  COUNT(*)
#   0   no  good      7173       167
#   1   no  poor       340        11
#   2  yes  good       311        10
#   3  yes  poor       577        21,
#      al          ba   pe  htn         pcc  MAX(age)  COUNT(*)
#   0   0  notpresent   no   no  notpresent        80       128
#   1   0  notpresent   no  yes  notpresent        75         8
#   2   0  notpresent  yes  yes  notpresent        73         3
#   3   1  notpresent   no   no  notpresent        63         5
#   4   1  notpresent   no  yes  notpresent        90         6
#   5   1  notpresent  yes  yes  notpresent        67         2
#   6   2  notpresent   no   no  notpresent        60         2
#   7   2  notpresent   no   no     present        45         1
#   8   2  notpresent   no  yes  notpresent        73         4
#   9   2  notpresent   no  yes     present        53         2
#   10  2  notpresent  yes   no     present        42         1
#   11  2  notpresent  yes  yes  notpresent        61         2
#   12  2     present   no   no     present        71         1
#   13  2     present   no  yes  notpresent        63         1
#   14  2     present  yes   no     present        50         1
#   15  3  notpresent   no   no     present        73         1
#   16  3  notpresent   no  yes  notpresent        83         5
#   17  3  notpresent   no  yes     present        73         5
#   18  3  notpresent  yes   no  notpresent        59         1
#   19  3  notpresent  yes  yes  notpresent        69         6
#   20  3  notpresent  yes  yes     present        68         3
#   21  3     present   no  yes  notpresent        60         1
#   22  3     present   no  yes     present        71         1
#   23  3     present  yes  yes     present        68         2
#   24  4  notpresent   no   no  notpresent        56         1
#   25  4  notpresent   no  yes  notpresent        70         4
#   26  4  notpresent  yes  yes  notpresent        71         4
#   27  4  notpresent  yes  yes     present        56         2
#   28  4     present   no   no  notpresent         6         1
#   29  4     present   no   no     present        21         1
#   30  4     present  yes   no  notpresent        48         1
#   31  4     present  yes  yes  notpresent        64         2
#   32  4     present  yes  yes     present        69         1,
#   Empty DataFrame
#   Columns: [cad, al, pe, su, sg, ane, htn, pcc, MAX(bu), COUNT(*)]
#   Index: [],
#      su  htn   dm     sg          ba  MIN(hemo)  COUNT(*)
#   0   0   no   no   1.01  notpresent       11.1         3
#   1   0   no   no   1.01     present        8.2         3
#   2   0   no   no  1.015  notpresent        7.5         8
#   3   0   no   no  1.015     present       11.3         1
#   4   0   no   no   1.02  notpresent        9.8        61
#   5   0   no   no  1.025  notpresent       10.0        60
#   6   0   no  yes  1.005     present       10.3         1
#   7   0   no  yes   1.01  notpresent        9.6         5
#   8   0   no  yes  1.015  notpresent       12.4         1
#   9   0  yes   no  1.005  notpresent       11.2         1
#   10  0  yes   no   1.01  notpresent        7.1         4
#   11  0  yes   no  1.015  notpresent        7.6         6
#   12  0  yes   no   1.02  notpresent        8.7         1
#   13  0  yes   no  1.025  notpresent        9.8         1
#   14  0  yes  yes  1.005  notpresent       10.0         1
#   15  0  yes  yes   1.01  notpresent        8.1         7
#   16  0  yes  yes   1.01     present       10.4         1
#   17  0  yes  yes  1.015  notpresent        7.7         6
#   18  0  yes  yes   1.02  notpresent        9.5         3
#   19  0  yes  yes  1.025  notpresent        9.9         3
#   20  1   no   no  1.015  notpresent       16.1         1
#   21  1  yes   no   1.01  notpresent        7.9         1
#   22  1  yes   no   1.02  notpresent       13.4         1
#   23  1  yes  yes   1.01  notpresent        3.1         3
#   24  1  yes  yes   1.01     present        9.5         2
#   25  1  yes  yes  1.015  notpresent        9.7         1
#   26  2   no  yes  1.015  notpresent       13.2         1
#   27  2  yes   no   1.01     present       13.0         1
#   28  2  yes  yes   1.01  notpresent        8.8         2
#   29  2  yes  yes   1.01     present        5.6         1
#   30  2  yes  yes  1.015  notpresent        7.3         3
#   31  2  yes  yes  1.015     present        7.9         1
#   32  2  yes  yes   1.02  notpresent       10.9         2
#   33  3  yes  yes  1.005  notpresent        8.4         1
#   34  3  yes  yes   1.01  notpresent       10.0         3
#   35  3  yes  yes   1.01     present        9.4         1
#   36  3  yes  yes  1.015  notpresent        8.1         1
#   37  3  yes  yes  1.025  notpresent       12.7         1
#   38  4  yes  yes   1.01  notpresent       12.5         1
#   39  4  yes  yes  1.015  notpresent       10.9         2
#   40  5  yes  yes   1.01     present       11.5         1
#   41  5  yes  yes  1.015  notpresent       12.5         1,
#     Class  AVG(pcv)  COUNT(*)
#   0   ckd      34.0         2,
#         sg         pcc su  htn  MAX(bp)  COUNT(*)
#   0  1.005     present  0  yes       70         1
#   1   1.02  notpresent  2  yes      100         1,
#      al         pcc  cad   Class   dm su     sg        pc  SUM(hemo)  COUNT(*)
#   0   0  notpresent   no     ckd   no  0   1.01  abnormal        NaN       NaN
#   1   0  notpresent   no     ckd   no  0   1.01    normal       45.0       4.0
#   2   0  notpresent   no     ckd   no  0  1.015  abnormal       11.8       1.0
#   3   0  notpresent   no     ckd   no  0   1.02  abnormal        NaN       NaN
#   4   0  notpresent   no     ckd   no  0   1.02    normal       11.3       1.0
#   .. ..         ...  ...     ...  ... ..    ...       ...        ...       ...
#   95  4  notpresent   no  notckd   no  0   1.02    normal        NaN       NaN
#   96  4  notpresent   no  notckd   no  0  1.025    normal        NaN       NaN
#   97  4  notpresent   no  notckd   no  2   1.01    normal        NaN       NaN
#   98  4  notpresent  yes     ckd   no  0  1.025  abnormal        NaN       NaN
#   99  4     present   no     ckd  yes  0  1.015    normal        NaN       NaN
#
#   [100 rows x 10 columns],
#   Empty DataFrame
#   Columns: [appet, sg, MAX(sod), COUNT(*)]
#   Index: []],
#  'query_syn': [    htn        pc   Class su  MIN(hemo)  COUNT(*)
#   0    no  abnormal     ckd  0   9.966591        14
#   1    no  abnormal     ckd  4  10.549322         1
#   2    no    normal     ckd  0   9.461225        25
#   3    no    normal     ckd  1  14.282631         1
#   4    no    normal     ckd  2  11.628731         2
#   5    no    normal     ckd  3  11.734121         2
#   6    no    normal     ckd  5  11.409817         1
#   7    no    normal  notckd  0  12.163944       103
#   8    no    normal  notckd  1  14.184206         3
#   9    no    normal  notckd  2  14.098292         5
#   10   no    normal  notckd  3  13.300737         3
#   11   no    normal  notckd  4  17.267805         1
#   12   no    normal  notckd  5  14.097420         1
#   13  yes  abnormal     ckd  0   8.299664        28
#   14  yes  abnormal     ckd  2  10.142905         1
#   15  yes  abnormal     ckd  3  11.029934         1
#   16  yes  abnormal     ckd  4   9.298001         2
#   17  yes    normal     ckd  0   9.886254        13
#   18  yes    normal  notckd  0  14.977071         2,
#               pcc  cad   pe  ane   dm al su appet     sg          ba  SUM(bp)  \
#   0    notpresent   no   no   no   no  0  0  good  1.005  notpresent      100
#   1    notpresent   no   no   no   no  0  0  good   1.01  notpresent     1280
#   2    notpresent   no   no   no   no  0  0  good  1.015  notpresent      910
#   3    notpresent   no   no   no   no  0  0  good   1.02  notpresent     1700
#   4    notpresent   no   no   no   no  0  0  good  1.025  notpresent     1360
#   ..          ...  ...  ...  ...  ... .. ..   ...    ...         ...      ...
#   98      present   no  yes   no  yes  4  0  poor  1.015  notpresent       80
#   99      present   no  yes  yes  yes  0  4  good   1.02  notpresent       80
#   100     present  yes   no   no   no  0  0  good   1.02  notpresent       70
#   101     present  yes   no   no   no  2  0  good   1.02     present       80
#   102     present  yes   no  yes   no  3  0  good   1.02  notpresent      100
#
#        COUNT(*)
#   0           1
#   1          18
#   2          12
#   3          23
#   4          18
#   ..        ...
#   98          1
#   99          1
#   100         1
#   101         1
#   102         1
#
#   [103 rows x 12 columns],
#       pe appet     SUM(pcv)  COUNT(*)
#   0   no  good  6887.968160     164.0
#   1   no  poor   841.106942      23.0
#   2  yes  good   469.414736      13.0
#   3  yes  poor   253.176133       8.0,
#      al          ba   pe  htn         pcc  MAX(age)  COUNT(*)
#   0   0  notpresent   no   no  notpresent      80.0      95.0
#   1   0  notpresent   no  yes  notpresent      79.0      20.0
#   2   0  notpresent  yes  yes  notpresent      59.0       2.0
#   3   1  notpresent   no   no  notpresent      65.0       9.0
#   4   1  notpresent   no  yes  notpresent      58.0       2.0
#   5   1  notpresent  yes  yes  notpresent      59.0       3.0
#   6   2  notpresent   no   no  notpresent      70.0       8.0
#   7   2  notpresent   no   no     present       NaN       NaN
#   8   2  notpresent   no  yes  notpresent      73.0       2.0
#   9   2  notpresent   no  yes     present       NaN       NaN
#   10  2  notpresent  yes   no     present       NaN       NaN
#   11  2  notpresent  yes  yes  notpresent       NaN       NaN
#   12  2     present   no   no     present       NaN       NaN
#   13  2     present   no  yes  notpresent       NaN       NaN
#   14  2     present  yes   no     present       NaN       NaN
#   15  3  notpresent   no   no     present       NaN       NaN
#   16  3  notpresent   no  yes  notpresent      71.0       2.0
#   17  3  notpresent   no  yes     present      59.0       1.0
#   18  3  notpresent  yes   no  notpresent      48.0       1.0
#   19  3  notpresent  yes  yes  notpresent       NaN       NaN
#   20  3  notpresent  yes  yes     present       NaN       NaN
#   21  3     present   no  yes  notpresent       NaN       NaN
#   22  3     present   no  yes     present       NaN       NaN
#   23  3     present  yes  yes     present       NaN       NaN
#   24  4  notpresent   no   no  notpresent      72.0       9.0
#   25  4  notpresent   no  yes  notpresent      68.0       3.0
#   26  4  notpresent  yes  yes  notpresent      64.0       1.0
#   27  4  notpresent  yes  yes     present      69.0       1.0
#   28  4     present   no   no  notpresent       NaN       NaN
#   29  4     present   no   no     present       NaN       NaN
#   30  4     present  yes   no  notpresent       NaN       NaN
#   31  4     present  yes  yes  notpresent       NaN       NaN
#   32  4     present  yes  yes     present       NaN       NaN,
#   Empty DataFrame
#   Columns: [cad, al, pe, su, sg, ane, htn, pcc, MAX(bu), COUNT(*)]
#   Index: [],
#      su  htn   dm     sg          ba  MIN(hemo)  COUNT(*)
#   0   0   no   no   1.01  notpresent   9.966591      32.0
#   1   0   no   no   1.01     present        NaN       NaN
#   2   0   no   no  1.015  notpresent   9.989916      17.0
#   3   0   no   no  1.015     present        NaN       NaN
#   4   0   no   no   1.02  notpresent   9.461225      33.0
#   5   0   no   no  1.025  notpresent  10.430671      36.0
#   6   0   no  yes  1.005     present        NaN       NaN
#   7   0   no  yes   1.01  notpresent  12.851942       1.0
#   8   0   no  yes  1.015  notpresent  11.796989       3.0
#   9   0  yes   no  1.005  notpresent  10.007756       1.0
#   10  0  yes   no   1.01  notpresent  12.250794       2.0
#   11  0  yes   no  1.015  notpresent  11.253509       3.0
#   12  0  yes   no   1.02  notpresent   8.326425       5.0
#   13  0  yes   no  1.025  notpresent   9.840666       4.0
#   14  0  yes  yes  1.005  notpresent        NaN       NaN
#   15  0  yes  yes   1.01  notpresent   8.750333       5.0
#   16  0  yes  yes   1.01     present        NaN       NaN
#   17  0  yes  yes  1.015  notpresent   9.667678       3.0
#   18  0  yes  yes   1.02  notpresent   8.299664       9.0
#   19  0  yes  yes  1.025  notpresent   9.628661       8.0
#   20  1   no   no  1.015  notpresent  14.882312       1.0
#   21  1  yes   no   1.01  notpresent        NaN       NaN
#   22  1  yes   no   1.02  notpresent        NaN       NaN
#   23  1  yes  yes   1.01  notpresent        NaN       NaN
#   24  1  yes  yes   1.01     present        NaN       NaN
#   25  1  yes  yes  1.015  notpresent        NaN       NaN
#   26  2   no  yes  1.015  notpresent        NaN       NaN
#   27  2  yes   no   1.01     present        NaN       NaN
#   28  2  yes  yes   1.01  notpresent        NaN       NaN
#   29  2  yes  yes   1.01     present        NaN       NaN
#   30  2  yes  yes  1.015  notpresent  10.142905       1.0
#   31  2  yes  yes  1.015     present        NaN       NaN
#   32  2  yes  yes   1.02  notpresent        NaN       NaN
#   33  3  yes  yes  1.005  notpresent        NaN       NaN
#   34  3  yes  yes   1.01  notpresent  11.029934       1.0
#   35  3  yes  yes   1.01     present        NaN       NaN
#   36  3  yes  yes  1.015  notpresent        NaN       NaN
#   37  3  yes  yes  1.025  notpresent        NaN       NaN
#   38  4  yes  yes   1.01  notpresent        NaN       NaN
#   39  4  yes  yes  1.015  notpresent  10.668446       1.0
#   40  5  yes  yes   1.01     present        NaN       NaN
#   41  5  yes  yes  1.015  notpresent        NaN       NaN,
#     Class  AVG(pcv)  COUNT(*)
#   0   ckd       NaN       NaN,
#         sg         pcc su  htn  MAX(bp)  COUNT(*)
#   0  1.005     present  0  yes      NaN       NaN
#   1   1.02  notpresent  2  yes      NaN       NaN,
#      al         pcc  cad   Class   dm su     sg        pc  SUM(hemo)  COUNT(*)
#   0   0  notpresent   no     ckd   no  0   1.01  abnormal  43.631093         4
#   1   0  notpresent   no     ckd   no  0   1.01    normal  38.033119         3
#   2   0  notpresent   no     ckd   no  0  1.015  abnormal  11.650268         1
#   3   0  notpresent   no     ckd   no  0   1.02  abnormal   8.326425         1
#   4   0  notpresent   no     ckd   no  0   1.02    normal  46.786799         4
#   .. ..         ...  ...     ...  ... ..    ...       ...        ...       ...
#   95  4  notpresent   no  notckd   no  0   1.02    normal  16.256696         1
#   96  4  notpresent   no  notckd   no  0  1.025    normal  42.804612         3
#   97  4  notpresent   no  notckd   no  2   1.01    normal  16.085740         1
#   98  4  notpresent  yes     ckd   no  0  1.025  abnormal  12.403579         1
#   99  4     present   no     ckd  yes  0  1.015    normal   9.890979         1
#
#   [100 rows x 10 columns],
#   Empty DataFrame
#   Columns: [appet, sg, MAX(sod), COUNT(*)]
#   Index: []],
#  'query_params': [{'where_cnt_vars': ['sod'],
#    'where_cat_vars': ['class', 'appet', 'dm'],
#    'where_dt_vars': [],
#    'query_type': 'aggfltr_1',
#    'real_table_name': 'C7',
#    'syn_table_name': 'C7_syn_06',
#    'query_tmplt_idx': 3,
#    'query_cat_vars': ['htn', 'pc', 'class', 'su'],
#    'query_cnt_vars': nan,
#    'query_dt_vars': nan,
#    'query_cnt_var': 'hemo',
#    'query_agg_op': 'MIN',
#    'query_match_vars': ['htn', 'pc', 'class', 'su'],
#    'real_sql': "SELECT htn,pc,class,su,MIN(hemo), COUNT(*) FROM C7  WHERE (class IN ('ckd', 'notckd')  AND  sod <= 146)   OR (appet <> 'good'  OR  dm IN ('no', 'yes'))   GROUP BY htn,pc,class,su",
#    'syn_sql': "SELECT htn,pc,class,su,MIN(hemo), COUNT(*) FROM C7_syn_06  WHERE (class IN ('ckd', 'notckd')  AND  sod <= 146)   OR (appet <> 'good'  OR  dm IN ('no', 'yes'))   GROUP BY htn,pc,class,su",
#    'real_n_rcrds': 16,
#    'syn_n_rcrds': 19},
#   {'where_cnt_vars': ['bgr', 'pot', 'age', 'hemo', 'bp', 'sod', 'sc'],
#    'where_cat_vars': ['sg',
#     'al',
#     'htn',
#     'class',
#     'pcc',
#     'ba',
#     'dm',
#     'su',
#     'pe'],
#    'where_dt_vars': [],
#    'query_type': 'aggfltr_1',
#    'real_table_name': 'C7',
#    'syn_table_name': 'C7_syn_06',
#    'query_tmplt_idx': 9,
#    'query_cat_vars': ['pcc',
#     'cad',
#     'pe',
#     'ane',
#     'dm',
#     'al',
#     'su',
#     'appet',
#     'sg',
#     'ba'],
#    'query_cnt_vars': nan,
#    'query_dt_vars': nan,
#    'query_cnt_var': 'bp',
#    'query_agg_op': 'SUM',
#    'query_match_vars': ['pcc',
#     'cad',
#     'pe',
#     'ane',
#     'dm',
#     'al',
#     'su',
#     'appet',
#     'sg',
#     'ba'],
#    'real_sql': "SELECT pcc,cad,pe,ane,dm,al,su,appet,sg,ba,SUM(bp), COUNT(*) FROM C7  WHERE (sg <> '1.02'  OR  al LIKE '0')   AND (bgr <= 123  AND   pot BETWEEN 4.7 AND 3.7) AND  ((age BETWEEN 25 AND 23) AND htn <> 'no')   OR (class <> 'ckd'  OR  hemo <> 9.8)   AND (pcc <> 'notpresent'  AND  ba = 'notpresent')   OR  ((bp BETWEEN 80 AND 80) OR dm <> 'no')   OR (sod < 140  OR  su = '0')   OR (sc > 0.8  OR  pe = 'no')   GROUP BY pcc,cad,pe,ane,dm,al,su,appet,sg,ba",
#    'syn_sql': "SELECT pcc,cad,pe,ane,dm,al,su,appet,sg,ba,SUM(bp), COUNT(*) FROM C7_syn_06  WHERE (sg <> '1.02'  OR  al LIKE '0')   AND (bgr <= 123  AND   pot BETWEEN 4.7 AND 3.7) AND  ((age BETWEEN 25 AND 23) AND htn <> 'no')   OR (class <> 'ckd'  OR  hemo <> 9.8)   AND (pcc <> 'notpresent'  AND  ba = 'notpresent')   OR  ((bp BETWEEN 80 AND 80) OR dm <> 'no')   OR (sod < 140  OR  su = '0')   OR (sc > 0.8  OR  pe = 'no')   GROUP BY pcc,cad,pe,ane,dm,al,su,appet,sg,ba",
#    'real_n_rcrds': 83,
#    'syn_n_rcrds': 103},
#   {'where_cnt_vars': ['sc', 'sod', 'bgr', 'hemo', 'bp', 'bu', 'age', 'pcv'],
#    'where_cat_vars': ['ane',
#     'dm',
#     'pc',
#     'su',
#     'ba',
#     'class',
#     'htn',
#     'sg',
#     'appet',
#     'pcc',
#     'cad',
#     'al'],
#    'where_dt_vars': [],
#    'query_type': 'aggfltr_1',
#    'real_table_name': 'C7',
#    'syn_table_name': 'C7_syn_06',
#    'query_tmplt_idx': 1,
#    'query_cat_vars': ['pe', 'appet'],
#    'query_cnt_vars': nan,
#    'query_dt_vars': nan,
#    'query_cnt_var': 'pcv',
#    'query_agg_op': 'SUM',
#    'query_match_vars': ['pe', 'appet'],
#    'real_sql': "SELECT pe,appet,SUM(pcv), COUNT(*) FROM C7  WHERE (ane LIKE 'no'  AND   sc BETWEEN 1.0 AND 0.9) AND (dm LIKE 'no'  AND  sod > 145)   AND (bgr > 76  AND  pc <> 'normal')   AND (su IN ('0', '2', '3', '5', '4')  AND  ba = 'notpresent')   OR (class IN ('ckd', 'notckd')  OR  hemo >= 14.5)   AND (htn <> 'no'  AND  sg = '1.02')   AND  ((bp BETWEEN 70 AND 80) AND bu <> 30.0)   OR (appet <> 'good'  OR  pcc IN ('notpresent', 'present'))   AND (cad <> 'yes'  AND  age <> 63)   OR (pcv <= 41  OR  al LIKE '0')   GROUP BY pe,appet",
#    'syn_sql': "SELECT pe,appet,SUM(pcv), COUNT(*) FROM C7_syn_06  WHERE (ane LIKE 'no'  AND   sc BETWEEN 1.0 AND 0.9) AND (dm LIKE 'no'  AND  sod > 145)   AND (bgr > 76  AND  pc <> 'normal')   AND (su IN ('0', '2', '3', '5', '4')  AND  ba = 'notpresent')   OR (class IN ('ckd', 'notckd')  OR  hemo >= 14.5)   AND (htn <> 'no'  AND  sg = '1.02')   AND  ((bp BETWEEN 70 AND 80) AND bu <> 30.0)   OR (appet <> 'good'  OR  pcc IN ('notpresent', 'present'))   AND (cad <> 'yes'  AND  age <> 63)   OR (pcv <= 41  OR  al LIKE '0')   GROUP BY pe,appet",
#    'real_n_rcrds': 4,
#    'syn_n_rcrds': 4},
#   {'where_cnt_vars': ['pot',
#     'sc',
#     'hemo',
#     'bu',
#     'bp',
#     'pcv',
#     'age',
#     'bgr',
#     'sod'],
#    'where_cat_vars': ['dm',
#     'su',
#     'ane',
#     'pc',
#     'al',
#     'pe',
#     'pcc',
#     'sg',
#     'htn',
#     'class',
#     'cad'],
#    'where_dt_vars': [],
#    'query_type': 'aggfltr_1',
#    'real_table_name': 'C7',
#    'syn_table_name': 'C7_syn_06',
#    'query_tmplt_idx': 4,
#    'query_cat_vars': ['al', 'ba', 'pe', 'htn', 'pcc'],
#    'query_cnt_vars': nan,
#    'query_dt_vars': nan,
#    'query_cnt_var': 'age',
#    'query_agg_op': 'MAX',
#    'query_match_vars': ['al', 'ba', 'pe', 'htn', 'pcc'],
#    'real_sql': "SELECT al,ba,pe,htn,pcc,MAX(age), COUNT(*) FROM C7  WHERE (pot > 4.1  OR  dm <> 'no')   OR (sc = 1.6  OR  hemo > 12.5)   AND  ((bu BETWEEN 25.0 AND 48.0) AND su = '1')   AND (bp = 80  AND  ane IN ('yes', 'no'))   OR (pc = 'normal'  OR  al = '0')   OR (pe = 'no'  OR   pcv BETWEEN 31 AND 32) OR  ((age BETWEEN 58 AND 69) OR pcc LIKE 'notpresent')   OR (bgr >= 130  OR  sg <> '1.025')   AND (htn LIKE 'no'  AND  sod >= 135)   OR (class = 'ckd'  OR  cad <> 'no')   GROUP BY al,ba,pe,htn,pcc",
#    'syn_sql': "SELECT al,ba,pe,htn,pcc,MAX(age), COUNT(*) FROM C7_syn_06  WHERE (pot > 4.1  OR  dm <> 'no')   OR (sc = 1.6  OR  hemo > 12.5)   AND  ((bu BETWEEN 25.0 AND 48.0) AND su = '1')   AND (bp = 80  AND  ane IN ('yes', 'no'))   OR (pc = 'normal'  OR  al = '0')   OR (pe = 'no'  OR   pcv BETWEEN 31 AND 32) OR  ((age BETWEEN 58 AND 69) OR pcc LIKE 'notpresent')   OR (bgr >= 130  OR  sg <> '1.025')   AND (htn LIKE 'no'  AND  sod >= 135)   OR (class = 'ckd'  OR  cad <> 'no')   GROUP BY al,ba,pe,htn,pcc",
#    'real_n_rcrds': 33,
#    'syn_n_rcrds': 29},
#   {'where_cnt_vars': ['hemo', 'pot'],
#    'where_cat_vars': ['ane', 'htn', 'su'],
#    'where_dt_vars': [],
#    'query_type': 'aggfltr_1',
#    'real_table_name': 'C7',
#    'syn_table_name': 'C7_syn_06',
#    'query_tmplt_idx': 7,
#    'query_cat_vars': ['cad', 'al', 'pe', 'su', 'sg', 'ane', 'htn', 'pcc'],
#    'query_cnt_vars': nan,
#    'query_dt_vars': nan,
#    'query_cnt_var': 'bu',
#    'query_agg_op': 'MAX',
#    'query_match_vars': ['cad', 'al', 'pe', 'su', 'sg', 'ane', 'htn', 'pcc'],
#    'real_sql': "SELECT cad,al,pe,su,sg,ane,htn,pcc,MAX(bu), COUNT(*) FROM C7 WHERE (ane <> 'no')  AND (hemo >= 14.5  AND  htn LIKE 'yes')   AND  ((pot BETWEEN 4.2 AND 5.5) AND su IN ('2', '5', '4'))   GROUP BY cad,al,pe,su,sg,ane,htn,pcc",
#    'syn_sql': "SELECT cad,al,pe,su,sg,ane,htn,pcc,MAX(bu), COUNT(*) FROM C7_syn_06 WHERE (ane <> 'no')  AND (hemo >= 14.5  AND  htn LIKE 'yes')   AND  ((pot BETWEEN 4.2 AND 5.5) AND su IN ('2', '5', '4'))   GROUP BY cad,al,pe,su,sg,ane,htn,pcc",
#    'real_n_rcrds': 0,
#    'syn_n_rcrds': 0},
#   {'where_cnt_vars': ['sc', 'hemo', 'bp', 'pcv', 'age'],
#    'where_cat_vars': ['su', 'pcc', 'cad', 'ba', 'pc', 'htn', 'pe'],
#    'where_dt_vars': [],
#    'query_type': 'aggfltr_1',
#    'real_table_name': 'C7',
#    'syn_table_name': 'C7_syn_06',
#    'query_tmplt_idx': 4,
#    'query_cat_vars': ['su', 'htn', 'dm', 'sg', 'ba'],
#    'query_cnt_vars': nan,
#    'query_dt_vars': nan,
#    'query_cnt_var': 'hemo',
#    'query_agg_op': 'MIN',
#    'query_match_vars': ['su', 'htn', 'dm', 'sg', 'ba'],
#    'real_sql': "SELECT su,htn,dm,sg,ba,MIN(hemo), COUNT(*) FROM C7  WHERE (sc = 0.7  OR  su <> '0')   AND  ((hemo BETWEEN 9.5 AND 16.5) AND pcc IN ('notpresent', 'present'))   OR (cad = 'no'  OR  bp = 60)   AND (ba <> 'notpresent'  AND   pcv BETWEEN 50 AND 52) OR (pc <> 'normal'  OR  htn IN ('yes', 'no'))   OR (pe IN ('yes', 'no')  OR   age BETWEEN 68 AND 6) GROUP BY su,htn,dm,sg,ba",
#    'syn_sql': "SELECT su,htn,dm,sg,ba,MIN(hemo), COUNT(*) FROM C7_syn_06  WHERE (sc = 0.7  OR  su <> '0')   AND  ((hemo BETWEEN 9.5 AND 16.5) AND pcc IN ('notpresent', 'present'))   OR (cad = 'no'  OR  bp = 60)   AND (ba <> 'notpresent'  AND   pcv BETWEEN 50 AND 52) OR (pc <> 'normal'  OR  htn IN ('yes', 'no'))   OR (pe IN ('yes', 'no')  OR   age BETWEEN 68 AND 6) GROUP BY su,htn,dm,sg,ba",
#    'real_n_rcrds': 42,
#    'syn_n_rcrds': 41},
#   {'where_cnt_vars': ['pcv', 'bp'],
#    'where_cat_vars': ['pe'],
#    'where_dt_vars': [],
#    'query_type': 'aggfltr_1',
#    'real_table_name': 'C7',
#    'syn_table_name': 'C7_syn_06',
#    'query_tmplt_idx': 0,
#    'query_cat_vars': ['class'],
#    'query_cnt_vars': nan,
#    'query_dt_vars': nan,
#    'query_cnt_var': 'pcv',
#    'query_agg_op': 'AVG',
#    'query_match_vars': ['class'],
#    'real_sql': "SELECT class,AVG(pcv), COUNT(*) FROM C7 WHERE (pe IN ('no', 'yes'))  AND (pcv = 34  AND   bp BETWEEN 60 AND 80) GROUP BY class",
#    'syn_sql': "SELECT class,AVG(pcv), COUNT(*) FROM C7_syn_06 WHERE (pe IN ('no', 'yes'))  AND (pcv = 34  AND   bp BETWEEN 60 AND 80) GROUP BY class",
#    'real_n_rcrds': 1,
#    'syn_n_rcrds': 0},
#   {'where_cnt_vars': ['hemo'],
#    'where_cat_vars': ['class'],
#    'where_dt_vars': [],
#    'query_type': 'aggfltr_1',
#    'real_table_name': 'C7',
#    'syn_table_name': 'C7_syn_06',
#    'query_tmplt_idx': 3,
#    'query_cat_vars': ['sg', 'pcc', 'su', 'htn'],
#    'query_cnt_vars': nan,
#    'query_dt_vars': nan,
#    'query_cnt_var': 'bp',
#    'query_agg_op': 'MAX',
#    'query_match_vars': ['sg', 'pcc', 'su', 'htn'],
#    'real_sql': "SELECT sg,pcc,su,htn,MAX(bp), COUNT(*) FROM C7  WHERE (class = 'ckd'  AND  hemo = 11.2)   GROUP BY sg,pcc,su,htn",
#    'syn_sql': "SELECT sg,pcc,su,htn,MAX(bp), COUNT(*) FROM C7_syn_06  WHERE (class = 'ckd'  AND  hemo = 11.2)   GROUP BY sg,pcc,su,htn",
#    'real_n_rcrds': 2,
#    'syn_n_rcrds': 0},
#   {'where_cnt_vars': ['pot', 'bgr', 'sc', 'pcv', 'bp', 'bu'],
#    'where_cat_vars': ['ane',
#     'sg',
#     'class',
#     'su',
#     'pc',
#     'pcc',
#     'ba',
#     'cad',
#     'pe',
#     'dm'],
#    'where_dt_vars': [],
#    'query_type': 'aggfltr_1',
#    'real_table_name': 'C7',
#    'syn_table_name': 'C7_syn_06',
#    'query_tmplt_idx': 7,
#    'query_cat_vars': ['al', 'pcc', 'cad', 'class', 'dm', 'su', 'sg', 'pc'],
#    'query_cnt_vars': nan,
#    'query_dt_vars': nan,
#    'query_cnt_var': 'hemo',
#    'query_agg_op': 'SUM',
#    'query_match_vars': ['al', 'pcc', 'cad', 'class', 'dm', 'su', 'sg', 'pc'],
#    'real_sql': "SELECT al,pcc,cad,class,dm,su,sg,pc,SUM(hemo), COUNT(*) FROM C7  WHERE (ane IN ('yes', 'no')  AND  sg <> '1.025')   AND (class <> 'ckd'  AND  pot > 4.9)   AND (su = '3'  AND  pc LIKE 'normal')   AND (bgr <= 132  AND   sc BETWEEN 0.8 AND 1.2) AND (pcc <> 'present'  AND  ba = 'notpresent')   OR (cad IN ('no', 'yes')  OR  pcv <> 28)   OR (bp = 80  OR  pe LIKE 'no')   AND (dm LIKE 'no'  AND   bu BETWEEN 47.0 AND 25.0) GROUP BY al,pcc,cad,class,dm,su,sg,pc",
#    'syn_sql': "SELECT al,pcc,cad,class,dm,su,sg,pc,SUM(hemo), COUNT(*) FROM C7_syn_06  WHERE (ane IN ('yes', 'no')  AND  sg <> '1.025')   AND (class <> 'ckd'  AND  pot > 4.9)   AND (su = '3'  AND  pc LIKE 'normal')   AND (bgr <= 132  AND   sc BETWEEN 0.8 AND 1.2) AND (pcc <> 'present'  AND  ba = 'notpresent')   OR (cad IN ('no', 'yes')  OR  pcv <> 28)   OR (bp = 80  OR  pe LIKE 'no')   AND (dm LIKE 'no'  AND   bu BETWEEN 47.0 AND 25.0) GROUP BY al,pcc,cad,class,dm,su,sg,pc",
#    'real_n_rcrds': 77,
#    'syn_n_rcrds': 100},
#   {'where_cnt_vars': ['pot', 'bp', 'bu', 'sc', 'bgr'],
#    'where_cat_vars': ['sg', 'ane', 'dm'],
#    'where_dt_vars': [],
#    'query_type': 'aggfltr_1',
#    'real_table_name': 'C7',
#    'syn_table_name': 'C7_syn_06',
#    'query_tmplt_idx': 1,
#    'query_cat_vars': ['appet', 'sg'],
#    'query_cnt_vars': nan,
#    'query_dt_vars': nan,
#    'query_cnt_var': 'sod',
#    'query_agg_op': 'MAX',
#    'query_match_vars': ['appet', 'sg'],
#    'real_sql': "SELECT appet,sg,MAX(sod), COUNT(*) FROM C7  WHERE  ((pot BETWEEN 3.8 AND 4.2) OR sg LIKE '1.02')   AND (ane <> 'yes'  AND   bp BETWEEN 70 AND 80) AND (bu >= 235.0  AND  dm LIKE 'yes')   AND (sc > 14.2  AND   bgr BETWEEN 100 AND 118) GROUP BY appet,sg",
#    'syn_sql': "SELECT appet,sg,MAX(sod), COUNT(*) FROM C7_syn_06  WHERE  ((pot BETWEEN 3.8 AND 4.2) OR sg LIKE '1.02')   AND (ane <> 'yes'  AND   bp BETWEEN 70 AND 80) AND (bu >= 235.0  AND  dm LIKE 'yes')   AND (sc > 14.2  AND   bgr BETWEEN 100 AND 118) GROUP BY appet,sg",
#    'real_n_rcrds': 0,
#    'syn_n_rcrds': 0}],
#  'hlngr_dist': [0.15358896033772754,
#   0.35057788376388305,
#   0.11457348082539362,
#   0.21849760406052376,
#   nan,
#   0.31558678036383186,
#   nan,
#   nan,
#   0.24032773303456914,
#   nan],
#  'ecldn_dist': [0.3162277660168379,
#   0.2773500981126146,
#   0.49999999999999994,
#   0.2581988897471611,
#   nan,
#   0.22941573387056174,
#   nan,
#   nan,
#   0.316227766016838,
#   nan]}
