# %%
from config_paths import *
import sys
sys.path.append(str(SRC_DIR))

from fuzzy_sql.fuzzy_sql import *
import json
import os
from pathlib import Path

DATASET_NAME='sdgd'
import glob

# %%
# set directories
metadata_dir = os.path.join(DATA_DIR, DATASET_NAME,'processed/metadata')
real_dir = os.path.join(DATA_DIR,DATASET_NAME, 'processed/real')
syn_dir = os.path.join(DATA_DIR,DATASET_NAME, 'processed/synthetic')
db_path = os.path.join(DB_DIR, f'{DATASET_NAME}.db')

# %%
# poplulate filenames from folder into a list
real_fnames=glob.glob(real_dir+'/*.csv')
real_fnames=[Path(real_fname).stem for real_fname in real_fnames]
real_fnames.sort()


# generate filenames
meta_jsons=[]
real_csvs=[]
for real_fname in real_fnames:
    meta_jsons.append(real_fname+'.json')
    real_csvs.append(real_fname+'.csv')

# %%
# import real data into database
conn = sqlite3.connect(db_path)
with conn:
    for real_csv,meta_json in zip(real_csvs,meta_jsons):
        #Import real
        data,_=prep_data_for_db(os.path.join(real_dir,real_csv)) # Note: This function  can be used to quickly generate metadata template, but this is not shown here.
        with open(os.path.join(metadata_dir, meta_json), 'r') as f:
            metadata=json.load(f)
        print(f"Processing {real_csv} and {meta_json} ")
        candidate_db_idx=get_vars_to_index(metadata,data)
        table_name=Path(real_csv).stem
        make_table(table_name, data, conn,indx_vars=candidate_db_idx)
# Out:
# Processing C1.csv and C1.json
# Table C1 already exists in the database
# Processing C10.csv and C10.json
# Table C10 is created in the database
# .... The index: IDX_C10_hsv_total_h_std is created for the table: C10 in the database
# .... The index: IDX_C10_cervix_specularities_area is created for the table: C10 in the database
# .... The index: IDX_C10_hsv_cervix_s_std is created for the table: C10 in the database
# .... The index: IDX_C10_hsv_total_h_mean is created for the table: C10 in the database
# .... The index: IDX_C10_fit_ellipse_total is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_cervix_r_mean is created for the table: C10 in the database
# .... The index: IDX_C10_fit_cervix_bbox_rate is created for the table: C10 in the database
# .... The index: IDX_C10_cervix_area is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_cervix_b_mean is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_total_b_mean_minus_std is created for the table: C10 in the database
# .... The index: IDX_C10_hsv_cervix_v_mean is created for the table: C10 in the database
# .... The index: IDX_C10_hsv_total_v_std is created for the table: C10 in the database
# .... The index: IDX_C10_fit_circle_rate is created for the table: C10 in the database
# .... The index: IDX_C10_fit_cervix_hull_rate is created for the table: C10 in the database
# .... The index: IDX_C10_speculum_specularities_area is created for the table: C10 in the database
# .... The index: IDX_C10_walls_specularities_area is created for the table: C10 in the database
# .... The index: IDX_C10_fit_circle_total is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_total_b_mean is created for the table: C10 in the database
# .... The index: IDX_C10_hsv_total_s_mean is created for the table: C10 in the database
# .... The index: IDX_C10_speculum_area is created for the table: C10 in the database
# .... The index: IDX_C10_dist_to_center_cervix is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_cervix_b_mean_plus_std is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_cervix_g_mean_plus_std is created for the table: C10 in the database
# .... The index: IDX_C10_dist_to_center_os is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_total_g_mean_plus_std is created for the table: C10 in the database
# .... The index: IDX_C10_os_artifacts_area is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_cervix_b_mean_minus_std is created for the table: C10 in the database
# .... The index: IDX_C10_hsv_cervix_v_std is created for the table: C10 in the database
# .... The index: IDX_C10_artifacts_area is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_total_g_mean_minus_std is created for the table: C10 in the database
# .... The index: IDX_C10_speculum_artifacts_area is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_cervix_g_std is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_total_g_mean is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_cervix_r_mean_plus_std is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_total_r_mean_plus_std is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_total_b_std is created for the table: C10 in the database
# .... The index: IDX_C10_fit_cervix_bbox_total is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_total_g_std is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_cervix_g_mean is created for the table: C10 in the database
# .... The index: IDX_C10_consensus is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_total_r_mean_minus_std is created for the table: C10 in the database
# .... The index: IDX_C10_hsv_cervix_h_mean is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_total_r_mean is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_total_b_mean_plus_std is created for the table: C10 in the database
# .... The index: IDX_C10_specularities_area is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_cervix_r_std is created for the table: C10 in the database
# .... The index: IDX_C10_os_specularities_area is created for the table: C10 in the database
# .... The index: IDX_C10_hsv_cervix_h_std is created for the table: C10 in the database
# .... The index: IDX_C10_fit_ellipse_goodness is created for the table: C10 in the database
# .... The index: IDX_C10_hsv_cervix_s_mean is created for the table: C10 in the database
# .... The index: IDX_C10_area_h_max_diff is created for the table: C10 in the database
# .... The index: IDX_C10_walls_area is created for the table: C10 in the database
# .... The index: IDX_C10_os_area is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_cervix_b_std is created for the table: C10 in the database
# .... The index: IDX_C10_cervix_artifacts_area is created for the table: C10 in the database
# .... The index: IDX_C10_hsv_total_v_mean is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_cervix_r_mean_minus_std is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_total_r_std is created for the table: C10 in the database
# .... The index: IDX_C10_rgb_cervix_g_mean_minus_std is created for the table: C10 in the database
# .... The index: IDX_C10_walls_artifacts_area is created for the table: C10 in the database
# .... The index: IDX_C10_fit_cervix_hull_total is created for the table: C10 in the database
# .... The index: IDX_C10_hsv_total_s_std is created for the table: C10 in the database
# .... The index: IDX_C10_fit_ellipse_rate is created for the table: C10 in the database
# Processing C11.csv and C11.json
# Table C11 is created in the database
# .... The index: IDX_C11_hsv_total_h_std is created for the table: C11 in the database
# .... The index: IDX_C11_cervix_specularities_area is created for the table: C11 in the database
# .... The index: IDX_C11_hsv_cervix_s_std is created for the table: C11 in the database
# .... The index: IDX_C11_hsv_total_h_mean is created for the table: C11 in the database
# .... The index: IDX_C11_fit_ellipse_total is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_cervix_r_mean is created for the table: C11 in the database
# .... The index: IDX_C11_fit_cervix_bbox_rate is created for the table: C11 in the database
# .... The index: IDX_C11_cervix_area is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_cervix_b_mean is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_total_b_mean_minus_std is created for the table: C11 in the database
# .... The index: IDX_C11_hsv_cervix_v_mean is created for the table: C11 in the database
# .... The index: IDX_C11_hsv_total_v_std is created for the table: C11 in the database
# .... The index: IDX_C11_fit_circle_rate is created for the table: C11 in the database
# .... The index: IDX_C11_fit_cervix_hull_rate is created for the table: C11 in the database
# .... The index: IDX_C11_speculum_specularities_area is created for the table: C11 in the database
# .... The index: IDX_C11_walls_specularities_area is created for the table: C11 in the database
# .... The index: IDX_C11_fit_circle_total is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_total_b_mean is created for the table: C11 in the database
# .... The index: IDX_C11_hsv_total_s_mean is created for the table: C11 in the database
# .... The index: IDX_C11_speculum_area is created for the table: C11 in the database
# .... The index: IDX_C11_dist_to_center_cervix is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_cervix_b_mean_plus_std is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_cervix_g_mean_plus_std is created for the table: C11 in the database
# .... The index: IDX_C11_dist_to_center_os is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_total_g_mean_plus_std is created for the table: C11 in the database
# .... The index: IDX_C11_os_artifacts_area is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_cervix_b_mean_minus_std is created for the table: C11 in the database
# .... The index: IDX_C11_hsv_cervix_v_std is created for the table: C11 in the database
# .... The index: IDX_C11_artifacts_area is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_total_g_mean_minus_std is created for the table: C11 in the database
# .... The index: IDX_C11_speculum_artifacts_area is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_cervix_g_std is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_total_g_mean is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_cervix_r_mean_plus_std is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_total_r_mean_plus_std is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_total_b_std is created for the table: C11 in the database
# .... The index: IDX_C11_fit_cervix_bbox_total is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_total_g_std is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_cervix_g_mean is created for the table: C11 in the database
# .... The index: IDX_C11_consensus is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_total_r_mean_minus_std is created for the table: C11 in the database
# .... The index: IDX_C11_hsv_cervix_h_mean is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_total_r_mean is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_total_b_mean_plus_std is created for the table: C11 in the database
# .... The index: IDX_C11_specularities_area is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_cervix_r_std is created for the table: C11 in the database
# .... The index: IDX_C11_os_specularities_area is created for the table: C11 in the database
# .... The index: IDX_C11_hsv_cervix_h_std is created for the table: C11 in the database
# .... The index: IDX_C11_fit_ellipse_goodness is created for the table: C11 in the database
# .... The index: IDX_C11_hsv_cervix_s_mean is created for the table: C11 in the database
# .... The index: IDX_C11_area_h_max_diff is created for the table: C11 in the database
# .... The index: IDX_C11_walls_area is created for the table: C11 in the database
# .... The index: IDX_C11_os_area is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_cervix_b_std is created for the table: C11 in the database
# .... The index: IDX_C11_cervix_artifacts_area is created for the table: C11 in the database
# .... The index: IDX_C11_hsv_total_v_mean is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_cervix_r_mean_minus_std is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_total_r_std is created for the table: C11 in the database
# .... The index: IDX_C11_rgb_cervix_g_mean_minus_std is created for the table: C11 in the database
# .... The index: IDX_C11_walls_artifacts_area is created for the table: C11 in the database
# .... The index: IDX_C11_fit_cervix_hull_total is created for the table: C11 in the database
# .... The index: IDX_C11_hsv_total_s_std is created for the table: C11 in the database
# .... The index: IDX_C11_fit_ellipse_rate is created for the table: C11 in the database
# Processing C12.csv and C12.json
# Table C12 is created in the database
# .... The index: IDX_C12_MLTV is created for the table: C12 in the database
# .... The index: IDX_C12_DP is created for the table: C12 in the database
# .... The index: IDX_C12_Tendency is created for the table: C12 in the database
# .... The index: IDX_C12_DL is created for the table: C12 in the database
# .... The index: IDX_C12_Mean is created for the table: C12 in the database
# .... The index: IDX_C12_Nmax is created for the table: C12 in the database
# .... The index: IDX_C12_Min is created for the table: C12 in the database
# .... The index: IDX_C12_Width is created for the table: C12 in the database
# .... The index: IDX_C12_AC is created for the table: C12 in the database
# .... The index: IDX_C12_Median is created for the table: C12 in the database
# .... The index: IDX_C12_ALTV is created for the table: C12 in the database
# .... The index: IDX_C12_MSTV is created for the table: C12 in the database
# .... The index: IDX_C12_Variance is created for the table: C12 in the database
# .... The index: IDX_C12_UC is created for the table: C12 in the database
# .... The index: IDX_C12_NSP is created for the table: C12 in the database
# .... The index: IDX_C12_LB is created for the table: C12 in the database
# .... The index: IDX_C12_Mode is created for the table: C12 in the database
# .... The index: IDX_C12_FM is created for the table: C12 in the database
# .... The index: IDX_C12_DS is created for the table: C12 in the database
# .... The index: IDX_C12_Max is created for the table: C12 in the database
# .... The index: IDX_C12_Nzeros is created for the table: C12 in the database
# .... The index: IDX_C12_ASTV is created for the table: C12 in the database
# Processing C13.csv and C13.json
# Table C13 is created in the database
# .... The index: IDX_C13_MLTV is created for the table: C13 in the database
# .... The index: IDX_C13_DP is created for the table: C13 in the database
# .... The index: IDX_C13_Tendency is created for the table: C13 in the database
# .... The index: IDX_C13_DL is created for the table: C13 in the database
# .... The index: IDX_C13_Class is created for the table: C13 in the database
# .... The index: IDX_C13_Mean is created for the table: C13 in the database
# .... The index: IDX_C13_Nmax is created for the table: C13 in the database
# .... The index: IDX_C13_Min is created for the table: C13 in the database
# .... The index: IDX_C13_Width is created for the table: C13 in the database
# .... The index: IDX_C13_AC is created for the table: C13 in the database
# .... The index: IDX_C13_Median is created for the table: C13 in the database
# .... The index: IDX_C13_ALTV is created for the table: C13 in the database
# .... The index: IDX_C13_MSTV is created for the table: C13 in the database
# .... The index: IDX_C13_Variance is created for the table: C13 in the database
# .... The index: IDX_C13_UC is created for the table: C13 in the database
# .... The index: IDX_C13_LB is created for the table: C13 in the database
# .... The index: IDX_C13_Mode is created for the table: C13 in the database
# .... The index: IDX_C13_FM is created for the table: C13 in the database
# .... The index: IDX_C13_DS is created for the table: C13 in the database
# .... The index: IDX_C13_Max is created for the table: C13 in the database
# .... The index: IDX_C13_Nzeros is created for the table: C13 in the database
# .... The index: IDX_C13_ASTV is created for the table: C13 in the database
# Processing C14.csv and C14.json
# Table C14 is created in the database
# .... The index: IDX_C14_spongiosis is created for the table: C14 in the database
# .... The index: IDX_C14_knee_elbow_involvement is created for the table: C14 in the database
# .... The index: IDX_C14_Class is created for the table: C14 in the database
# .... The index: IDX_C14_perifollicular_parakeratosis is created for the table: C14 in the database
# .... The index: IDX_C14_polygonal_papules is created for the table: C14 in the database
# .... The index: IDX_C14_scaling is created for the table: C14 in the database
# .... The index: IDX_C14_sawtooth_retes is created for the table: C14 in the database
# .... The index: IDX_C14_vacuolisation_damage_basal_layer is created for the table: C14 in the database
# .... The index: IDX_C14_family_history is created for the table: C14 in the database
# .... The index: IDX_C14_disappearance_granular_layer is created for the table: C14 in the database
# .... The index: IDX_C14_bandlike_infiltrate is created for the table: C14 in the database
# .... The index: IDX_C14_parakeratosis is created for the table: C14 in the database
# .... The index: IDX_C14_inflammatory_monoluclear_inflitrate is created for the table: C14 in the database
# .... The index: IDX_C14_elongation_rete_ridges is created for the table: C14 in the database
# .... The index: IDX_C14_exocytosis is created for the table: C14 in the database
# .... The index: IDX_C14_PNL_infiltrate is created for the table: C14 in the database
# .... The index: IDX_C14_definite_borders is created for the table: C14 in the database
# .... The index: IDX_C14_follicular_papules is created for the table: C14 in the database
# .... The index: IDX_C14_follicular_horn_plug is created for the table: C14 in the database
# .... The index: IDX_C14_Age is created for the table: C14 in the database
# .... The index: IDX_C14_spongiform_pustule is created for the table: C14 in the database
# .... The index: IDX_C14_eosinophils_infiltrate is created for the table: C14 in the database
# .... The index: IDX_C14_erythema is created for the table: C14 in the database
# .... The index: IDX_C14_melanin_incontinence is created for the table: C14 in the database
# .... The index: IDX_C14_hyperkeratosis is created for the table: C14 in the database
# .... The index: IDX_C14_thinning_suprapapillary_epidermis is created for the table: C14 in the database
# .... The index: IDX_C14_koebner_phenomenon is created for the table: C14 in the database
# .... The index: IDX_C14_itching is created for the table: C14 in the database
# .... The index: IDX_C14_acanthosis is created for the table: C14 in the database
# .... The index: IDX_C14_oral_mucosal_involvement is created for the table: C14 in the database
# .... The index: IDX_C14_fibrosis_papillary_dermis is created for the table: C14 in the database
# .... The index: IDX_C14_munro_microabcess is created for the table: C14 in the database
# .... The index: IDX_C14_scalp_involvement is created for the table: C14 in the database
# .... The index: IDX_C14_clubbing_rete_ridges is created for the table: C14 in the database
# .... The index: IDX_C14_focal_hypergranulosis is created for the table: C14 in the database
# Processing C15.csv and C15.json
# Table C15 is created in the database
# .... The index: IDX_C15_OCP is created for the table: C15 in the database
# .... The index: IDX_C15_FTG_2 is created for the table: C15 in the database
# .... The index: IDX_C15_STP is created for the table: C15 in the database
# .... The index: IDX_C15_LHN is created for the table: C15 in the database
# .... The index: IDX_C15_DBP is created for the table: C15 in the database
# .... The index: IDX_C15_RIH is created for the table: C15 in the database
# .... The index: IDX_C15_IIU is created for the table: C15 in the database
# .... The index: IDX_C15_WKN is created for the table: C15 in the database
# .... The index: IDX_C15_BWR is created for the table: C15 in the database
# .... The index: IDX_C15_SFS is created for the table: C15 in the database
# .... The index: IDX_C15_SWT is created for the table: C15 in the database
# .... The index: IDX_C15_DRN is created for the table: C15 in the database
# .... The index: IDX_C15_DIS is created for the table: C15 in the database
# .... The index: IDX_C15_SBF is created for the table: C15 in the database
# .... The index: IDX_C15_RIG is created for the table: C15 in the database
# .... The index: IDX_C15_LCR is created for the table: C15 in the database
# .... The index: IDX_C15_FTG_5 is created for the table: C15 in the database
# .... The index: IDX_C15_HDC is created for the table: C15 in the database
# .... The index: IDX_C15_TRM is created for the table: C15 in the database
# .... The index: IDX_C15_LHV is created for the table: C15 in the database
# .... The index: IDX_C15_WTG is created for the table: C15 in the database
# .... The index: IDX_C15_SFH is created for the table: C15 in the database
# .... The index: IDX_C15_FHB is created for the table: C15 in the database
# .... The index: IDX_C15_VDS is created for the table: C15 in the database
# .... The index: IDX_C15_DLB is created for the table: C15 in the database
# .... The index: IDX_C15_DRV is created for the table: C15 in the database
# .... The index: IDX_C15_FRU is created for the table: C15 in the database
# .... The index: IDX_C15_EXT is created for the table: C15 in the database
# .... The index: IDX_C15_NSA_2 is created for the table: C15 in the database
# .... The index: IDX_C15_GSV is created for the table: C15 in the database
# .... The index: IDX_C15_LOE is created for the table: C15 in the database
# .... The index: IDX_C15_SWG is created for the table: C15 in the database
# .... The index: IDX_C15_SEX is created for the table: C15 in the database
# .... The index: IDX_C15_FTG_4 is created for the table: C15 in the database
# .... The index: IDX_C15_WTL is created for the table: C15 in the database
# .... The index: IDX_C15_HNG is created for the table: C15 in the database
# .... The index: IDX_C15_EYP is created for the table: C15 in the database
# .... The index: IDX_C15_WLG is created for the table: C15 in the database
# .... The index: IDX_C15_SAD is created for the table: C15 in the database
# .... The index: IDX_C15_TYPE is created for the table: C15 in the database
# .... The index: IDX_C15_IRT_2 is created for the table: C15 in the database
# .... The index: IDX_C15_CDC is created for the table: C15 in the database
# .... The index: IDX_C15_NRV_2 is created for the table: C15 in the database
# .... The index: IDX_C15_SLS is created for the table: C15 in the database
# .... The index: IDX_C15_BMI is created for the table: C15 in the database
# .... The index: IDX_C15_SOB_2 is created for the table: C15 in the database
# .... The index: IDX_C15_SOB is created for the table: C15 in the database
# .... The index: IDX_C15_DRB is created for the table: C15 in the database
# .... The index: IDX_C15_LOA_2 is created for the table: C15 in the database
# .... The index: IDX_C15_AGE is created for the table: C15 in the database
# .... The index: IDX_C15_PRE is created for the table: C15 in the database
# .... The index: IDX_C15_NSA_3 is created for the table: C15 in the database
# .... The index: IDX_C15_CFS_3 is created for the table: C15 in the database
# .... The index: IDX_C15_MST is created for the table: C15 in the database
# .... The index: IDX_C15_EXT_2 is created for the table: C15 in the database
# .... The index: IDX_C15_NRV is created for the table: C15 in the database
# .... The index: IDX_C15_EXP is created for the table: C15 in the database
# .... The index: IDX_C15_ETN is created for the table: C15 in the database
# .... The index: IDX_C15_DSV is created for the table: C15 in the database
# .... The index: IDX_C15_FRO is created for the table: C15 in the database
# .... The index: IDX_C15_PCJ is created for the table: C15 in the database
# .... The index: IDX_C15_WKN_2 is created for the table: C15 in the database
# .... The index: IDX_C15_RPP is created for the table: C15 in the database
# .... The index: IDX_C15_WKN_3 is created for the table: C15 in the database
# .... The index: IDX_C15_SCE is created for the table: C15 in the database
# .... The index: IDX_C15_DRN_2 is created for the table: C15 in the database
# .... The index: IDX_C15_PPT is created for the table: C15 in the database
# .... The index: IDX_C15_PLH is created for the table: C15 in the database
# .... The index: IDX_C15_DIT is created for the table: C15 in the database
# .... The index: IDX_C15_WGT is created for the table: C15 in the database
# .... The index: IDX_C15_IRT is created for the table: C15 in the database
# .... The index: IDX_C15_FLS is created for the table: C15 in the database
# .... The index: IDX_C15_CFS is created for the table: C15 in the database
# .... The index: IDX_C15_DZN is created for the table: C15 in the database
# .... The index: IDX_C15_CSS is created for the table: C15 in the database
# .... The index: IDX_C15_VMT is created for the table: C15 in the database
# .... The index: IDX_C15_LOA is created for the table: C15 in the database
# .... The index: IDX_C15_WTL_2 is created for the table: C15 in the database
# .... The index: IDX_C15_RSB is created for the table: C15 in the database
# .... The index: IDX_C15_GLU is created for the table: C15 in the database
# .... The index: IDX_C15_NSA is created for the table: C15 in the database
# .... The index: IDX_C15_HIT is created for the table: C15 in the database
# .... The index: IDX_C15_CCS is created for the table: C15 in the database
# .... The index: IDX_C15_CVS is created for the table: C15 in the database
# .... The index: IDX_C15_CFS_2 is created for the table: C15 in the database
# .... The index: IDX_C15_FAW is created for the table: C15 in the database
# .... The index: IDX_C15_SHC is created for the table: C15 in the database
# .... The index: IDX_C15_FVR is created for the table: C15 in the database
# .... The index: IDX_C15_COM is created for the table: C15 in the database
# .... The index: IDX_C15_FTG_3 is created for the table: C15 in the database
# .... The index: IDX_C15_DCD is created for the table: C15 in the database
# .... The index: IDX_C15_HBP is created for the table: C15 in the database
# .... The index: IDX_C15_VLS is created for the table: C15 in the database
# .... The index: IDX_C15_SHK is created for the table: C15 in the database
# .... The index: IDX_C15_BRV is created for the table: C15 in the database
# .... The index: IDX_C15_TLF is created for the table: C15 in the database
# .... The index: IDX_C15_RIV is created for the table: C15 in the database
# .... The index: IDX_C15_CIT is created for the table: C15 in the database
# Processing C16.csv and C16.json
# Table C16 is created in the database
# .... The index: IDX_C16_Class is created for the table: C16 in the database
# .... The index: IDX_C16_Exu1 is created for the table: C16 in the database
# .... The index: IDX_C16_Exu4 is created for the table: C16 in the database
# .... The index: IDX_C16_Exu6 is created for the table: C16 in the database
# .... The index: IDX_C16_AM_FM is created for the table: C16 in the database
# .... The index: IDX_C16_MA1 is created for the table: C16 in the database
# .... The index: IDX_C16_MA7 is created for the table: C16 in the database
# .... The index: IDX_C16_PreScreen is created for the table: C16 in the database
# .... The index: IDX_C16_Euc_Dist is created for the table: C16 in the database
# .... The index: IDX_C16_Exu7 is created for the table: C16 in the database
# .... The index: IDX_C16_MA2 is created for the table: C16 in the database
# .... The index: IDX_C16_Exu3 is created for the table: C16 in the database
# .... The index: IDX_C16_Exu2 is created for the table: C16 in the database
# .... The index: IDX_C16_MA5 is created for the table: C16 in the database
# .... The index: IDX_C16_MA4 is created for the table: C16 in the database
# .... The index: IDX_C16_MA6 is created for the table: C16 in the database
# .... The index: IDX_C16_MA3 is created for the table: C16 in the database
# .... The index: IDX_C16_Quality is created for the table: C16 in the database
# .... The index: IDX_C16_Diameter_Optic_Disc is created for the table: C16 in the database
# .... The index: IDX_C16_Exu5 is created for the table: C16 in the database
# Processing C17.csv and C17.json
# Table C17 is created in the database
# .... The index: IDX_C17_wall_motion_score is created for the table: C17 in the database
# .... The index: IDX_C17_still_alive is created for the table: C17 in the database
# .... The index: IDX_C17_wall_motion_index is created for the table: C17 in the database
# .... The index: IDX_C17_mult is created for the table: C17 in the database
# .... The index: IDX_C17_age_at_heart_attack is created for the table: C17 in the database
# .... The index: IDX_C17_pericardial_effusion is created for the table: C17 in the database
# .... The index: IDX_C17_epss is created for the table: C17 in the database
# .... The index: IDX_C17_alive_at_1 is created for the table: C17 in the database
# .... The index: IDX_C17_lvdd is created for the table: C17 in the database
# .... The index: IDX_C17_fractional_shortening is created for the table: C17 in the database
# .... The index: IDX_C17_survival is created for the table: C17 in the database
# Processing C18.csv and C18.json
# Table C18 is created in the database
# .... The index: IDX_C18_P8 is created for the table: C18 in the database
# .... The index: IDX_C18_eyeDetection is created for the table: C18 in the database
# .... The index: IDX_C18_P7 is created for the table: C18 in the database
# .... The index: IDX_C18_AF4 is created for the table: C18 in the database
# .... The index: IDX_C18_FC6 is created for the table: C18 in the database
# .... The index: IDX_C18_F3 is created for the table: C18 in the database
# .... The index: IDX_C18_F7 is created for the table: C18 in the database
# .... The index: IDX_C18_AF3 is created for the table: C18 in the database
# .... The index: IDX_C18_T7 is created for the table: C18 in the database
# .... The index: IDX_C18_T8 is created for the table: C18 in the database
# .... The index: IDX_C18_F8 is created for the table: C18 in the database
# .... The index: IDX_C18_O2 is created for the table: C18 in the database
# .... The index: IDX_C18_FC5 is created for the table: C18 in the database
# .... The index: IDX_C18_F4 is created for the table: C18 in the database
# .... The index: IDX_C18_O1 is created for the table: C18 in the database
# Processing C19.csv and C19.json
# Table C19 is created in the database
# .... The index: IDX_C19_Exclusion is created for the table: C19 in the database
# .... The index: IDX_C19_RegNo is created for the table: C19 in the database
# .... The index: IDX_C19_LymDimin is created for the table: C19 in the database
# .... The index: IDX_C19_Class is created for the table: C19 in the database
# .... The index: IDX_C19_SpecialForms is created for the table: C19 in the database
# .... The index: IDX_C19_ChangesStru is created for the table: C19 in the database
# .... The index: IDX_C19_ChangeLym is created for the table: C19 in the database
# .... The index: IDX_C19_EarlyUptake is created for the table: C19 in the database
# .... The index: IDX_C19_ChangesNode is created for the table: C19 in the database
# .... The index: IDX_C19_BlockOfAffere is created for the table: C19 in the database
# .... The index: IDX_C19_DefectNode is created for the table: C19 in the database
# .... The index: IDX_C19_Dislocation is created for the table: C19 in the database
# .... The index: IDX_C19_Lymphatics is created for the table: C19 in the database
# .... The index: IDX_C19_BLymphS is created for the table: C19 in the database
# .... The index: IDX_C19_BLymphC is created for the table: C19 in the database
# .... The index: IDX_C19_Extravasates is created for the table: C19 in the database
# .... The index: IDX_C19_Bypass is created for the table: C19 in the database
# .... The index: IDX_C19_LymEnlar is created for the table: C19 in the database
# .... The index: IDX_C19_NoNodes is created for the table: C19 in the database
# Processing C2.csv and C2.json
# Table C2 already exists in the database
# Processing C20.csv and C20.json
# Table C20 is created in the database
# .... The index: IDX_C20_RSK_N is created for the table: C20 in the database
# .... The index: IDX_C20_APP_N is created for the table: C20 in the database
# .... The index: IDX_C20_pP70S6_N is created for the table: C20 in the database
# .... The index: IDX_C20_TIAM1_N is created for the table: C20 in the database
# .... The index: IDX_C20_pGSK3B_N is created for the table: C20 in the database
# .... The index: IDX_C20_Bcatenin_N is created for the table: C20 in the database
# .... The index: IDX_C20_Genotype is created for the table: C20 in the database
# .... The index: IDX_C20_P70S6_N is created for the table: C20 in the database
# .... The index: IDX_C20_NR2A_N is created for the table: C20 in the database
# .... The index: IDX_C20_S6_N is created for the table: C20 in the database
# .... The index: IDX_C20_ITSN1_N is created for the table: C20 in the database
# .... The index: IDX_C20_Treatment is created for the table: C20 in the database
# .... The index: IDX_C20_SNCA_N is created for the table: C20 in the database
# .... The index: IDX_C20_pNUMB_N is created for the table: C20 in the database
# .... The index: IDX_C20_GluR4_N is created for the table: C20 in the database
# .... The index: IDX_C20_SYP_N is created for the table: C20 in the database
# .... The index: IDX_C20_ELK_N is created for the table: C20 in the database
# .... The index: IDX_C20_AKT_N is created for the table: C20 in the database
# .... The index: IDX_C20_ADARB1_N is created for the table: C20 in the database
# .... The index: IDX_C20_PSD95_N is created for the table: C20 in the database
# .... The index: IDX_C20_AcetylH3K9_N is created for the table: C20 in the database
# .... The index: IDX_C20_CAMKII_N is created for the table: C20 in the database
# .... The index: IDX_C20_CREB_N is created for the table: C20 in the database
# .... The index: IDX_C20_pCAMKII_N is created for the table: C20 in the database
# .... The index: IDX_C20_Behavior is created for the table: C20 in the database
# .... The index: IDX_C20_AMPKA_N is created for the table: C20 in the database
# .... The index: IDX_C20_Ubiquitin_N is created for the table: C20 in the database
# .... The index: IDX_C20_GluR3_N is created for the table: C20 in the database
# .... The index: IDX_C20_MTOR_N is created for the table: C20 in the database
# .... The index: IDX_C20_P38_N is created for the table: C20 in the database
# .... The index: IDX_C20_pELK_N is created for the table: C20 in the database
# .... The index: IDX_C20_ARC_N is created for the table: C20 in the database
# .... The index: IDX_C20_Tau_N is created for the table: C20 in the database
# .... The index: IDX_C20_pMTOR_N is created for the table: C20 in the database
# .... The index: IDX_C20_DYRK1A_N is created for the table: C20 in the database
# .... The index: IDX_C20_pCFOS_N is created for the table: C20 in the database
# .... The index: IDX_C20_EGR1_N is created for the table: C20 in the database
# .... The index: IDX_C20_H3AcK18_N is created for the table: C20 in the database
# .... The index: IDX_C20_IL1B_N is created for the table: C20 in the database
# .... The index: IDX_C20_MEK_N is created for the table: C20 in the database
# .... The index: IDX_C20_pERK_N is created for the table: C20 in the database
# .... The index: IDX_C20_pPKCAB_N is created for the table: C20 in the database
# .... The index: IDX_C20_nNOS_N is created for the table: C20 in the database
# .... The index: IDX_C20_pBRAF_N is created for the table: C20 in the database
# .... The index: IDX_C20_pAKT_N is created for the table: C20 in the database
# .... The index: IDX_C20_class is created for the table: C20 in the database
# .... The index: IDX_C20_NR2B_N is created for the table: C20 in the database
# .... The index: IDX_C20_ERBB4_N is created for the table: C20 in the database
# .... The index: IDX_C20_pCASP9_N is created for the table: C20 in the database
# .... The index: IDX_C20_SOD1_N is created for the table: C20 in the database
# .... The index: IDX_C20_TRKA_N is created for the table: C20 in the database
# .... The index: IDX_C20_GFAP_N is created for the table: C20 in the database
# .... The index: IDX_C20_pJNK_N is created for the table: C20 in the database
# .... The index: IDX_C20_RAPTOR_N is created for the table: C20 in the database
# .... The index: IDX_C20_CDK5_N is created for the table: C20 in the database
# .... The index: IDX_C20_pCREB_N is created for the table: C20 in the database
# .... The index: IDX_C20_pGSK3B_Tyr216_N is created for the table: C20 in the database
# .... The index: IDX_C20_ERK_N is created for the table: C20 in the database
# .... The index: IDX_C20_DSCR1_N is created for the table: C20 in the database
# .... The index: IDX_C20_NR1_N is created for the table: C20 in the database
# .... The index: IDX_C20_SHH_N is created for the table: C20 in the database
# .... The index: IDX_C20_pNR2B_N is created for the table: C20 in the database
# .... The index: IDX_C20_BRAF_N is created for the table: C20 in the database
# .... The index: IDX_C20_pNR1_N is created for the table: C20 in the database
# .... The index: IDX_C20_BDNF_N is created for the table: C20 in the database
# .... The index: IDX_C20_NUMB_N is created for the table: C20 in the database
# .... The index: IDX_C20_JNK_N is created for the table: C20 in the database
# .... The index: IDX_C20_GSK3B_N is created for the table: C20 in the database
# .... The index: IDX_C20_pS6_N is created for the table: C20 in the database
# .... The index: IDX_C20_RRP1_N is created for the table: C20 in the database
# .... The index: IDX_C20_pNR2A_N is created for the table: C20 in the database
# .... The index: IDX_C20_pMEK_N is created for the table: C20 in the database
# .... The index: IDX_C20_PKCA_N is created for the table: C20 in the database
# .... The index: IDX_C20_pPKCG_N is created for the table: C20 in the database
# .... The index: IDX_C20_pRSK_N is created for the table: C20 in the database
# .... The index: IDX_C20_BAX_N is created for the table: C20 in the database
# .... The index: IDX_C20_P3525_N is created for the table: C20 in the database
# .... The index: IDX_C20_CaNA_N is created for the table: C20 in the database
# Processing C21.csv and C21.json
# Table C21 is created in the database
# .... The index: IDX_C21_L_CORE is created for the table: C21 in the database
# .... The index: IDX_C21_COMFORT is created for the table: C21 in the database
# .... The index: IDX_C21_MP_STBL is created for the table: C21 in the database
# .... The index: IDX_C21_L_O2 is created for the table: C21 in the database
# .... The index: IDX_C21_L_BP is created for the table: C21 in the database
# .... The index: IDX_C21_L_SURF is created for the table: C21 in the database
# .... The index: IDX_C21_CORE_STBL is created for the table: C21 in the database
# .... The index: IDX_C21_SURF_STBL is created for the table: C21 in the database
# .... The index: IDX_C21_ADM_DECS is created for the table: C21 in the database
# Processing C22.csv and C22.json
# Table C22 is created in the database
# .... The index: IDX_C22_brain is created for the table: C22 in the database
# .... The index: IDX_C22_bone is created for the table: C22 in the database
# .... The index: IDX_C22_age is created for the table: C22 in the database
# .... The index: IDX_C22_bone_marrow is created for the table: C22 in the database
# .... The index: IDX_C22_abdominal is created for the table: C22 in the database
# .... The index: IDX_C22_mediastinum is created for the table: C22 in the database
# .... The index: IDX_C22_lung is created for the table: C22 in the database
# .... The index: IDX_C22_liver is created for the table: C22 in the database
# .... The index: IDX_C22_Class is created for the table: C22 in the database
# .... The index: IDX_C22_supraclavicular is created for the table: C22 in the database
# .... The index: IDX_C22_neck is created for the table: C22 in the database
# .... The index: IDX_C22_sex is created for the table: C22 in the database
# .... The index: IDX_C22_pleura is created for the table: C22 in the database
# .... The index: IDX_C22_peritoneum is created for the table: C22 in the database
# .... The index: IDX_C22_axillar is created for the table: C22 in the database
# .... The index: IDX_C22_skin is created for the table: C22 in the database
# Processing C23.csv and C23.json
# Table C23 is created in the database
# .... The index: IDX_C23_stroke is created for the table: C23 in the database
# .... The index: IDX_C23_hypertension is created for the table: C23 in the database
# .... The index: IDX_C23_work_type is created for the table: C23 in the database
# .... The index: IDX_C23_gender is created for the table: C23 in the database
# .... The index: IDX_C23_age is created for the table: C23 in the database
# .... The index: IDX_C23_heart_disease is created for the table: C23 in the database
# .... The index: IDX_C23_Residence_type is created for the table: C23 in the database
# .... The index: IDX_C23_ever_married is created for the table: C23 in the database
# .... The index: IDX_C23_bmi is created for the table: C23 in the database
# .... The index: IDX_C23_avg_glucose_level is created for the table: C23 in the database
# .... The index: IDX_C23_smoking_status is created for the table: C23 in the database
# Processing C24.csv and C24.json
# Table C24 is created in the database
# .... The index: IDX_C24_PRE5 is created for the table: C24 in the database
# .... The index: IDX_C24_DGN is created for the table: C24 in the database
# .... The index: IDX_C24_PRE8 is created for the table: C24 in the database
# .... The index: IDX_C24_PRE9 is created for the table: C24 in the database
# .... The index: IDX_C24_PRE4 is created for the table: C24 in the database
# .... The index: IDX_C24_PRE11 is created for the table: C24 in the database
# .... The index: IDX_C24_AGE is created for the table: C24 in the database
# .... The index: IDX_C24_PRE6 is created for the table: C24 in the database
# .... The index: IDX_C24_PRE10 is created for the table: C24 in the database
# .... The index: IDX_C24_PRE14 is created for the table: C24 in the database
# .... The index: IDX_C24_PRE19 is created for the table: C24 in the database
# .... The index: IDX_C24_PRE17 is created for the table: C24 in the database
# .... The index: IDX_C24_PRE25 is created for the table: C24 in the database
# .... The index: IDX_C24_PRE30 is created for the table: C24 in the database
# .... The index: IDX_C24_PRE32 is created for the table: C24 in the database
# .... The index: IDX_C24_PRE7 is created for the table: C24 in the database
# .... The index: IDX_C24_Risk1Yr is created for the table: C24 in the database
# Processing C25.csv and C25.json
# Table C25 is created in the database
# .... The index: IDX_C25_query_on_thyroxine is created for the table: C25 in the database
# .... The index: IDX_C25_TSH is created for the table: C25 in the database
# .... The index: IDX_C25_hypopituitary is created for the table: C25 in the database
# .... The index: IDX_C25_age is created for the table: C25 in the database
# .... The index: IDX_C25_referral_source is created for the table: C25 in the database
# .... The index: IDX_C25_Class is created for the table: C25 in the database
# .... The index: IDX_C25_TT4 is created for the table: C25 in the database
# .... The index: IDX_C25_tumor is created for the table: C25 in the database
# .... The index: IDX_C25_sex is created for the table: C25 in the database
# .... The index: IDX_C25_thyroid_surgery is created for the table: C25 in the database
# .... The index: IDX_C25_query_hyperthyroid is created for the table: C25 in the database
# .... The index: IDX_C25_antithyroid_med is created for the table: C25 in the database
# .... The index: IDX_C25_query_hypothyroid is created for the table: C25 in the database
# .... The index: IDX_C25_on_thyroxine is created for the table: C25 in the database
# .... The index: IDX_C25_pregnant is created for the table: C25 in the database
# .... The index: IDX_C25_I131_treatment is created for the table: C25 in the database
# .... The index: IDX_C25_T4U is created for the table: C25 in the database
# .... The index: IDX_C25_lithium is created for the table: C25 in the database
# .... The index: IDX_C25_sick is created for the table: C25 in the database
# .... The index: IDX_C25_goitre is created for the table: C25 in the database
# .... The index: IDX_C25_T3 is created for the table: C25 in the database
# .... The index: IDX_C25_FTI is created for the table: C25 in the database
# .... The index: IDX_C25_psych is created for the table: C25 in the database
# Processing C26.csv and C26.json
# Table C26 is created in the database
# .... The index: IDX_C26_Total_serum_triiodothyronine is created for the table: C26 in the database
# .... The index: IDX_C26_TSH_Post is created for the table: C26 in the database
# .... The index: IDX_C26_Basal_TSH is created for the table: C26 in the database
# .... The index: IDX_C26_Total_serum_thyroxin is created for the table: C26 in the database
# .... The index: IDX_C26_Class is created for the table: C26 in the database
# .... The index: IDX_C26_T3_resin is created for the table: C26 in the database
# Processing C27.csv and C27.json
# Table C27 is created in the database
# .... The index: IDX_C27_Embarked is created for the table: C27 in the database
# .... The index: IDX_C27_Parch is created for the table: C27 in the database
# .... The index: IDX_C27_SibSp is created for the table: C27 in the database
# .... The index: IDX_C27_Survived is created for the table: C27 in the database
# .... The index: IDX_C27_Fare is created for the table: C27 in the database
# .... The index: IDX_C27_Pclass is created for the table: C27 in the database
# .... The index: IDX_C27_Sex is created for the table: C27 in the database
# Processing C28.csv and C28.json
# Table C28 is created in the database
# .... The index: IDX_C28_HTN is created for the table: C28 in the database
# .... The index: IDX_C28_FH is created for the table: C28 in the database
# .... The index: IDX_C28_Thyroid_Disease is created for the table: C28 in the database
# .... The index: IDX_C28_Weight is created for the table: C28 in the database
# .... The index: IDX_C28_Tinversion is created for the table: C28 in the database
# .... The index: IDX_C28_Dyspnea is created for the table: C28 in the database
# .... The index: IDX_C28_Neut is created for the table: C28 in the database
# .... The index: IDX_C28_LDL is created for the table: C28 in the database
# .... The index: IDX_C28_BBB is created for the table: C28 in the database
# .... The index: IDX_C28_CVA is created for the table: C28 in the database
# .... The index: IDX_C28_CR is created for the table: C28 in the database
# .... The index: IDX_C28_PR is created for the table: C28 in the database
# .... The index: IDX_C28_Edema is created for the table: C28 in the database
# .... The index: IDX_C28_LVH is created for the table: C28 in the database
# .... The index: IDX_C28_Atypical is created for the table: C28 in the database
# .... The index: IDX_C28_DM is created for the table: C28 in the database
# .... The index: IDX_C28_HB is created for the table: C28 in the database
# .... The index: IDX_C28_PLT is created for the table: C28 in the database
# .... The index: IDX_C28_Region_RWMA is created for the table: C28 in the database
# .... The index: IDX_C28_Cath is created for the table: C28 in the database
# .... The index: IDX_C28_LowTH_Ang is created for the table: C28 in the database
# .... The index: IDX_C28_BUN is created for the table: C28 in the database
# .... The index: IDX_C28_Na is created for the table: C28 in the database
# .... The index: IDX_C28_ESR is created for the table: C28 in the database
# .... The index: IDX_C28_Nonanginal is created for the table: C28 in the database
# .... The index: IDX_C28_VHD is created for the table: C28 in the database
# .... The index: IDX_C28_Exertional_CP is created for the table: C28 in the database
# .... The index: IDX_C28_Airway_disease is created for the table: C28 in the database
# .... The index: IDX_C28_BP is created for the table: C28 in the database
# .... The index: IDX_C28_Lung_rales is created for the table: C28 in the database
# .... The index: IDX_C28_St_Depression is created for the table: C28 in the database
# .... The index: IDX_C28_HDL is created for the table: C28 in the database
# .... The index: IDX_C28_K is created for the table: C28 in the database
# .... The index: IDX_C28_Sex is created for the table: C28 in the database
# .... The index: IDX_C28_Function_Class is created for the table: C28 in the database
# .... The index: IDX_C28_Q_Wave is created for the table: C28 in the database
# .... The index: IDX_C28_BMI is created for the table: C28 in the database
# .... The index: IDX_C28_Length is created for the table: C28 in the database
# .... The index: IDX_C28_Typical_Chest_Pain is created for the table: C28 in the database
# .... The index: IDX_C28_St_Elevation is created for the table: C28 in the database
# .... The index: IDX_C28_Lymph is created for the table: C28 in the database
# .... The index: IDX_C28_Systolic_Murmur is created for the table: C28 in the database
# .... The index: IDX_C28_Age is created for the table: C28 in the database
# .... The index: IDX_C28_Current_Smoker is created for the table: C28 in the database
# ...
# .... The index: IDX_trial6_HGB5_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_DOSE is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB23_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_RANDDY is created for the table: trial6 in the database
# .... The index: IDX_trial6_CHHBCD_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB16_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_EVALPRIM is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBRSPYN_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_EOTXHB is created for the table: trial6 in the database
# .... The index: IDX_trial6_STUDYDAY_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_PDDY_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBRSPWK is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBG50P19_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBTGTYN is created for the table: trial6 in the database
# .... The index: IDX_trial6_TFNTXYN5_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBG50WK_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBT50P19_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_X1_PULSE is created for the table: trial6 in the database
# .... The index: IDX_trial6_CMPRIOR is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBCORTDY_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_CNSNTDY is created for the table: trial6 in the database
# .... The index: IDX_trial6_X2_URACID is created for the table: trial6 in the database
# .... The index: IDX_trial6_SEX is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBTGTDY is created for the table: trial6 in the database
# .... The index: IDX_trial6_UEOTXWK_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_COMTXYN is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB5 is created for the table: trial6 in the database
# .... The index: IDX_trial6_X2_WBC is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBTGTDY_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_AGE75YN is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBT19WK_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBRSPDY_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB30_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_TXGROUP is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB8 is created for the table: trial6 in the database
# .... The index: IDX_trial6_RSPWK_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_X2_SBP is created for the table: trial6 in the database
# .... The index: IDX_trial6_PRGPOTYN is created for the table: trial6 in the database
# .... The index: IDX_trial6_PTESTRES is created for the table: trial6 in the database
# .... The index: IDX_trial6_SAFGROUP is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBW19TWK_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_EVALQOL is created for the table: trial6 in the database
# .... The index: IDX_trial6_SDISRS is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB26_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB11 is created for the table: trial6 in the database
# .... The index: IDX_trial6_X3_ECOGCD is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBT50WK_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_RSPDY_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_TFNLE8WK is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB33_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBRSPWK_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_X2_DBP is created for the table: trial6 in the database
# .... The index: IDX_trial6_X3_ECOG is created for the table: trial6 in the database
# .... The index: IDX_trial6_DTHDY_y_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_DOSEAD is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBRSPYN_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB24_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_X1_HGB is created for the table: trial6 in the database
# .... The index: IDX_trial6_EOTHBWK_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_X2_HCT is created for the table: trial6 in the database
# .... The index: IDX_trial6_B_ECOG2 is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBG50PER_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_WCDOSE is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBCORTWK is created for the table: trial6 in the database
# .... The index: IDX_trial6_UEOTXWK_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB6 is created for the table: trial6 in the database
# .... The index: IDX_trial6_RSPDURDY is created for the table: trial6 in the database
# .... The index: IDX_trial6_TFNLE8YN_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_CMFEYN is created for the table: trial6 in the database
# .... The index: IDX_trial6_B_WGTN is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBRSPYN is created for the table: trial6 in the database
# .... The index: IDX_trial6_B_WEIGHT is created for the table: trial6 in the database
# .... The index: IDX_trial6_TFNLE8YN_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_X1_ALBUMN is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBW19DY_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_X2_ANC is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB25_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_X3_DBP is created for the table: trial6 in the database
# .... The index: IDX_trial6_TFNTXD_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB29_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_B_LDH2 is created for the table: trial6 in the database
# .... The index: IDX_trial6_EOTXWK is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBT50PER_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_TFNTXYN is created for the table: trial6 in the database
# .... The index: IDX_trial6_BORSPCD is created for the table: trial6 in the database
# .... The index: IDX_trial6_TFNLE8YN is created for the table: trial6 in the database
# .... The index: IDX_trial6_DTH_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB15_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_PFSCD_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBCORN19_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_TFNLE8WK_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBW19WK_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_X2_BUN is created for the table: trial6 in the database
# .... The index: IDX_trial6_B_SEREPO is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBCORN19_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_X1_DBP is created for the table: trial6 in the database
# .... The index: IDX_trial6_RSPCD_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB4_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_X1_SEGS is created for the table: trial6 in the database
# .... The index: IDX_trial6_EOTPDAY_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB25 is created for the table: trial6 in the database
# .... The index: IDX_trial6_AGE65YN is created for the table: trial6 in the database
# .... The index: IDX_trial6_TFNDY is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB21 is created for the table: trial6 in the database
# .... The index: IDX_trial6_EOTPTDAY_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_X1_SGOT is created for the table: trial6 in the database
# .... The index: IDX_trial6_TFNWK_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_B_ECOGDY is created for the table: trial6 in the database
# .... The index: IDX_trial6_CHHB is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB22_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_FSTCHDY is created for the table: trial6 in the database
# .... The index: IDX_trial6_BORSPDY_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_X1_TLBILI is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB3_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_X2_PLT is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBTGVAL is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBCORNET_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_EOTPDAY2 is created for the table: trial6 in the database
# .... The index: IDX_trial6_UCHBCD_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_SAFTXG is created for the table: trial6 in the database
# .... The index: IDX_trial6_X1_SGPT is created for the table: trial6 in the database
# .... The index: IDX_trial6_TFNLE8DY is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB11_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_X1_TLPROT is created for the table: trial6 in the database
# .... The index: IDX_trial6_B_ECOGN is created for the table: trial6 in the database
# .... The index: IDX_trial6_RSPWK is created for the table: trial6 in the database
# .... The index: IDX_trial6_UEOTXHB_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_SAFTXDOS is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB14 is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBTGTWK is created for the table: trial6 in the database
# .... The index: IDX_trial6_LSTTXDY is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB35_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB17_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_RSPDURWK is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB20_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBCORNET_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_DTAECAUS is created for the table: trial6 in the database
# .... The index: IDX_trial6_B_HGBN is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB9 is created for the table: trial6 in the database
# .... The index: IDX_trial6_X2_ALBUMN is created for the table: trial6 in the database
# .... The index: IDX_trial6_FSTTADY is created for the table: trial6 in the database
# .... The index: IDX_trial6_X2_NEUT is created for the table: trial6 in the database
# .... The index: IDX_trial6_EXHBCOYN is created for the table: trial6 in the database
# .... The index: IDX_trial6_X1_BICARB is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB1_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_UCHB_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_X1_BANDS is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBCORYN is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB15_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_BORSPCD_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_PFSDY_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBCORTYN is created for the table: trial6 in the database
# .... The index: IDX_trial6_TFNTXYN5_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBCORTET is created for the table: trial6 in the database
# .... The index: IDX_trial6_UCHB is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB12 is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB27_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_UEOTXDY is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB32_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_EOTXHB_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB20_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_X1_LDH is created for the table: trial6 in the database
# .... The index: IDX_trial6_TFNLE8WK_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_BORSPCD_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_RSPDURWK_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBCORTWK_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_MEDHINTN is created for the table: trial6 in the database
# .... The index: IDX_trial6_UEOTXHB_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_UEOTXDY_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_TFNDY_y is created for the table: trial6 in the database
# .... The index: IDX_trial6_PFSDYA_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_EOTPDAY3 is created for the table: trial6 in the database
# .... The index: IDX_trial6_COMPSYN is created for the table: trial6 in the database
# .... The index: IDX_trial6_ACTIVE is created for the table: trial6 in the database
# .... The index: IDX_trial6_PRTFN is created for the table: trial6 in the database
# .... The index: IDX_trial6_PFSWK_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBG50P19 is created for the table: trial6 in the database
# .... The index: IDX_trial6_HGB23 is created for the table: trial6 in the database
# .... The index: IDX_trial6_PFSCDA_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBT50WK is created for the table: trial6 in the database
# .... The index: IDX_trial6_DISRSP is created for the table: trial6 in the database
# .... The index: IDX_trial6_RSPDY_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_X2_PULSE is created for the table: trial6 in the database
# .... The index: IDX_trial6_X1_URACID is created for the table: trial6 in the database
# .... The index: IDX_trial6_TXDOSE is created for the table: trial6 in the database
# .... The index: IDX_trial6_ENDTX is created for the table: trial6 in the database
# .... The index: IDX_trial6_X1_RBC is created for the table: trial6 in the database
# .... The index: IDX_trial6_HBCORTET_x is created for the table: trial6 in the database
# .... The index: IDX_trial6_X2_CL is created for the table: trial6 in the database

# %%
def find_syn_fnames(syn_data_dir: Path, real_names: list) -> dict:
    syn_dict={}
    for real_name_i in real_names:
        catch_file=[]
        for syn_name_i in os.listdir(syn_data_dir):
            if syn_name_i.startswith(real_name_i+'_'):
                catch_file.append(Path(syn_name_i).stem)
        syn_dict[real_name_i]=catch_file
    print('Extracted the names of all available synthetic datasets corresponding to {} real datasets'.format(str(len(syn_dict))))
    return syn_dict

# %%
# import syn data into database
syn_dict=find_syn_fnames(syn_dir,real_fnames)

#drop datasets with no synthetic data available 
tabular_test_set={key:val for key,val in syn_dict.items() if len(val)!=0}
# Out:
# Extracted the names of all available synthetic datasets corresponding to 41 real datasets

# %%
#import synthetic data into database
for key in tabular_test_set.keys():
    meta_json=key+'.json'
    for syn_table_name in tabular_test_set[key]:
        syn_csv=syn_table_name+'.csv'
        data,_=prep_data_for_db(os.path.join(syn_dir,syn_csv)) # Note: This function  can be used to quickly generate metadata template, but this is not shown here.
        with open(os.path.join(metadata_dir, meta_json), 'r') as f:
            metadata=json.load(f)
        print(f"Processing {syn_csv} and {meta_json} ")
        candidate_db_idx=get_vars_to_index(metadata,data)
        table_name=Path(syn_csv).stem
        make_table(table_name, data, conn,indx_vars=candidate_db_idx)
# Out:
# Processing C1_syn_default_14.csv and C1.json
# Table C1_syn_default_14 is created in the database
# .... The index: IDX_C1_syn_default_14_relationship is created for the table: C1_syn_default_14 in the database
# .... The index: IDX_C1_syn_default_14_income is created for the table: C1_syn_default_14 in the database
# .... The index: IDX_C1_syn_default_14_hours_per_week is created for the table: C1_syn_default_14 in the database
# .... The index: IDX_C1_syn_default_14_marital_status is created for the table: C1_syn_default_14 in the database
# .... The index: IDX_C1_syn_default_14_age is created for the table: C1_syn_default_14 in the database
# .... The index: IDX_C1_syn_default_14_fnlwgt is created for the table: C1_syn_default_14 in the database
# .... The index: IDX_C1_syn_default_14_race is created for the table: C1_syn_default_14 in the database
# .... The index: IDX_C1_syn_default_14_education is created for the table: C1_syn_default_14 in the database
# .... The index: IDX_C1_syn_default_14_native_country is created for the table: C1_syn_default_14 in the database
# .... The index: IDX_C1_syn_default_14_sex is created for the table: C1_syn_default_14 in the database
# .... The index: IDX_C1_syn_default_14_workclass is created for the table: C1_syn_default_14 in the database
# .... The index: IDX_C1_syn_default_14_capital is created for the table: C1_syn_default_14 in the database
# .... The index: IDX_C1_syn_default_14_occupation is created for the table: C1_syn_default_14 in the database
# Processing C1_synthpop_7.csv and C1.json
# Table C1_synthpop_7 is created in the database
# .... The index: IDX_C1_synthpop_7_relationship is created for the table: C1_synthpop_7 in the database
# .... The index: IDX_C1_synthpop_7_income is created for the table: C1_synthpop_7 in the database
# .... The index: IDX_C1_synthpop_7_hours_per_week is created for the table: C1_synthpop_7 in the database
# .... The index: IDX_C1_synthpop_7_marital_status is created for the table: C1_synthpop_7 in the database
# .... The index: IDX_C1_synthpop_7_age is created for the table: C1_synthpop_7 in the database
# .... The index: IDX_C1_synthpop_7_fnlwgt is created for the table: C1_synthpop_7 in the database
# .... The index: IDX_C1_synthpop_7_race is created for the table: C1_synthpop_7 in the database
# .... The index: IDX_C1_synthpop_7_education is created for the table: C1_synthpop_7 in the database
# .... The index: IDX_C1_synthpop_7_native_country is created for the table: C1_synthpop_7 in the database
# .... The index: IDX_C1_synthpop_7_sex is created for the table: C1_synthpop_7 in the database
# .... The index: IDX_C1_synthpop_7_workclass is created for the table: C1_synthpop_7 in the database
# .... The index: IDX_C1_synthpop_7_capital is created for the table: C1_synthpop_7 in the database
# .... The index: IDX_C1_synthpop_7_occupation is created for the table: C1_synthpop_7 in the database
# Processing C1_synthpop_6.csv and C1.json
# Table C1_synthpop_6 is created in the database
# .... The index: IDX_C1_synthpop_6_relationship is created for the table: C1_synthpop_6 in the database
# .... The index: IDX_C1_synthpop_6_income is created for the table: C1_synthpop_6 in the database
# .... The index: IDX_C1_synthpop_6_hours_per_week is created for the table: C1_synthpop_6 in the database
# .... The index: IDX_C1_synthpop_6_marital_status is created for the table: C1_synthpop_6 in the database
# .... The index: IDX_C1_synthpop_6_age is created for the table: C1_synthpop_6 in the database
# .... The index: IDX_C1_synthpop_6_fnlwgt is created for the table: C1_synthpop_6 in the database
# .... The index: IDX_C1_synthpop_6_race is created for the table: C1_synthpop_6 in the database
# .... The index: IDX_C1_synthpop_6_education is created for the table: C1_synthpop_6 in the database
# .... The index: IDX_C1_synthpop_6_native_country is created for the table: C1_synthpop_6 in the database
# .... The index: IDX_C1_synthpop_6_sex is created for the table: C1_synthpop_6 in the database
# .... The index: IDX_C1_synthpop_6_workclass is created for the table: C1_synthpop_6 in the database
# .... The index: IDX_C1_synthpop_6_capital is created for the table: C1_synthpop_6 in the database
# .... The index: IDX_C1_synthpop_6_occupation is created for the table: C1_synthpop_6 in the database
# Processing C1_syn_default_15.csv and C1.json
# Table C1_syn_default_15 is created in the database
# .... The index: IDX_C1_syn_default_15_relationship is created for the table: C1_syn_default_15 in the database
# .... The index: IDX_C1_syn_default_15_income is created for the table: C1_syn_default_15 in the database
# .... The index: IDX_C1_syn_default_15_hours_per_week is created for the table: C1_syn_default_15 in the database
# .... The index: IDX_C1_syn_default_15_marital_status is created for the table: C1_syn_default_15 in the database
# .... The index: IDX_C1_syn_default_15_age is created for the table: C1_syn_default_15 in the database
# .... The index: IDX_C1_syn_default_15_fnlwgt is created for the table: C1_syn_default_15 in the database
# .... The index: IDX_C1_syn_default_15_race is created for the table: C1_syn_default_15 in the database
# .... The index: IDX_C1_syn_default_15_education is created for the table: C1_syn_default_15 in the database
# .... The index: IDX_C1_syn_default_15_native_country is created for the table: C1_syn_default_15 in the database
# .... The index: IDX_C1_syn_default_15_sex is created for the table: C1_syn_default_15 in the database
# .... The index: IDX_C1_syn_default_15_workclass is created for the table: C1_syn_default_15 in the database
# .... The index: IDX_C1_syn_default_15_capital is created for the table: C1_syn_default_15 in the database
# .... The index: IDX_C1_syn_default_15_occupation is created for the table: C1_syn_default_15 in the database
# Processing C1_syn_default_17.csv and C1.json
# Table C1_syn_default_17 is created in the database
# .... The index: IDX_C1_syn_default_17_relationship is created for the table: C1_syn_default_17 in the database
# .... The index: IDX_C1_syn_default_17_income is created for the table: C1_syn_default_17 in the database
# .... The index: IDX_C1_syn_default_17_hours_per_week is created for the table: C1_syn_default_17 in the database
# .... The index: IDX_C1_syn_default_17_marital_status is created for the table: C1_syn_default_17 in the database
# .... The index: IDX_C1_syn_default_17_age is created for the table: C1_syn_default_17 in the database
# .... The index: IDX_C1_syn_default_17_fnlwgt is created for the table: C1_syn_default_17 in the database
# .... The index: IDX_C1_syn_default_17_race is created for the table: C1_syn_default_17 in the database
# .... The index: IDX_C1_syn_default_17_education is created for the table: C1_syn_default_17 in the database
# .... The index: IDX_C1_syn_default_17_native_country is created for the table: C1_syn_default_17 in the database
# .... The index: IDX_C1_syn_default_17_sex is created for the table: C1_syn_default_17 in the database
# .... The index: IDX_C1_syn_default_17_workclass is created for the table: C1_syn_default_17 in the database
# .... The index: IDX_C1_syn_default_17_capital is created for the table: C1_syn_default_17 in the database
# .... The index: IDX_C1_syn_default_17_occupation is created for the table: C1_syn_default_17 in the database
# Processing C1_synthpop_4.csv and C1.json
# Table C1_synthpop_4 is created in the database
# .... The index: IDX_C1_synthpop_4_relationship is created for the table: C1_synthpop_4 in the database
# .... The index: IDX_C1_synthpop_4_income is created for the table: C1_synthpop_4 in the database
# .... The index: IDX_C1_synthpop_4_hours_per_week is created for the table: C1_synthpop_4 in the database
# .... The index: IDX_C1_synthpop_4_marital_status is created for the table: C1_synthpop_4 in the database
# .... The index: IDX_C1_synthpop_4_age is created for the table: C1_synthpop_4 in the database
# .... The index: IDX_C1_synthpop_4_fnlwgt is created for the table: C1_synthpop_4 in the database
# .... The index: IDX_C1_synthpop_4_race is created for the table: C1_synthpop_4 in the database
# .... The index: IDX_C1_synthpop_4_education is created for the table: C1_synthpop_4 in the database
# .... The index: IDX_C1_synthpop_4_native_country is created for the table: C1_synthpop_4 in the database
# .... The index: IDX_C1_synthpop_4_sex is created for the table: C1_synthpop_4 in the database
# .... The index: IDX_C1_synthpop_4_workclass is created for the table: C1_synthpop_4 in the database
# .... The index: IDX_C1_synthpop_4_capital is created for the table: C1_synthpop_4 in the database
# .... The index: IDX_C1_synthpop_4_occupation is created for the table: C1_synthpop_4 in the database
# Processing C1_syn_default_9.csv and C1.json
# Table C1_syn_default_9 is created in the database
# .... The index: IDX_C1_syn_default_9_relationship is created for the table: C1_syn_default_9 in the database
# .... The index: IDX_C1_syn_default_9_income is created for the table: C1_syn_default_9 in the database
# .... The index: IDX_C1_syn_default_9_hours_per_week is created for the table: C1_syn_default_9 in the database
# .... The index: IDX_C1_syn_default_9_marital_status is created for the table: C1_syn_default_9 in the database
# .... The index: IDX_C1_syn_default_9_age is created for the table: C1_syn_default_9 in the database
# .... The index: IDX_C1_syn_default_9_fnlwgt is created for the table: C1_syn_default_9 in the database
# .... The index: IDX_C1_syn_default_9_race is created for the table: C1_syn_default_9 in the database
# .... The index: IDX_C1_syn_default_9_education is created for the table: C1_syn_default_9 in the database
# .... The index: IDX_C1_syn_default_9_native_country is created for the table: C1_syn_default_9 in the database
# .... The index: IDX_C1_syn_default_9_sex is created for the table: C1_syn_default_9 in the database
# .... The index: IDX_C1_syn_default_9_workclass is created for the table: C1_syn_default_9 in the database
# .... The index: IDX_C1_syn_default_9_capital is created for the table: C1_syn_default_9 in the database
# .... The index: IDX_C1_syn_default_9_occupation is created for the table: C1_syn_default_9 in the database
# Processing C1_syn_default_8.csv and C1.json
# Table C1_syn_default_8 is created in the database
# .... The index: IDX_C1_syn_default_8_relationship is created for the table: C1_syn_default_8 in the database
# .... The index: IDX_C1_syn_default_8_income is created for the table: C1_syn_default_8 in the database
# .... The index: IDX_C1_syn_default_8_hours_per_week is created for the table: C1_syn_default_8 in the database
# .... The index: IDX_C1_syn_default_8_marital_status is created for the table: C1_syn_default_8 in the database
# .... The index: IDX_C1_syn_default_8_age is created for the table: C1_syn_default_8 in the database
# .... The index: IDX_C1_syn_default_8_fnlwgt is created for the table: C1_syn_default_8 in the database
# .... The index: IDX_C1_syn_default_8_race is created for the table: C1_syn_default_8 in the database
# .... The index: IDX_C1_syn_default_8_education is created for the table: C1_syn_default_8 in the database
# .... The index: IDX_C1_syn_default_8_native_country is created for the table: C1_syn_default_8 in the database
# .... The index: IDX_C1_syn_default_8_sex is created for the table: C1_syn_default_8 in the database
# .... The index: IDX_C1_syn_default_8_workclass is created for the table: C1_syn_default_8 in the database
# .... The index: IDX_C1_syn_default_8_capital is created for the table: C1_syn_default_8 in the database
# .... The index: IDX_C1_syn_default_8_occupation is created for the table: C1_syn_default_8 in the database
# Processing C1_synthpop_5.csv and C1.json
# Table C1_synthpop_5 is created in the database
# .... The index: IDX_C1_synthpop_5_relationship is created for the table: C1_synthpop_5 in the database
# .... The index: IDX_C1_synthpop_5_income is created for the table: C1_synthpop_5 in the database
# .... The index: IDX_C1_synthpop_5_hours_per_week is created for the table: C1_synthpop_5 in the database
# .... The index: IDX_C1_synthpop_5_marital_status is created for the table: C1_synthpop_5 in the database
# .... The index: IDX_C1_synthpop_5_age is created for the table: C1_synthpop_5 in the database
# .... The index: IDX_C1_synthpop_5_fnlwgt is created for the table: C1_synthpop_5 in the database
# .... The index: IDX_C1_synthpop_5_race is created for the table: C1_synthpop_5 in the database
# .... The index: IDX_C1_synthpop_5_education is created for the table: C1_synthpop_5 in the database
# .... The index: IDX_C1_synthpop_5_native_country is created for the table: C1_synthpop_5 in the database
# .... The index: IDX_C1_synthpop_5_sex is created for the table: C1_synthpop_5 in the database
# .... The index: IDX_C1_synthpop_5_workclass is created for the table: C1_synthpop_5 in the database
# .... The index: IDX_C1_synthpop_5_capital is created for the table: C1_synthpop_5 in the database
# .... The index: IDX_C1_synthpop_5_occupation is created for the table: C1_synthpop_5 in the database
# Processing C1_syn_default_16.csv and C1.json
# Table C1_syn_default_16 is created in the database
# .... The index: IDX_C1_syn_default_16_relationship is created for the table: C1_syn_default_16 in the database
# .... The index: IDX_C1_syn_default_16_income is created for the table: C1_syn_default_16 in the database
# .... The index: IDX_C1_syn_default_16_hours_per_week is created for the table: C1_syn_default_16 in the database
# .... The index: IDX_C1_syn_default_16_marital_status is created for the table: C1_syn_default_16 in the database
# .... The index: IDX_C1_syn_default_16_age is created for the table: C1_syn_default_16 in the database
# .... The index: IDX_C1_syn_default_16_fnlwgt is created for the table: C1_syn_default_16 in the database
# .... The index: IDX_C1_syn_default_16_race is created for the table: C1_syn_default_16 in the database
# .... The index: IDX_C1_syn_default_16_education is created for the table: C1_syn_default_16 in the database
# .... The index: IDX_C1_syn_default_16_native_country is created for the table: C1_syn_default_16 in the database
# .... The index: IDX_C1_syn_default_16_sex is created for the table: C1_syn_default_16 in the database
# .... The index: IDX_C1_syn_default_16_workclass is created for the table: C1_syn_default_16 in the database
# .... The index: IDX_C1_syn_default_16_capital is created for the table: C1_syn_default_16 in the database
# .... The index: IDX_C1_syn_default_16_occupation is created for the table: C1_syn_default_16 in the database
# Processing C1_syn_default_12.csv and C1.json
# Table C1_syn_default_12 is created in the database
# .... The index: IDX_C1_syn_default_12_relationship is created for the table: C1_syn_default_12 in the database
# .... The index: IDX_C1_syn_default_12_income is created for the table: C1_syn_default_12 in the database
# .... The index: IDX_C1_syn_default_12_hours_per_week is created for the table: C1_syn_default_12 in the database
# .... The index: IDX_C1_syn_default_12_marital_status is created for the table: C1_syn_default_12 in the database
# .... The index: IDX_C1_syn_default_12_age is created for the table: C1_syn_default_12 in the database
# .... The index: IDX_C1_syn_default_12_fnlwgt is created for the table: C1_syn_default_12 in the database
# .... The index: IDX_C1_syn_default_12_race is created for the table: C1_syn_default_12 in the database
# .... The index: IDX_C1_syn_default_12_education is created for the table: C1_syn_default_12 in the database
# .... The index: IDX_C1_syn_default_12_native_country is created for the table: C1_syn_default_12 in the database
# .... The index: IDX_C1_syn_default_12_sex is created for the table: C1_syn_default_12 in the database
# .... The index: IDX_C1_syn_default_12_workclass is created for the table: C1_syn_default_12 in the database
# .... The index: IDX_C1_syn_default_12_capital is created for the table: C1_syn_default_12 in the database
# .... The index: IDX_C1_syn_default_12_occupation is created for the table: C1_syn_default_12 in the database
# Processing C1_synthpop_1.csv and C1.json
# Table C1_synthpop_1 is created in the database
# .... The index: IDX_C1_synthpop_1_relationship is created for the table: C1_synthpop_1 in the database
# .... The index: IDX_C1_synthpop_1_income is created for the table: C1_synthpop_1 in the database
# .... The index: IDX_C1_synthpop_1_hours_per_week is created for the table: C1_synthpop_1 in the database
# .... The index: IDX_C1_synthpop_1_marital_status is created for the table: C1_synthpop_1 in the database
# .... The index: IDX_C1_synthpop_1_age is created for the table: C1_synthpop_1 in the database
# .... The index: IDX_C1_synthpop_1_fnlwgt is created for the table: C1_synthpop_1 in the database
# .... The index: IDX_C1_synthpop_1_race is created for the table: C1_synthpop_1 in the database
# .... The index: IDX_C1_synthpop_1_education is created for the table: C1_synthpop_1 in the database
# .... The index: IDX_C1_synthpop_1_native_country is created for the table: C1_synthpop_1 in the database
# .... The index: IDX_C1_synthpop_1_sex is created for the table: C1_synthpop_1 in the database
# .... The index: IDX_C1_synthpop_1_workclass is created for the table: C1_synthpop_1 in the database
# .... The index: IDX_C1_synthpop_1_capital is created for the table: C1_synthpop_1 in the database
# .... The index: IDX_C1_synthpop_1_occupation is created for the table: C1_synthpop_1 in the database
# Processing C1_syn_default_13.csv and C1.json
# Table C1_syn_default_13 is created in the database
# .... The index: IDX_C1_syn_default_13_relationship is created for the table: C1_syn_default_13 in the database
# .... The index: IDX_C1_syn_default_13_income is created for the table: C1_syn_default_13 in the database
# .... The index: IDX_C1_syn_default_13_hours_per_week is created for the table: C1_syn_default_13 in the database
# .... The index: IDX_C1_syn_default_13_marital_status is created for the table: C1_syn_default_13 in the database
# .... The index: IDX_C1_syn_default_13_age is created for the table: C1_syn_default_13 in the database
# .... The index: IDX_C1_syn_default_13_fnlwgt is created for the table: C1_syn_default_13 in the database
# .... The index: IDX_C1_syn_default_13_race is created for the table: C1_syn_default_13 in the database
# .... The index: IDX_C1_syn_default_13_education is created for the table: C1_syn_default_13 in the database
# .... The index: IDX_C1_syn_default_13_native_country is created for the table: C1_syn_default_13 in the database
# .... The index: IDX_C1_syn_default_13_sex is created for the table: C1_syn_default_13 in the database
# .... The index: IDX_C1_syn_default_13_workclass is created for the table: C1_syn_default_13 in the database
# .... The index: IDX_C1_syn_default_13_capital is created for the table: C1_syn_default_13 in the database
# .... The index: IDX_C1_syn_default_13_occupation is created for the table: C1_syn_default_13 in the database
# Processing C1_syn_default_11.csv and C1.json
# Table C1_syn_default_11 is created in the database
# .... The index: IDX_C1_syn_default_11_relationship is created for the table: C1_syn_default_11 in the database
# .... The index: IDX_C1_syn_default_11_income is created for the table: C1_syn_default_11 in the database
# .... The index: IDX_C1_syn_default_11_hours_per_week is created for the table: C1_syn_default_11 in the database
# .... The index: IDX_C1_syn_default_11_marital_status is created for the table: C1_syn_default_11 in the database
# .... The index: IDX_C1_syn_default_11_age is created for the table: C1_syn_default_11 in the database
# .... The index: IDX_C1_syn_default_11_fnlwgt is created for the table: C1_syn_default_11 in the database
# .... The index: IDX_C1_syn_default_11_race is created for the table: C1_syn_default_11 in the database
# .... The index: IDX_C1_syn_default_11_education is created for the table: C1_syn_default_11 in the database
# .... The index: IDX_C1_syn_default_11_native_country is created for the table: C1_syn_default_11 in the database
# .... The index: IDX_C1_syn_default_11_sex is created for the table: C1_syn_default_11 in the database
# .... The index: IDX_C1_syn_default_11_workclass is created for the table: C1_syn_default_11 in the database
# .... The index: IDX_C1_syn_default_11_capital is created for the table: C1_syn_default_11 in the database
# .... The index: IDX_C1_syn_default_11_occupation is created for the table: C1_syn_default_11 in the database
# Processing C1_synthpop_2.csv and C1.json
# Table C1_synthpop_2 is created in the database
# .... The index: IDX_C1_synthpop_2_relationship is created for the table: C1_synthpop_2 in the database
# .... The index: IDX_C1_synthpop_2_income is created for the table: C1_synthpop_2 in the database
# .... The index: IDX_C1_synthpop_2_hours_per_week is created for the table: C1_synthpop_2 in the database
# .... The index: IDX_C1_synthpop_2_marital_status is created for the table: C1_synthpop_2 in the database
# .... The index: IDX_C1_synthpop_2_age is created for the table: C1_synthpop_2 in the database
# .... The index: IDX_C1_synthpop_2_fnlwgt is created for the table: C1_synthpop_2 in the database
# .... The index: IDX_C1_synthpop_2_race is created for the table: C1_synthpop_2 in the database
# .... The index: IDX_C1_synthpop_2_education is created for the table: C1_synthpop_2 in the database
# .... The index: IDX_C1_synthpop_2_native_country is created for the table: C1_synthpop_2 in the database
# .... The index: IDX_C1_synthpop_2_sex is created for the table: C1_synthpop_2 in the database
# .... The index: IDX_C1_synthpop_2_workclass is created for the table: C1_synthpop_2 in the database
# .... The index: IDX_C1_synthpop_2_capital is created for the table: C1_synthpop_2 in the database
# .... The index: IDX_C1_synthpop_2_occupation is created for the table: C1_synthpop_2 in the database
# Processing C1_synthpop_3.csv and C1.json
# Table C1_synthpop_3 is created in the database
# .... The index: IDX_C1_synthpop_3_relationship is created for the table: C1_synthpop_3 in the database
# .... The index: IDX_C1_synthpop_3_income is created for the table: C1_synthpop_3 in the database
# .... The index: IDX_C1_synthpop_3_hours_per_week is created for the table: C1_synthpop_3 in the database
# .... The index: IDX_C1_synthpop_3_marital_status is created for the table: C1_synthpop_3 in the database
# .... The index: IDX_C1_synthpop_3_age is created for the table: C1_synthpop_3 in the database
# .... The index: IDX_C1_synthpop_3_fnlwgt is created for the table: C1_synthpop_3 in the database
# .... The index: IDX_C1_synthpop_3_race is created for the table: C1_synthpop_3 in the database
# .... The index: IDX_C1_synthpop_3_education is created for the table: C1_synthpop_3 in the database
# .... The index: IDX_C1_synthpop_3_native_country is created for the table: C1_synthpop_3 in the database
# .... The index: IDX_C1_synthpop_3_sex is created for the table: C1_synthpop_3 in the database
# .... The index: IDX_C1_synthpop_3_workclass is created for the table: C1_synthpop_3 in the database
# .... The index: IDX_C1_synthpop_3_capital is created for the table: C1_synthpop_3 in the database
# .... The index: IDX_C1_synthpop_3_occupation is created for the table: C1_synthpop_3 in the database
# Processing C1_syn_default_10.csv and C1.json
# Table C1_syn_default_10 is created in the database
# .... The index: IDX_C1_syn_default_10_relationship is created for the table: C1_syn_default_10 in the database
# .... The index: IDX_C1_syn_default_10_income is created for the table: C1_syn_default_10 in the database
# .... The index: IDX_C1_syn_default_10_hours_per_week is created for the table: C1_syn_default_10 in the database
# .... The index: IDX_C1_syn_default_10_marital_status is created for the table: C1_syn_default_10 in the database
# .... The index: IDX_C1_syn_default_10_age is created for the table: C1_syn_default_10 in the database
# .... The index: IDX_C1_syn_default_10_fnlwgt is created for the table: C1_syn_default_10 in the database
# .... The index: IDX_C1_syn_default_10_race is created for the table: C1_syn_default_10 in the database
# .... The index: IDX_C1_syn_default_10_education is created for the table: C1_syn_default_10 in the database
# .... The index: IDX_C1_syn_default_10_native_country is created for the table: C1_syn_default_10 in the database
# .... The index: IDX_C1_syn_default_10_sex is created for the table: C1_syn_default_10 in the database
# .... The index: IDX_C1_syn_default_10_workclass is created for the table: C1_syn_default_10 in the database
# .... The index: IDX_C1_syn_default_10_capital is created for the table: C1_syn_default_10 in the database
# .... The index: IDX_C1_syn_default_10_occupation is created for the table: C1_syn_default_10 in the database
# Processing C1_synthpop_10.csv and C1.json
# Table C1_synthpop_10 is created in the database
# .... The index: IDX_C1_synthpop_10_relationship is created for the table: C1_synthpop_10 in the database
# .... The index: IDX_C1_synthpop_10_income is created for the table: C1_synthpop_10 in the database
# .... The index: IDX_C1_synthpop_10_hours_per_week is created for the table: C1_synthpop_10 in the database
# .... The index: IDX_C1_synthpop_10_marital_status is created for the table: C1_synthpop_10 in the database
# .... The index: IDX_C1_synthpop_10_age is created for the table: C1_synthpop_10 in the database
# .... The index: IDX_C1_synthpop_10_fnlwgt is created for the table: C1_synthpop_10 in the database
# .... The index: IDX_C1_synthpop_10_race is created for the table: C1_synthpop_10 in the database
# .... The index: IDX_C1_synthpop_10_education is created for the table: C1_synthpop_10 in the database
# .... The index: IDX_C1_synthpop_10_native_country is created for the table: C1_synthpop_10 in the database
# .... The index: IDX_C1_synthpop_10_sex is created for the table: C1_synthpop_10 in the database
# .... The index: IDX_C1_synthpop_10_workclass is created for the table: C1_synthpop_10 in the database
# .... The index: IDX_C1_synthpop_10_capital is created for the table: C1_synthpop_10 in the database
# .... The index: IDX_C1_synthpop_10_occupation is created for the table: C1_synthpop_10 in the database
# Processing C1_syn_default_3.csv and C1.json
# Table C1_syn_default_3 is created in the database
# .... The index: IDX_C1_syn_default_3_relationship is created for the table: C1_syn_default_3 in the database
# .... The index: IDX_C1_syn_default_3_income is created for the table: C1_syn_default_3 in the database
# .... The index: IDX_C1_syn_default_3_hours_per_week is created for the table: C1_syn_default_3 in the database
# .... The index: IDX_C1_syn_default_3_marital_status is created for the table: C1_syn_default_3 in the database
# .... The index: IDX_C1_syn_default_3_age is created for the table: C1_syn_default_3 in the database
# .... The index: IDX_C1_syn_default_3_fnlwgt is created for the table: C1_syn_default_3 in the database
# .... The index: IDX_C1_syn_default_3_race is created for the table: C1_syn_default_3 in the database
# .... The index: IDX_C1_syn_default_3_education is created for the table: C1_syn_default_3 in the database
# .... The index: IDX_C1_syn_default_3_native_country is created for the table: C1_syn_default_3 in the database
# .... The index: IDX_C1_syn_default_3_sex is created for the table: C1_syn_default_3 in the database
# .... The index: IDX_C1_syn_default_3_workclass is created for the table: C1_syn_default_3 in the database
# .... The index: IDX_C1_syn_default_3_capital is created for the table: C1_syn_default_3 in the database
# .... The index: IDX_C1_syn_default_3_occupation is created for the table: C1_syn_default_3 in the database
# Processing C1_syn_default_2.csv and C1.json
# Table C1_syn_default_2 is created in the database
# .... The index: IDX_C1_syn_default_2_relationship is created for the table: C1_syn_default_2 in the database
# .... The index: IDX_C1_syn_default_2_income is created for the table: C1_syn_default_2 in the database
# .... The index: IDX_C1_syn_default_2_hours_per_week is created for the table: C1_syn_default_2 in the database
# .... The index: IDX_C1_syn_default_2_marital_status is created for the table: C1_syn_default_2 in the database
# .... The index: IDX_C1_syn_default_2_age is created for the table: C1_syn_default_2 in the database
# .... The index: IDX_C1_syn_default_2_fnlwgt is created for the table: C1_syn_default_2 in the database
# .... The index: IDX_C1_syn_default_2_race is created for the table: C1_syn_default_2 in the database
# .... The index: IDX_C1_syn_default_2_education is created for the table: C1_syn_default_2 in the database
# .... The index: IDX_C1_syn_default_2_native_country is created for the table: C1_syn_default_2 in the database
# .... The index: IDX_C1_syn_default_2_sex is created for the table: C1_syn_default_2 in the database
# .... The index: IDX_C1_syn_default_2_workclass is created for the table: C1_syn_default_2 in the database
# .... The index: IDX_C1_syn_default_2_capital is created for the table: C1_syn_default_2 in the database
# .... The index: IDX_C1_syn_default_2_occupation is created for the table: C1_syn_default_2 in the database
# Processing C1_syn_default_20.csv and C1.json
# Table C1_syn_default_20 is created in the database
# .... The index: IDX_C1_syn_default_20_relationship is created for the table: C1_syn_default_20 in the database
# .... The index: IDX_C1_syn_default_20_income is created for the table: C1_syn_default_20 in the database
# .... The index: IDX_C1_syn_default_20_hours_per_week is created for the table: C1_syn_default_20 in the database
# .... The index: IDX_C1_syn_default_20_marital_status is created for the table: C1_syn_default_20 in the database
# .... The index: IDX_C1_syn_default_20_age is created for the table: C1_syn_default_20 in the database
# .... The index: IDX_C1_syn_default_20_fnlwgt is created for the table: C1_syn_default_20 in the database
# .... The index: IDX_C1_syn_default_20_race is created for the table: C1_syn_default_20 in the database
# .... The index: IDX_C1_syn_default_20_education is created for the table: C1_syn_default_20 in the database
# .... The index: IDX_C1_syn_default_20_native_country is created for the table: C1_syn_default_20 in the database
# .... The index: IDX_C1_syn_default_20_sex is created for the table: C1_syn_default_20 in the database
# .... The index: IDX_C1_syn_default_20_workclass is created for the table: C1_syn_default_20 in the database
# .... The index: IDX_C1_syn_default_20_capital is created for the table: C1_syn_default_20 in the database
# .... The index: IDX_C1_syn_default_20_occupation is created for the table: C1_syn_default_20 in the database
# Processing C1_syn_default_1.csv and C1.json
# Table C1_syn_default_1 already exists in the database
# Processing C1_synthpop_8.csv and C1.json
# Table C1_synthpop_8 is created in the database
# .... The index: IDX_C1_synthpop_8_relationship is created for the table: C1_synthpop_8 in the database
# .... The index: IDX_C1_synthpop_8_income is created for the table: C1_synthpop_8 in the database
# .... The index: IDX_C1_synthpop_8_hours_per_week is created for the table: C1_synthpop_8 in the database
# .... The index: IDX_C1_synthpop_8_marital_status is created for the table: C1_synthpop_8 in the database
# .... The index: IDX_C1_synthpop_8_age is created for the table: C1_synthpop_8 in the database
# .... The index: IDX_C1_synthpop_8_fnlwgt is created for the table: C1_synthpop_8 in the database
# .... The index: IDX_C1_synthpop_8_race is created for the table: C1_synthpop_8 in the database
# .... The index: IDX_C1_synthpop_8_education is created for the table: C1_synthpop_8 in the database
# .... The index: IDX_C1_synthpop_8_native_country is created for the table: C1_synthpop_8 in the database
# .... The index: IDX_C1_synthpop_8_sex is created for the table: C1_synthpop_8 in the database
# .... The index: IDX_C1_synthpop_8_workclass is created for the table: C1_synthpop_8 in the database
# .... The index: IDX_C1_synthpop_8_capital is created for the table: C1_synthpop_8 in the database
# .... The index: IDX_C1_synthpop_8_occupation is created for the table: C1_synthpop_8 in the database
# Processing C1_syn_default_5.csv and C1.json
# Table C1_syn_default_5 is created in the database
# .... The index: IDX_C1_syn_default_5_relationship is created for the table: C1_syn_default_5 in the database
# .... The index: IDX_C1_syn_default_5_income is created for the table: C1_syn_default_5 in the database
# .... The index: IDX_C1_syn_default_5_hours_per_week is created for the table: C1_syn_default_5 in the database
# .... The index: IDX_C1_syn_default_5_marital_status is created for the table: C1_syn_default_5 in the database
# .... The index: IDX_C1_syn_default_5_age is created for the table: C1_syn_default_5 in the database
# .... The index: IDX_C1_syn_default_5_fnlwgt is created for the table: C1_syn_default_5 in the database
# .... The index: IDX_C1_syn_default_5_race is created for the table: C1_syn_default_5 in the database
# .... The index: IDX_C1_syn_default_5_education is created for the table: C1_syn_default_5 in the database
# .... The index: IDX_C1_syn_default_5_native_country is created for the table: C1_syn_default_5 in the database
# .... The index: IDX_C1_syn_default_5_sex is created for the table: C1_syn_default_5 in the database
# .... The index: IDX_C1_syn_default_5_workclass is created for the table: C1_syn_default_5 in the database
# .... The index: IDX_C1_syn_default_5_capital is created for the table: C1_syn_default_5 in the database
# .... The index: IDX_C1_syn_default_5_occupation is created for the table: C1_syn_default_5 in the database
# Processing C1_syn_default_4.csv and C1.json
# Table C1_syn_default_4 is created in the database
# .... The index: IDX_C1_syn_default_4_relationship is created for the table: C1_syn_default_4 in the database
# .... The index: IDX_C1_syn_default_4_income is created for the table: C1_syn_default_4 in the database
# .... The index: IDX_C1_syn_default_4_hours_per_week is created for the table: C1_syn_default_4 in the database
# .... The index: IDX_C1_syn_default_4_marital_status is created for the table: C1_syn_default_4 in the database
# .... The index: IDX_C1_syn_default_4_age is created for the table: C1_syn_default_4 in the database
# .... The index: IDX_C1_syn_default_4_fnlwgt is created for the table: C1_syn_default_4 in the database
# .... The index: IDX_C1_syn_default_4_race is created for the table: C1_syn_default_4 in the database
# .... The index: IDX_C1_syn_default_4_education is created for the table: C1_syn_default_4 in the database
# .... The index: IDX_C1_syn_default_4_native_country is created for the table: C1_syn_default_4 in the database
# .... The index: IDX_C1_syn_default_4_sex is created for the table: C1_syn_default_4 in the database
# .... The index: IDX_C1_syn_default_4_workclass is created for the table: C1_syn_default_4 in the database
# .... The index: IDX_C1_syn_default_4_capital is created for the table: C1_syn_default_4 in the database
# .... The index: IDX_C1_syn_default_4_occupation is created for the table: C1_syn_default_4 in the database
# Processing C1_synthpop_9.csv and C1.json
# Table C1_synthpop_9 is created in the database
# .... The index: IDX_C1_synthpop_9_relationship is created for the table: C1_synthpop_9 in the database
# .... The index: IDX_C1_synthpop_9_income is created for the table: C1_synthpop_9 in the database
# .... The index: IDX_C1_synthpop_9_hours_per_week is created for the table: C1_synthpop_9 in the database
# .... The index: IDX_C1_synthpop_9_marital_status is created for the table: C1_synthpop_9 in the database
# .... The index: IDX_C1_synthpop_9_age is created for the table: C1_synthpop_9 in the database
# .... The index: IDX_C1_synthpop_9_fnlwgt is created for the table: C1_synthpop_9 in the database
# .... The index: IDX_C1_synthpop_9_race is created for the table: C1_synthpop_9 in the database
# .... The index: IDX_C1_synthpop_9_education is created for the table: C1_synthpop_9 in the database
# .... The index: IDX_C1_synthpop_9_native_country is created for the table: C1_synthpop_9 in the database
# .... The index: IDX_C1_synthpop_9_sex is created for the table: C1_synthpop_9 in the database
# .... The index: IDX_C1_synthpop_9_workclass is created for the table: C1_synthpop_9 in the database
# .... The index: IDX_C1_synthpop_9_capital is created for the table: C1_synthpop_9 in the database
# .... The index: IDX_C1_synthpop_9_occupation is created for the table: C1_synthpop_9 in the database
# Processing C1_syn_06.csv and C1.json
# Table C1_syn_06 is created in the database
# .... The index: IDX_C1_syn_06_relationship is created for the table: C1_syn_06 in the database
# .... The index: IDX_C1_syn_06_income is created for the table: C1_syn_06 in the database
# .... The index: IDX_C1_syn_06_hours_per_week is created for the table: C1_syn_06 in the database
# .... The index: IDX_C1_syn_06_marital_status is created for the table: C1_syn_06 in the database
# .... The index: IDX_C1_syn_06_age is created for the table: C1_syn_06 in the database
# .... The index: IDX_C1_syn_06_fnlwgt is created for the table: C1_syn_06 in the database
# .... The index: IDX_C1_syn_06_race is created for the table: C1_syn_06 in the database
# .... The index: IDX_C1_syn_06_education is created for the table: C1_syn_06 in the database
# .... The index: IDX_C1_syn_06_native_country is created for the table: C1_syn_06 in the database
# .... The index: IDX_C1_syn_06_sex is created for the table: C1_syn_06 in the database
# .... The index: IDX_C1_syn_06_workclass is created for the table: C1_syn_06 in the database
# .... The index: IDX_C1_syn_06_capital is created for the table: C1_syn_06 in the database
# .... The index: IDX_C1_syn_06_occupation is created for the table: C1_syn_06 in the database
# Processing C1_syn_default_18.csv and C1.json
# Table C1_syn_default_18 is created in the database
# .... The index: IDX_C1_syn_default_18_relationship is created for the table: C1_syn_default_18 in the database
# .... The index: IDX_C1_syn_default_18_income is created for the table: C1_syn_default_18 in the database
# .... The index: IDX_C1_syn_default_18_hours_per_week is created for the table: C1_syn_default_18 in the database
# .... The index: IDX_C1_syn_default_18_marital_status is created for the table: C1_syn_default_18 in the database
# .... The index: IDX_C1_syn_default_18_age is created for the table: C1_syn_default_18 in the database
# .... The index: IDX_C1_syn_default_18_fnlwgt is created for the table: C1_syn_default_18 in the database
# .... The index: IDX_C1_syn_default_18_race is created for the table: C1_syn_default_18 in the database
# .... The index: IDX_C1_syn_default_18_education is created for the table: C1_syn_default_18 in the database
# .... The index: IDX_C1_syn_default_18_native_country is created for the table: C1_syn_default_18 in the database
# .... The index: IDX_C1_syn_default_18_sex is created for the table: C1_syn_default_18 in the database
# .... The index: IDX_C1_syn_default_18_workclass is created for the table: C1_syn_default_18 in the database
# .... The index: IDX_C1_syn_default_18_capital is created for the table: C1_syn_default_18 in the database
# .... The index: IDX_C1_syn_default_18_occupation is created for the table: C1_syn_default_18 in the database
# Processing C1_syn_default_6.csv and C1.json
# Table C1_syn_default_6 is created in the database
# .... The index: IDX_C1_syn_default_6_relationship is created for the table: C1_syn_default_6 in the database
# .... The index: IDX_C1_syn_default_6_income is created for the table: C1_syn_default_6 in the database
# .... The index: IDX_C1_syn_default_6_hours_per_week is created for the table: C1_syn_default_6 in the database
# .... The index: IDX_C1_syn_default_6_marital_status is created for the table: C1_syn_default_6 in the database
# .... The index: IDX_C1_syn_default_6_age is created for the table: C1_syn_default_6 in the database
# .... The index: IDX_C1_syn_default_6_fnlwgt is created for the table: C1_syn_default_6 in the database
# .... The index: IDX_C1_syn_default_6_race is created for the table: C1_syn_default_6 in the database
# .... The index: IDX_C1_syn_default_6_education is created for the table: C1_syn_default_6 in the database
# .... The index: IDX_C1_syn_default_6_native_country is created for the table: C1_syn_default_6 in the database
# .... The index: IDX_C1_syn_default_6_sex is created for the table: C1_syn_default_6 in the database
# .... The index: IDX_C1_syn_default_6_workclass is created for the table: C1_syn_default_6 in the database
# .... The index: IDX_C1_syn_default_6_capital is created for the table: C1_syn_default_6 in the database
# .... The index: IDX_C1_syn_default_6_occupation is created for the table: C1_syn_default_6 in the database
# Processing C1_syn_default_7.csv and C1.json
# Table C1_syn_default_7 is created in the database
# .... The index: IDX_C1_syn_default_7_relationship is created for the table: C1_syn_default_7 in the database
# .... The index: IDX_C1_syn_default_7_income is created for the table: C1_syn_default_7 in the database
# .... The index: IDX_C1_syn_default_7_hours_per_week is created for the table: C1_syn_default_7 in the database
# .... The index: IDX_C1_syn_default_7_marital_status is created for the table: C1_syn_default_7 in the database
# .... The index: IDX_C1_syn_default_7_age is created for the table: C1_syn_default_7 in the database
# .... The index: IDX_C1_syn_default_7_fnlwgt is created for the table: C1_syn_default_7 in the database
# .... The index: IDX_C1_syn_default_7_race is created for the table: C1_syn_default_7 in the database
# .... The index: IDX_C1_syn_default_7_education is created for the table: C1_syn_default_7 in the database
# .... The index: IDX_C1_syn_default_7_native_country is created for the table: C1_syn_default_7 in the database
# .... The index: IDX_C1_syn_default_7_sex is created for the table: C1_syn_default_7 in the database
# .... The index: IDX_C1_syn_default_7_workclass is created for the table: C1_syn_default_7 in the database
# .... The index: IDX_C1_syn_default_7_capital is created for the table: C1_syn_default_7 in the database
# .... The index: IDX_C1_syn_default_7_occupation is created for the table: C1_syn_default_7 in the database
# Processing C1_syn_39.csv and C1.json
# Table C1_syn_39 is created in the database
# .... The index: IDX_C1_syn_39_relationship is created for the table: C1_syn_39 in the database
# .... The index: IDX_C1_syn_39_income is created for the table: C1_syn_39 in the database
# .... The index: IDX_C1_syn_39_hours_per_week is created for the table: C1_syn_39 in the database
# .... The index: IDX_C1_syn_39_marital_status is created for the table: C1_syn_39 in the database
# .... The index: IDX_C1_syn_39_age is created for the table: C1_syn_39 in the database
# .... The index: IDX_C1_syn_39_fnlwgt is created for the table: C1_syn_39 in the database
# .... The index: IDX_C1_syn_39_race is created for the table: C1_syn_39 in the database
# .... The index: IDX_C1_syn_39_education is created for the table: C1_syn_39 in the database
# .... The index: IDX_C1_syn_39_native_country is created for the table: C1_syn_39 in the database
# .... The index: IDX_C1_syn_39_sex is created for the table: C1_syn_39 in the database
# .... The index: IDX_C1_syn_39_workclass is created for the table: C1_syn_39 in the database
# .... The index: IDX_C1_syn_39_capital is created for the table: C1_syn_39 in the database
# .... The index: IDX_C1_syn_39_occupation is created for the table: C1_syn_39 in the database
# Processing C1_syn_default_19.csv and C1.json
# Table C1_syn_default_19 is created in the database
# .... The index: IDX_C1_syn_default_19_relationship is created for the table: C1_syn_default_19 in the database
# .... The index: IDX_C1_syn_default_19_income is created for the table: C1_syn_default_19 in the database
# .... The index: IDX_C1_syn_default_19_hours_per_week is created for the table: C1_syn_default_19 in the database
# .... The index: IDX_C1_syn_default_19_marital_status is created for the table: C1_syn_default_19 in the database
# .... The index: IDX_C1_syn_default_19_age is created for the table: C1_syn_default_19 in the database
# .... The index: IDX_C1_syn_default_19_fnlwgt is created for the table: C1_syn_default_19 in the database
# .... The index: IDX_C1_syn_default_19_race is created for the table: C1_syn_default_19 in the database
# .... The index: IDX_C1_syn_default_19_education is created for the table: C1_syn_default_19 in the database
# .... The index: IDX_C1_syn_default_19_native_country is created for the table: C1_syn_default_19 in the database
# .... The index: IDX_C1_syn_default_19_sex is created for the table: C1_syn_default_19 in the database
# .... The index: IDX_C1_syn_default_19_workclass is created for the table: C1_syn_default_19 in the database
# .... The index: IDX_C1_syn_default_19_capital is created for the table: C1_syn_default_19 in the database
# .... The index: IDX_C1_syn_default_19_occupation is created for the table: C1_syn_default_19 in the database
# Processing C10_syn_06.csv and C10.json
# Table C10_syn_06 is created in the database
# .... The index: IDX_C10_syn_06_hsv_total_h_std is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_cervix_specularities_area is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_hsv_cervix_s_std is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_hsv_total_h_mean is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_fit_ellipse_total is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_rgb_cervix_r_mean is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_fit_cervix_bbox_rate is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_cervix_area is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_rgb_cervix_b_mean is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_rgb_total_b_mean_minus_std is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_hsv_cervix_v_mean is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_hsv_total_v_std is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_fit_circle_rate is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_fit_cervix_hull_rate is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_speculum_specularities_area is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_walls_specularities_area is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_fit_circle_total is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_rgb_total_b_mean is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_hsv_total_s_mean is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_speculum_area is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_dist_to_center_cervix is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_rgb_cervix_b_mean_plus_std is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_rgb_cervix_g_mean_plus_std is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_dist_to_center_os is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_rgb_total_g_mean_plus_std is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_os_artifacts_area is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_rgb_cervix_b_mean_minus_std is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_hsv_cervix_v_std is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_artifacts_area is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_rgb_total_g_mean_minus_std is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_speculum_artifacts_area is created for the table: C10_syn_06 in the database
# ...
# .... The index: IDX_trial2_syn_39_AGEGR1 is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_AGEGR2N is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_METLIV is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_AVAL is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_METKIDNY is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_REGNGR2 is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_BSA is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_METOTH is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_EVNTDESC_TIME2DTH is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_ECOG is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_BCA199 is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_DSREASN is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_TRTP is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_ADT is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_BCAGR1 is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_REGNGR2N is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_R10XGR1 is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_METDGR1 is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_TRTA is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_TRTAN is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_PARAMCD is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_DIAGGR1N is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_AGEGR1N is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_PARAM is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_METDGR1N is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_METDDUR is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_PTLOC is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_HGTGR1 is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_METLUNG is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_HEIGHT is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_AVAL_TDTHSEN2 is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_STATUS is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_BCAGR1N is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_REGNGR1N is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_DGMTDUR is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_DTHFL is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_HGTGR1N is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_WEIGHT is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_EVNTDESC_TDTHSEN1 is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_DEATHDY is created for the table: trial2_syn_39 in the database
# Processing trial4_syn_39.csv and trial4.json
# Table trial4_syn_39 is created in the database
# .... The index: IDX_trial4_syn_39_BMMTR5 is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_BMMTR3 is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_B_WEIGHT is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_VISITDY is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_RACE is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_DIAGMONS is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Carcinoembryonic_Antigen_LBSTRESN is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Albumin_LBSTRESN is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Creatinine_LBSTRESN is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Lactate_Dehydrogenase_LBSTRESN is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_White_Blood_Cells_LBSTUNIT is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_SEX is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_DIAGTYPE is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_X3_LSLD is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_DTHX is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Platelets_LBSTUNIT is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_X1_LSLD is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Alkaline_Phosphatase_LBSTUNIT is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_BMMTR4 is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_SXANY is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_BMMTNM7 is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_X2_LSLD is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_X5_LSLD is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_BMMTNM6 is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_X3_LSSITE is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_TRT is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_BMMTNM1 is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_X2_LSSITE is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Platelets_LBSTRESN is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Creatinine_LBSTUNIT is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Albumin_LBSTUNIT is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_BMMTR2 is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_White_Blood_Cells_LBSTRESN is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_X1_LSSITE is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Hemoglobin_LBSTUNIT is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_X4_LSSITE is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Hemoglobin_LBSTRESN is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_BMMTNM3 is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Alkaline_Phosphatase_LBSTRESN is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_PFSDYCR is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_LSSLD is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Carcinoembryonic_Antigen_LBSTUNIT is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Lactate_Dehydrogenase_LBSTUNIT is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_BMMTR7 is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_PFSCR is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_BMMTNM2 is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_BMMTR6 is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_ATRT is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_X5_LSSITE is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_BMMTNM4 is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_X4_LSLD is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_AGE is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_B_ECOG is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_HISSUBTY is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_BMMTR1 is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_DTHDYX is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_WEIGHT is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_BMMTNM5 is created for the table: trial4_syn_39 in the database
# Processing trial4_syn_06.csv and trial4.json
# Table trial4_syn_06 is created in the database
# .... The index: IDX_trial4_syn_06_BMMTR5 is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_BMMTR3 is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_B_WEIGHT is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_VISITDY is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_RACE is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_DIAGMONS is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Carcinoembryonic_Antigen_LBSTRESN is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Albumin_LBSTRESN is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Creatinine_LBSTRESN is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Lactate_Dehydrogenase_LBSTRESN is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_White_Blood_Cells_LBSTUNIT is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_SEX is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_DIAGTYPE is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_X3_LSLD is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_DTHX is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Platelets_LBSTUNIT is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_X1_LSLD is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Alkaline_Phosphatase_LBSTUNIT is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_BMMTR4 is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_SXANY is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_BMMTNM7 is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_X2_LSLD is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_X5_LSLD is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_BMMTNM6 is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_X3_LSSITE is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_TRT is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_BMMTNM1 is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_X2_LSSITE is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Platelets_LBSTRESN is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Creatinine_LBSTUNIT is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Albumin_LBSTUNIT is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_BMMTR2 is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_White_Blood_Cells_LBSTRESN is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_X1_LSSITE is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Hemoglobin_LBSTUNIT is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_X4_LSSITE is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Hemoglobin_LBSTRESN is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_BMMTNM3 is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Alkaline_Phosphatase_LBSTRESN is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_PFSDYCR is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_LSSLD is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Carcinoembryonic_Antigen_LBSTUNIT is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Lactate_Dehydrogenase_LBSTUNIT is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_BMMTR7 is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_PFSCR is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_BMMTNM2 is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_BMMTR6 is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_ATRT is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_X5_LSSITE is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_BMMTNM4 is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_X4_LSLD is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_AGE is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_B_ECOG is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_HISSUBTY is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_BMMTR1 is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_DTHDYX is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_WEIGHT is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_BMMTNM5 is created for the table: trial4_syn_06 in the database

# %%
#save tabula test set for late usage in testing fuzzy SQL
with open('tabular_test_set.json','w') as f:
    json.dump(tabular_test_set, f)
