# %%
import sys
sys.path.append('/home/samer/projects/fuzzy_sql/src')

from fuzzy_sql.fuzzy_sql import *
import json
import os
from pathlib import Path
import glob

# %%
# set directories
root_dir = Path('/home/samer/projects/fuzzy_sql')
metadata_dir = os.path.join(root_dir, 'data/sdgd/processed/metadata')
real_dir = os.path.join(root_dir, 'data/sdgd/processed/real')
syn_dir = os.path.join(root_dir, 'data/sdgd/processed/synthetic')
db_path = os.path.join(root_dir, 'db/sdgd.db')

# %%
# poplulate filenames from folder into a list
real_fnames=glob.glob(real_dir+'/*.csv')
real_fnames=[Path(real_fname).stem for real_fname in real_fnames]
real_fnames.sort()


# generate filenames
meta_jsons=[]
real_csvs=[]
for real_fname in real_fnames:
    meta_jsons.append(real_fname+'.json')
    real_csvs.append(real_fname+'.csv')

# %%
# connect to db
conn = sqlite3.connect(db_path)

# %%
# import real data into database
for real_csv,meta_json in zip(real_csvs,meta_jsons):
    #Import real
    data,_=prep_data_for_db(os.path.join(real_dir,real_csv)) # Note: This function  can be used to quickly generate metadata template, but this is not shown here.
    with open(os.path.join(metadata_dir, meta_json), 'r') as f:
        metadata=json.load(f)
    print(f"Processing {real_csv} and {meta_json} ")
    candidate_db_idx=get_vars_to_index(metadata,data)
    table_name=Path(real_csv).stem
    make_table(table_name, data, conn,indx_vars=candidate_db_idx)
# Out:
# Processing C1.csv and C1.json
# Table C1 already exists in the database
# Processing C10.csv and C10.json
# Table C10 already exists in the database
# Processing C11.csv and C11.json
# Table C11 already exists in the database
# Processing C12.csv and C12.json
# Table C12 already exists in the database
# Processing C13.csv and C13.json
# Table C13 already exists in the database
# Processing C14.csv and C14.json
# Table C14 already exists in the database
# Processing C15.csv and C15.json
# Table C15 already exists in the database
# Processing C16.csv and C16.json
# Table C16 already exists in the database
# Processing C17.csv and C17.json
# Table C17 already exists in the database
# Processing C18.csv and C18.json
# Table C18 already exists in the database
# Processing C19.csv and C19.json
# Table C19 already exists in the database
# Processing C2.csv and C2.json
# Table C2 already exists in the database
# Processing C20.csv and C20.json
# Table C20 already exists in the database
# Processing C21.csv and C21.json
# Table C21 already exists in the database
# Processing C22.csv and C22.json
# Table C22 already exists in the database
# Processing C23.csv and C23.json
# Table C23 already exists in the database
# Processing C24.csv and C24.json
# Table C24 already exists in the database
# Processing C25.csv and C25.json
# Table C25 already exists in the database
# Processing C26.csv and C26.json
# Table C26 already exists in the database
# Processing C27.csv and C27.json
# Table C27 already exists in the database
# Processing C28.csv and C28.json
# Table C28 already exists in the database
# Processing C3.csv and C3.json
# Table C3 already exists in the database
# Processing C4.csv and C4.json
# Table C4 already exists in the database
# Processing C5.csv and C5.json
# Table C5 already exists in the database
# Processing C6.csv and C6.json
# Table C6 already exists in the database
# Processing C7.csv and C7.json
# Table C7 already exists in the database
# Processing C8.csv and C8.json
# Table C8 already exists in the database
# Processing C9.csv and C9.json
# Table C9 already exists in the database
# Processing cchs.csv and cchs.json
# Table cchs already exists in the database
# Processing dad.csv and dad.json
# Table dad already exists in the database
# Processing danish.csv and danish.json
# Table danish already exists in the database
# Processing n0147.csv and n0147.json
# Table n0147 already exists in the database
# Processing n0147DFS.csv and n0147DFS.json
# Table n0147DFS already exists in the database
# Processing n0147OS.csv and n0147OS.json
# Table n0147OS already exists in the database
# Processing oncovid_dtd.csv and oncovid_dtd.json
# Table oncovid_dtd already exists in the database
# Processing trial1.csv and trial1.json
# Table trial1 already exists in the database
# Processing trial2.csv and trial2.json
# Table trial2 already exists in the database
# Processing trial3.csv and trial3.json
# Table trial3 already exists in the database
# Processing trial4.csv and trial4.json
# Table trial4 already exists in the database
# Processing trial5.csv and trial5.json
# Table trial5 already exists in the database
# Processing trial6.csv and trial6.json
# Table trial6 already exists in the database

# %%
def find_syn_fnames(syn_data_dir: Path, real_names: list) -> dict:
    syn_dict={}
    for real_name_i in real_names:
        catch_file=[]
        for syn_name_i in os.listdir(syn_data_dir):
            if syn_name_i.startswith(real_name_i+'_'):
                catch_file.append(Path(syn_name_i).stem)
        syn_dict[real_name_i]=catch_file
    print('Extracted the names of all available synthetic datasets corresponding to {} real datasets'.format(str(len(syn_dict))))
    return syn_dict

# %%
# import syn data into database
syn_dict=find_syn_fnames(syn_dir,real_fnames)

#drop datasets with no synthetic data available 
tabular_test_set={key:val for key,val in syn_dict.items() if len(val)!=0}
# Out:
# Extracted the names of all available synthetic datasets corresponding to 41 real datasets

# %%
#import synthetic data into database
for key in tabular_test_set.keys():
    meta_json=key+'.json'
    for syn_table_name in tabular_test_set[key]:
        syn_csv=syn_table_name+'.csv'
        data,_=prep_data_for_db(os.path.join(syn_dir,syn_csv)) # Note: This function  can be used to quickly generate metadata template, but this is not shown here.
        with open(os.path.join(metadata_dir, meta_json), 'r') as f:
            metadata=json.load(f)
        print(f"Processing {syn_csv} and {meta_json} ")
        candidate_db_idx=get_vars_to_index(metadata,data)
        table_name=Path(syn_csv).stem
        make_table(table_name, data, conn,indx_vars=candidate_db_idx)
# Out:
# Processing C1_syn_default_19.csv and C1.json
# Table C1_syn_default_19 is created in the database
# .... The index: IDX_C1_syn_default_19_capital is created for the table: C1_syn_default_19 in the database
# .... The index: IDX_C1_syn_default_19_fnlwgt is created for the table: C1_syn_default_19 in the database
# .... The index: IDX_C1_syn_default_19_native_country is created for the table: C1_syn_default_19 in the database
# .... The index: IDX_C1_syn_default_19_age is created for the table: C1_syn_default_19 in the database
# Processing C1_syn_default_3.csv and C1.json
# Table C1_syn_default_3 is created in the database
# .... The index: IDX_C1_syn_default_3_capital is created for the table: C1_syn_default_3 in the database
# .... The index: IDX_C1_syn_default_3_fnlwgt is created for the table: C1_syn_default_3 in the database
# .... The index: IDX_C1_syn_default_3_native_country is created for the table: C1_syn_default_3 in the database
# .... The index: IDX_C1_syn_default_3_age is created for the table: C1_syn_default_3 in the database
# Processing C1_synthpop_7.csv and C1.json
# Table C1_synthpop_7 is created in the database
# .... The index: IDX_C1_synthpop_7_fnlwgt is created for the table: C1_synthpop_7 in the database
# .... The index: IDX_C1_synthpop_7_age is created for the table: C1_synthpop_7 in the database
# .... The index: IDX_C1_synthpop_7_capital is created for the table: C1_synthpop_7 in the database
# .... The index: IDX_C1_synthpop_7_native_country is created for the table: C1_synthpop_7 in the database
# .... The index: IDX_C1_synthpop_7_hours_per_week is created for the table: C1_synthpop_7 in the database
# Processing C1_syn_default_16.csv and C1.json
# Table C1_syn_default_16 is created in the database
# .... The index: IDX_C1_syn_default_16_capital is created for the table: C1_syn_default_16 in the database
# .... The index: IDX_C1_syn_default_16_fnlwgt is created for the table: C1_syn_default_16 in the database
# .... The index: IDX_C1_syn_default_16_native_country is created for the table: C1_syn_default_16 in the database
# .... The index: IDX_C1_syn_default_16_age is created for the table: C1_syn_default_16 in the database
# Processing C1_syn_default_17.csv and C1.json
# Table C1_syn_default_17 is created in the database
# .... The index: IDX_C1_syn_default_17_capital is created for the table: C1_syn_default_17 in the database
# .... The index: IDX_C1_syn_default_17_fnlwgt is created for the table: C1_syn_default_17 in the database
# .... The index: IDX_C1_syn_default_17_native_country is created for the table: C1_syn_default_17 in the database
# .... The index: IDX_C1_syn_default_17_age is created for the table: C1_syn_default_17 in the database
# Processing C1_syn_default_11.csv and C1.json
# Table C1_syn_default_11 is created in the database
# .... The index: IDX_C1_syn_default_11_capital is created for the table: C1_syn_default_11 in the database
# .... The index: IDX_C1_syn_default_11_fnlwgt is created for the table: C1_syn_default_11 in the database
# .... The index: IDX_C1_syn_default_11_native_country is created for the table: C1_syn_default_11 in the database
# .... The index: IDX_C1_syn_default_11_age is created for the table: C1_syn_default_11 in the database
# Processing C1_syn_default_15.csv and C1.json
# Table C1_syn_default_15 is created in the database
# .... The index: IDX_C1_syn_default_15_capital is created for the table: C1_syn_default_15 in the database
# .... The index: IDX_C1_syn_default_15_fnlwgt is created for the table: C1_syn_default_15 in the database
# .... The index: IDX_C1_syn_default_15_native_country is created for the table: C1_syn_default_15 in the database
# .... The index: IDX_C1_syn_default_15_age is created for the table: C1_syn_default_15 in the database
# Processing C1_synthpop_1.csv and C1.json
# Table C1_synthpop_1 is created in the database
# .... The index: IDX_C1_synthpop_1_fnlwgt is created for the table: C1_synthpop_1 in the database
# .... The index: IDX_C1_synthpop_1_age is created for the table: C1_synthpop_1 in the database
# .... The index: IDX_C1_synthpop_1_capital is created for the table: C1_synthpop_1 in the database
# .... The index: IDX_C1_synthpop_1_native_country is created for the table: C1_synthpop_1 in the database
# .... The index: IDX_C1_synthpop_1_hours_per_week is created for the table: C1_synthpop_1 in the database
# Processing C1_synthpop_6.csv and C1.json
# Table C1_synthpop_6 is created in the database
# .... The index: IDX_C1_synthpop_6_fnlwgt is created for the table: C1_synthpop_6 in the database
# .... The index: IDX_C1_synthpop_6_age is created for the table: C1_synthpop_6 in the database
# .... The index: IDX_C1_synthpop_6_capital is created for the table: C1_synthpop_6 in the database
# .... The index: IDX_C1_synthpop_6_native_country is created for the table: C1_synthpop_6 in the database
# .... The index: IDX_C1_synthpop_6_hours_per_week is created for the table: C1_synthpop_6 in the database
# Processing C1_syn_default_9.csv and C1.json
# Table C1_syn_default_9 is created in the database
# .... The index: IDX_C1_syn_default_9_capital is created for the table: C1_syn_default_9 in the database
# .... The index: IDX_C1_syn_default_9_fnlwgt is created for the table: C1_syn_default_9 in the database
# .... The index: IDX_C1_syn_default_9_native_country is created for the table: C1_syn_default_9 in the database
# .... The index: IDX_C1_syn_default_9_age is created for the table: C1_syn_default_9 in the database
# Processing C1_syn_default_1.csv and C1.json
# Table C1_syn_default_1 already exists in the database
# Processing C1_synthpop_10.csv and C1.json
# Table C1_synthpop_10 is created in the database
# .... The index: IDX_C1_synthpop_10_fnlwgt is created for the table: C1_synthpop_10 in the database
# .... The index: IDX_C1_synthpop_10_age is created for the table: C1_synthpop_10 in the database
# .... The index: IDX_C1_synthpop_10_capital is created for the table: C1_synthpop_10 in the database
# .... The index: IDX_C1_synthpop_10_native_country is created for the table: C1_synthpop_10 in the database
# .... The index: IDX_C1_synthpop_10_hours_per_week is created for the table: C1_synthpop_10 in the database
# Processing C1_syn_default_20.csv and C1.json
# Table C1_syn_default_20 is created in the database
# .... The index: IDX_C1_syn_default_20_capital is created for the table: C1_syn_default_20 in the database
# .... The index: IDX_C1_syn_default_20_fnlwgt is created for the table: C1_syn_default_20 in the database
# .... The index: IDX_C1_syn_default_20_native_country is created for the table: C1_syn_default_20 in the database
# .... The index: IDX_C1_syn_default_20_age is created for the table: C1_syn_default_20 in the database
# Processing C1_synthpop_2.csv and C1.json
# Table C1_synthpop_2 is created in the database
# .... The index: IDX_C1_synthpop_2_fnlwgt is created for the table: C1_synthpop_2 in the database
# .... The index: IDX_C1_synthpop_2_age is created for the table: C1_synthpop_2 in the database
# .... The index: IDX_C1_synthpop_2_capital is created for the table: C1_synthpop_2 in the database
# .... The index: IDX_C1_synthpop_2_native_country is created for the table: C1_synthpop_2 in the database
# .... The index: IDX_C1_synthpop_2_hours_per_week is created for the table: C1_synthpop_2 in the database
# Processing C1_syn_default_14.csv and C1.json
# Table C1_syn_default_14 is created in the database
# .... The index: IDX_C1_syn_default_14_capital is created for the table: C1_syn_default_14 in the database
# .... The index: IDX_C1_syn_default_14_fnlwgt is created for the table: C1_syn_default_14 in the database
# .... The index: IDX_C1_syn_default_14_native_country is created for the table: C1_syn_default_14 in the database
# .... The index: IDX_C1_syn_default_14_age is created for the table: C1_syn_default_14 in the database
# Processing C1_syn_default_2.csv and C1.json
# Table C1_syn_default_2 is created in the database
# .... The index: IDX_C1_syn_default_2_capital is created for the table: C1_syn_default_2 in the database
# .... The index: IDX_C1_syn_default_2_fnlwgt is created for the table: C1_syn_default_2 in the database
# .... The index: IDX_C1_syn_default_2_native_country is created for the table: C1_syn_default_2 in the database
# .... The index: IDX_C1_syn_default_2_age is created for the table: C1_syn_default_2 in the database
# Processing C1_syn_default_10.csv and C1.json
# Table C1_syn_default_10 is created in the database
# .... The index: IDX_C1_syn_default_10_capital is created for the table: C1_syn_default_10 in the database
# .... The index: IDX_C1_syn_default_10_fnlwgt is created for the table: C1_syn_default_10 in the database
# .... The index: IDX_C1_syn_default_10_native_country is created for the table: C1_syn_default_10 in the database
# .... The index: IDX_C1_syn_default_10_age is created for the table: C1_syn_default_10 in the database
# Processing C1_synthpop_4.csv and C1.json
# Table C1_synthpop_4 is created in the database
# .... The index: IDX_C1_synthpop_4_fnlwgt is created for the table: C1_synthpop_4 in the database
# .... The index: IDX_C1_synthpop_4_age is created for the table: C1_synthpop_4 in the database
# .... The index: IDX_C1_synthpop_4_capital is created for the table: C1_synthpop_4 in the database
# .... The index: IDX_C1_synthpop_4_native_country is created for the table: C1_synthpop_4 in the database
# .... The index: IDX_C1_synthpop_4_hours_per_week is created for the table: C1_synthpop_4 in the database
# Processing C1_syn_default_13.csv and C1.json
# Table C1_syn_default_13 is created in the database
# .... The index: IDX_C1_syn_default_13_capital is created for the table: C1_syn_default_13 in the database
# .... The index: IDX_C1_syn_default_13_fnlwgt is created for the table: C1_syn_default_13 in the database
# .... The index: IDX_C1_syn_default_13_native_country is created for the table: C1_syn_default_13 in the database
# .... The index: IDX_C1_syn_default_13_age is created for the table: C1_syn_default_13 in the database
# Processing C1_syn_default_8.csv and C1.json
# Table C1_syn_default_8 is created in the database
# .... The index: IDX_C1_syn_default_8_capital is created for the table: C1_syn_default_8 in the database
# .... The index: IDX_C1_syn_default_8_fnlwgt is created for the table: C1_syn_default_8 in the database
# .... The index: IDX_C1_syn_default_8_native_country is created for the table: C1_syn_default_8 in the database
# .... The index: IDX_C1_syn_default_8_age is created for the table: C1_syn_default_8 in the database
# Processing C1_synthpop_9.csv and C1.json
# Table C1_synthpop_9 is created in the database
# .... The index: IDX_C1_synthpop_9_fnlwgt is created for the table: C1_synthpop_9 in the database
# .... The index: IDX_C1_synthpop_9_age is created for the table: C1_synthpop_9 in the database
# .... The index: IDX_C1_synthpop_9_capital is created for the table: C1_synthpop_9 in the database
# .... The index: IDX_C1_synthpop_9_native_country is created for the table: C1_synthpop_9 in the database
# .... The index: IDX_C1_synthpop_9_hours_per_week is created for the table: C1_synthpop_9 in the database
# Processing C1_synthpop_8.csv and C1.json
# Table C1_synthpop_8 is created in the database
# .... The index: IDX_C1_synthpop_8_fnlwgt is created for the table: C1_synthpop_8 in the database
# .... The index: IDX_C1_synthpop_8_age is created for the table: C1_synthpop_8 in the database
# .... The index: IDX_C1_synthpop_8_capital is created for the table: C1_synthpop_8 in the database
# .... The index: IDX_C1_synthpop_8_native_country is created for the table: C1_synthpop_8 in the database
# .... The index: IDX_C1_synthpop_8_hours_per_week is created for the table: C1_synthpop_8 in the database
# Processing C1_syn_default_12.csv and C1.json
# Table C1_syn_default_12 is created in the database
# .... The index: IDX_C1_syn_default_12_capital is created for the table: C1_syn_default_12 in the database
# .... The index: IDX_C1_syn_default_12_fnlwgt is created for the table: C1_syn_default_12 in the database
# .... The index: IDX_C1_syn_default_12_native_country is created for the table: C1_syn_default_12 in the database
# .... The index: IDX_C1_syn_default_12_age is created for the table: C1_syn_default_12 in the database
# Processing C1_syn_default_4.csv and C1.json
# Table C1_syn_default_4 is created in the database
# .... The index: IDX_C1_syn_default_4_capital is created for the table: C1_syn_default_4 in the database
# .... The index: IDX_C1_syn_default_4_fnlwgt is created for the table: C1_syn_default_4 in the database
# .... The index: IDX_C1_syn_default_4_native_country is created for the table: C1_syn_default_4 in the database
# .... The index: IDX_C1_syn_default_4_age is created for the table: C1_syn_default_4 in the database
# Processing C1_syn_default_7.csv and C1.json
# Table C1_syn_default_7 is created in the database
# .... The index: IDX_C1_syn_default_7_capital is created for the table: C1_syn_default_7 in the database
# .... The index: IDX_C1_syn_default_7_fnlwgt is created for the table: C1_syn_default_7 in the database
# .... The index: IDX_C1_syn_default_7_native_country is created for the table: C1_syn_default_7 in the database
# .... The index: IDX_C1_syn_default_7_age is created for the table: C1_syn_default_7 in the database
# Processing C1_syn_default_5.csv and C1.json
# Table C1_syn_default_5 is created in the database
# .... The index: IDX_C1_syn_default_5_capital is created for the table: C1_syn_default_5 in the database
# .... The index: IDX_C1_syn_default_5_fnlwgt is created for the table: C1_syn_default_5 in the database
# .... The index: IDX_C1_syn_default_5_native_country is created for the table: C1_syn_default_5 in the database
# .... The index: IDX_C1_syn_default_5_age is created for the table: C1_syn_default_5 in the database
# Processing C1_syn_default_6.csv and C1.json
# Table C1_syn_default_6 is created in the database
# .... The index: IDX_C1_syn_default_6_capital is created for the table: C1_syn_default_6 in the database
# .... The index: IDX_C1_syn_default_6_fnlwgt is created for the table: C1_syn_default_6 in the database
# .... The index: IDX_C1_syn_default_6_native_country is created for the table: C1_syn_default_6 in the database
# .... The index: IDX_C1_syn_default_6_age is created for the table: C1_syn_default_6 in the database
# Processing C1_synthpop_5.csv and C1.json
# Table C1_synthpop_5 is created in the database
# .... The index: IDX_C1_synthpop_5_fnlwgt is created for the table: C1_synthpop_5 in the database
# .... The index: IDX_C1_synthpop_5_age is created for the table: C1_synthpop_5 in the database
# .... The index: IDX_C1_synthpop_5_capital is created for the table: C1_synthpop_5 in the database
# .... The index: IDX_C1_synthpop_5_native_country is created for the table: C1_synthpop_5 in the database
# .... The index: IDX_C1_synthpop_5_hours_per_week is created for the table: C1_synthpop_5 in the database
# Processing C1_syn_default_18.csv and C1.json
# Table C1_syn_default_18 is created in the database
# .... The index: IDX_C1_syn_default_18_capital is created for the table: C1_syn_default_18 in the database
# .... The index: IDX_C1_syn_default_18_fnlwgt is created for the table: C1_syn_default_18 in the database
# .... The index: IDX_C1_syn_default_18_native_country is created for the table: C1_syn_default_18 in the database
# .... The index: IDX_C1_syn_default_18_age is created for the table: C1_syn_default_18 in the database
# Processing C1_syn_39.csv and C1.json
# Table C1_syn_39 is created in the database
# .... The index: IDX_C1_syn_39_capital is created for the table: C1_syn_39 in the database
# .... The index: IDX_C1_syn_39_fnlwgt is created for the table: C1_syn_39 in the database
# .... The index: IDX_C1_syn_39_native_country is created for the table: C1_syn_39 in the database
# .... The index: IDX_C1_syn_39_age is created for the table: C1_syn_39 in the database
# Processing C1_syn_06.csv and C1.json
# Table C1_syn_06 is created in the database
# .... The index: IDX_C1_syn_06_capital is created for the table: C1_syn_06 in the database
# .... The index: IDX_C1_syn_06_fnlwgt is created for the table: C1_syn_06 in the database
# .... The index: IDX_C1_syn_06_native_country is created for the table: C1_syn_06 in the database
# .... The index: IDX_C1_syn_06_age is created for the table: C1_syn_06 in the database
# Processing C1_synthpop_3.csv and C1.json
# Table C1_synthpop_3 is created in the database
# .... The index: IDX_C1_synthpop_3_fnlwgt is created for the table: C1_synthpop_3 in the database
# .... The index: IDX_C1_synthpop_3_age is created for the table: C1_synthpop_3 in the database
# .... The index: IDX_C1_synthpop_3_capital is created for the table: C1_synthpop_3 in the database
# .... The index: IDX_C1_synthpop_3_native_country is created for the table: C1_synthpop_3 in the database
# .... The index: IDX_C1_synthpop_3_hours_per_week is created for the table: C1_synthpop_3 in the database
# Processing C10_syn_default_20.csv and C10.json
# Table C10_syn_default_20 is created in the database
# .... The index: IDX_C10_syn_default_20_os_area is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_fit_ellipse_goodness is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_cervix_r_mean_plus_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_total_b_mean_minus_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_cervix_g_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_hsv_total_v_mean is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_hsv_total_s_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_hsv_cervix_v_mean is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_total_r_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_hsv_total_v_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_fit_cervix_bbox_rate is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_hsv_cervix_h_mean is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_fit_cervix_bbox_total is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_hsv_total_s_mean is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_fit_circle_total is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_specularities_area is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_cervix_area is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_cervix_b_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_fit_cervix_hull_total is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_total_b_mean is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_speculum_area is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_total_r_mean_minus_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_hsv_total_h_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_cervix_artifacts_area is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_total_g_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_total_b_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_cervix_g_mean is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_total_r_mean is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_total_g_mean_minus_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_artifacts_area is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_cervix_b_mean_plus_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_hsv_cervix_v_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_hsv_cervix_s_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_total_g_mean is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_walls_artifacts_area is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_walls_specularities_area is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_total_b_mean_plus_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_fit_cervix_hull_rate is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_total_g_mean_plus_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_cervix_g_mean_plus_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_cervix_g_mean_minus_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_os_artifacts_area is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_fit_ellipse_rate is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_hsv_cervix_h_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_fit_ellipse_total is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_dist_to_center_cervix is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_cervix_b_mean_minus_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_speculum_specularities_area is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_cervix_r_mean is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_speculum_artifacts_area is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_total_r_mean_plus_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_cervix_specularities_area is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_walls_area is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_cervix_b_mean is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_cervix_r_mean_minus_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_area_h_max_diff is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_hsv_cervix_s_mean is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_rgb_cervix_r_std is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_fit_circle_rate is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_hsv_total_h_mean is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_dist_to_center_os is created for the table: C10_syn_default_20 in the database
# .... The index: IDX_C10_syn_default_20_os_specularities_area is created for the table: C10_syn_default_20 in the database
# Processing C10_syn_default_4.csv and C10.json
# Table C10_syn_default_4 is created in the database
# .... The index: IDX_C10_syn_default_4_os_area is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_fit_ellipse_goodness is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_cervix_r_mean_plus_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_total_b_mean_minus_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_cervix_g_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_hsv_total_v_mean is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_hsv_total_s_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_hsv_cervix_v_mean is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_total_r_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_hsv_total_v_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_fit_cervix_bbox_rate is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_hsv_cervix_h_mean is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_fit_cervix_bbox_total is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_hsv_total_s_mean is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_fit_circle_total is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_specularities_area is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_cervix_area is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_cervix_b_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_fit_cervix_hull_total is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_total_b_mean is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_speculum_area is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_total_r_mean_minus_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_hsv_total_h_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_cervix_artifacts_area is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_total_g_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_total_b_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_cervix_g_mean is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_total_r_mean is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_total_g_mean_minus_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_artifacts_area is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_cervix_b_mean_plus_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_hsv_cervix_v_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_hsv_cervix_s_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_total_g_mean is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_walls_artifacts_area is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_walls_specularities_area is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_total_b_mean_plus_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_fit_cervix_hull_rate is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_total_g_mean_plus_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_cervix_g_mean_plus_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_cervix_g_mean_minus_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_os_artifacts_area is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_fit_ellipse_rate is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_hsv_cervix_h_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_fit_ellipse_total is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_dist_to_center_cervix is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_cervix_b_mean_minus_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_speculum_specularities_area is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_cervix_r_mean is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_speculum_artifacts_area is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_total_r_mean_plus_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_cervix_specularities_area is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_walls_area is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_cervix_b_mean is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_cervix_r_mean_minus_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_area_h_max_diff is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_hsv_cervix_s_mean is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_rgb_cervix_r_std is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_fit_circle_rate is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_hsv_total_h_mean is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_dist_to_center_os is created for the table: C10_syn_default_4 in the database
# .... The index: IDX_C10_syn_default_4_os_specularities_area is created for the table: C10_syn_default_4 in the database
# Processing C10_syn_default_9.csv and C10.json
# Table C10_syn_default_9 is created in the database
# .... The index: IDX_C10_syn_default_9_os_area is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_fit_ellipse_goodness is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_cervix_r_mean_plus_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_total_b_mean_minus_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_cervix_g_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_hsv_total_v_mean is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_hsv_total_s_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_hsv_cervix_v_mean is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_total_r_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_hsv_total_v_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_fit_cervix_bbox_rate is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_hsv_cervix_h_mean is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_fit_cervix_bbox_total is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_hsv_total_s_mean is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_fit_circle_total is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_specularities_area is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_cervix_area is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_cervix_b_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_fit_cervix_hull_total is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_total_b_mean is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_speculum_area is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_total_r_mean_minus_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_hsv_total_h_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_cervix_artifacts_area is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_total_g_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_total_b_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_cervix_g_mean is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_total_r_mean is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_total_g_mean_minus_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_artifacts_area is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_cervix_b_mean_plus_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_hsv_cervix_v_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_hsv_cervix_s_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_total_g_mean is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_walls_artifacts_area is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_walls_specularities_area is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_total_b_mean_plus_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_fit_cervix_hull_rate is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_total_g_mean_plus_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_cervix_g_mean_plus_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_cervix_g_mean_minus_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_os_artifacts_area is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_fit_ellipse_rate is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_hsv_cervix_h_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_fit_ellipse_total is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_dist_to_center_cervix is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_cervix_b_mean_minus_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_speculum_specularities_area is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_cervix_r_mean is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_speculum_artifacts_area is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_total_r_mean_plus_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_cervix_specularities_area is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_walls_area is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_cervix_b_mean is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_cervix_r_mean_minus_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_area_h_max_diff is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_hsv_cervix_s_mean is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_rgb_cervix_r_std is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_fit_circle_rate is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_hsv_total_h_mean is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_dist_to_center_os is created for the table: C10_syn_default_9 in the database
# .... The index: IDX_C10_syn_default_9_os_specularities_area is created for the table: C10_syn_default_9 in the database
# Processing C10_syn_default_8.csv and C10.json
# Table C10_syn_default_8 is created in the database
# .... The index: IDX_C10_syn_default_8_os_area is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_fit_ellipse_goodness is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_cervix_r_mean_plus_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_total_b_mean_minus_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_cervix_g_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_hsv_total_v_mean is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_hsv_total_s_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_hsv_cervix_v_mean is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_total_r_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_hsv_total_v_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_fit_cervix_bbox_rate is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_hsv_cervix_h_mean is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_fit_cervix_bbox_total is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_hsv_total_s_mean is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_fit_circle_total is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_specularities_area is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_cervix_area is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_cervix_b_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_fit_cervix_hull_total is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_total_b_mean is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_speculum_area is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_total_r_mean_minus_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_hsv_total_h_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_cervix_artifacts_area is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_total_g_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_total_b_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_cervix_g_mean is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_total_r_mean is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_total_g_mean_minus_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_artifacts_area is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_cervix_b_mean_plus_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_hsv_cervix_v_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_hsv_cervix_s_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_total_g_mean is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_walls_artifacts_area is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_walls_specularities_area is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_total_b_mean_plus_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_fit_cervix_hull_rate is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_total_g_mean_plus_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_cervix_g_mean_plus_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_cervix_g_mean_minus_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_os_artifacts_area is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_fit_ellipse_rate is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_hsv_cervix_h_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_fit_ellipse_total is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_dist_to_center_cervix is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_cervix_b_mean_minus_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_speculum_specularities_area is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_cervix_r_mean is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_speculum_artifacts_area is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_total_r_mean_plus_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_cervix_specularities_area is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_walls_area is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_cervix_b_mean is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_cervix_r_mean_minus_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_area_h_max_diff is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_hsv_cervix_s_mean is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_rgb_cervix_r_std is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_fit_circle_rate is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_hsv_total_h_mean is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_dist_to_center_os is created for the table: C10_syn_default_8 in the database
# .... The index: IDX_C10_syn_default_8_os_specularities_area is created for the table: C10_syn_default_8 in the database
# Processing C10_syn_06.csv and C10.json
# Table C10_syn_06 is created in the database
# .... The index: IDX_C10_syn_06_os_area is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_fit_ellipse_goodness is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_rgb_cervix_r_mean_plus_std is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_rgb_total_b_mean_minus_std is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_rgb_cervix_g_std is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_hsv_total_v_mean is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_hsv_total_s_std is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_hsv_cervix_v_mean is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_rgb_total_r_std is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_hsv_total_v_std is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_fit_cervix_bbox_rate is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_hsv_cervix_h_mean is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_fit_cervix_bbox_total is created for the table: C10_syn_06 in the database
# .... The index: IDX_C10_syn_06_hsv_total_s_mean is created for the table: C10_syn_06 in the database
# ...
# .... The index: IDX_C9_syn_default_2_os_specularities_area is created for the table: C9_syn_default_2 in the database
# Processing cchs_syn_39.csv and cchs.json
# Table cchs_syn_39 is created in the database
# .... The index: IDX_cchs_syn_39_new_bmi is created for the table: cchs_syn_39 in the database
# Processing cchs_syn_06.csv and cchs.json
# Table cchs_syn_06 is created in the database
# .... The index: IDX_cchs_syn_06_new_numberoffamilydrconsult is created for the table: cchs_syn_06 in the database
# .... The index: IDX_cchs_syn_06_new_bmi is created for the table: cchs_syn_06 in the database
# Processing dad_syn_06.csv and dad.json
# Table dad_syn_06 is created in the database
# .... The index: IDX_dad_syn_06_PatientID is created for the table: dad_syn_06 in the database
# .... The index: IDX_dad_syn_06_Age is created for the table: dad_syn_06 in the database
# .... The index: IDX_dad_syn_06_DaysSinceLastService is created for the table: dad_syn_06 in the database
# .... The index: IDX_dad_syn_06_BirthYear is created for the table: dad_syn_06 in the database
# Processing dad_syn_39.csv and dad.json
# Table dad_syn_39 is created in the database
# .... The index: IDX_dad_syn_39_PatientID is created for the table: dad_syn_39 in the database
# Processing danish_syn_06.csv and danish.json
# Table danish_syn_06 is created in the database
# .... The index: IDX_danish_syn_06_BMI is created for the table: danish_syn_06 in the database
# .... The index: IDX_danish_syn_06_Afdelingsnavn_indb is created for the table: danish_syn_06 in the database
# .... The index: IDX_danish_syn_06_Alder is created for the table: danish_syn_06 in the database
# .... The index: IDX_danish_syn_06_Op_dato is created for the table: danish_syn_06 in the database
# .... The index: IDX_danish_syn_06_Vaegt is created for the table: danish_syn_06 in the database
# .... The index: IDX_danish_syn_06_Perop_blodtab is created for the table: danish_syn_06 in the database
# .... The index: IDX_danish_syn_06_LPR_Charlson_score_txt is created for the table: danish_syn_06 in the database
# .... The index: IDX_danish_syn_06_LPR_Charlson_score is created for the table: danish_syn_06 in the database
# .... The index: IDX_danish_syn_06_Dato_diagnose is created for the table: danish_syn_06 in the database
# .... The index: IDX_danish_syn_06_P_res_mets is created for the table: danish_syn_06 in the database
# .... The index: IDX_danish_syn_06_Indi_year is created for the table: danish_syn_06 in the database
# .... The index: IDX_danish_syn_06_Hojde is created for the table: danish_syn_06 in the database
# .... The index: IDX_danish_syn_06_P_res_nodes is created for the table: danish_syn_06 in the database
# .... The index: IDX_danish_syn_06_Date_lokalrecidiv is created for the table: danish_syn_06 in the database
# Processing n0147_syn_39.csv and n0147.json
# Table n0147_syn_39 is created in the database
# .... The index: IDX_n0147_syn_39_dfstime5 is created for the table: n0147_syn_39 in the database
# .... The index: IDX_n0147_syn_39_bmi2 is created for the table: n0147_syn_39 in the database
# .... The index: IDX_n0147_syn_39_futime8 is created for the table: n0147_syn_39 in the database
# Processing n0147_syn_06.csv and n0147.json
# Table n0147_syn_06 is created in the database
# .... The index: IDX_n0147_syn_06_numcycle is created for the table: n0147_syn_06 in the database
# .... The index: IDX_n0147_syn_06_dfstime5 is created for the table: n0147_syn_06 in the database
# .... The index: IDX_n0147_syn_06_bmi2 is created for the table: n0147_syn_06 in the database
# .... The index: IDX_n0147_syn_06_futime8 is created for the table: n0147_syn_06 in the database
# Processing n0147DFS_syn_39.csv and n0147DFS.json
# Table n0147DFS_syn_39 is created in the database
# .... The index: IDX_n0147DFS_syn_39_rDFStime_month is created for the table: n0147DFS_syn_39 in the database
# Processing n0147DFS_syn_06.csv and n0147DFS.json
# Table n0147DFS_syn_06 is created in the database
# .... The index: IDX_n0147DFS_syn_06_rDFStime_month is created for the table: n0147DFS_syn_06 in the database
# Processing n0147OS_syn_39.csv and n0147OS.json
# Table n0147OS_syn_39 is created in the database
# .... The index: IDX_n0147OS_syn_39_rOStime_month is created for the table: n0147OS_syn_39 in the database
# Processing n0147OS_syn_06.csv and n0147OS.json
# Table n0147OS_syn_06 is created in the database
# .... The index: IDX_n0147OS_syn_06_rOStime_month is created for the table: n0147OS_syn_06 in the database
# Processing trial1_syn_06.csv and trial1.json
# Table trial1_syn_06 is created in the database
# .... The index: IDX_trial1_syn_06_TT_EVENT_RFS_by_investigator_visit is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_SGOT is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_RESTIM_N is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_TT_EVENT_RFS_back_date_recurrence_to_midpoint is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_TBIL is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_TT_EVENT_RFS_up_to_22Jan2007 is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_CREA is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_BMI is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_TT_EVENT_RFS_by_definitive_scan_or_biopsy is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_TSTTDAY is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_EXPDAY_N is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_AVGDOS_N is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_TT_EVENT_RFS is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_TT_EVENT_RFS_by_biopsy is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_SGPT is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_RTXINC_C is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_RFDCTX_C is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_TT_EVENT_RFS_for_3rd_interim is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_TT_EVENT_RFS_back_date_recurrence_to_scheduled_vi is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_TT_EVENT_RFS_censor_at_last_adequate_assessment is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_PLAT2 is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_WBC is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_TT_EVENT_RFS_by_CRF_documented_recurrence is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_FUTIME_N is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_TT_EVENT_Overall_survival is created for the table: trial1_syn_06 in the database
# .... The index: IDX_trial1_syn_06_DUREXP_N is created for the table: trial1_syn_06 in the database
# Processing trial2_syn_06.csv and trial2.json
# Table trial2_syn_06 is created in the database
# .... The index: IDX_trial2_syn_06_BSA is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_AVAL_TIME2DTH is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_DIAGDUR is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_DEATHDY is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_METDDUR is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_ADT_TIME2DTH is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_BCA199 is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_WEIGHT is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_ADT_TDTHSEN1 is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_AVAL is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_ADT_TDTHSEN2 is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_R10XGR1N is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_AVAL_TDTHSEN1 is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_RANDDUR is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_ADT is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_LASTVDT is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_RES10X is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_AVAL_TDTHSEN2 is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_HEIGHT is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_LASTCDT is created for the table: trial2_syn_06 in the database
# .... The index: IDX_trial2_syn_06_DGMTDUR is created for the table: trial2_syn_06 in the database
# Processing trial2_syn_39.csv and trial2.json
# Table trial2_syn_39 is created in the database
# .... The index: IDX_trial2_syn_39_BSA is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_AVAL_TIME2DTH is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_DIAGDUR is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_DEATHDY is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_METDDUR is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_ADT_TIME2DTH is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_BCA199 is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_WEIGHT is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_ADT_TDTHSEN1 is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_AVAL is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_ADT_TDTHSEN2 is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_AVAL_TDTHSEN1 is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_ADT is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_LASTVDT is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_RES10X is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_AVAL_TDTHSEN2 is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_HEIGHT is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_LASTCDT is created for the table: trial2_syn_39 in the database
# .... The index: IDX_trial2_syn_39_DGMTDUR is created for the table: trial2_syn_39 in the database
# Processing trial4_syn_39.csv and trial4.json
# Table trial4_syn_39 is created in the database
# .... The index: IDX_trial4_syn_39_Lactate_Dehydrogenase_LBSTRESN is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_X2_LSLD is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_VISITDY is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_X4_LSLD is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_X3_LSLD is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_White_Blood_Cells_LBSTRESN is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_WEIGHT is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_DTHDYX is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_DIAGMONS is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_X1_LSLD is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_LSSLD is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_AGE is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_PFSDYCR is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Carcinoembryonic_Antigen_LBSTRESN is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Hemoglobin_LBSTRESN is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Alkaline_Phosphatase_LBSTRESN is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_B_WEIGHT is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_X5_LSLD is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Albumin_LBSTRESN is created for the table: trial4_syn_39 in the database
# .... The index: IDX_trial4_syn_39_Platelets_LBSTRESN is created for the table: trial4_syn_39 in the database
# Processing trial4_syn_06.csv and trial4.json
# Table trial4_syn_06 is created in the database
# .... The index: IDX_trial4_syn_06_Lactate_Dehydrogenase_LBSTRESN is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_X2_LSLD is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_VISITDY is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Creatinine_LBSTRESN is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_X4_LSLD is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_X3_LSLD is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_White_Blood_Cells_LBSTRESN is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_WEIGHT is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_DTHDYX is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_DIAGMONS is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_X1_LSLD is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_LSSLD is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_AGE is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_PFSDYCR is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Carcinoembryonic_Antigen_LBSTRESN is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Hemoglobin_LBSTRESN is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Alkaline_Phosphatase_LBSTRESN is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_B_WEIGHT is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_X5_LSLD is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Albumin_LBSTRESN is created for the table: trial4_syn_06 in the database
# .... The index: IDX_trial4_syn_06_Platelets_LBSTRESN is created for the table: trial4_syn_06 in the database

# %%
#save tabula test set for late usage in testing fuzzy SQL
with open('tabular_test_set.json','w') as f:
    json.dump(tabular_test_set, f)
