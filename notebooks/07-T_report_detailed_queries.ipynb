# %%
from pathlib import Path
import os
import sys 
import pandas as pd
from csv import writer  

sys.path.append('/home/samer/projects/fuzzy_sql/src') #This will enable reading the modules
from fuzzy_sql.fuzzy_sql import *

# %%
#set paths
root_dir=Path('/home/samer/projects/fuzzy_sql')
real_dir=os.path.join(root_dir,'data/sdgd/processed/real')
meta_dir=os.path.join(root_dir,'data/sdgd/processed/metadata')
syn_dir=os.path.join(root_dir,'data/sdgd/processed/synthetic')
run_folder=os.path.join(root_dir,'.runs')
db_path=os.path.join(root_dir,'db/sdgd.db')

# %%
#extract real data names and define paths
ds_names=extract_fnames(real_dir)
# drop trail 5 since there is no synth data for it
ds_names.remove('trial5')
ds_names.remove('oncovid_dtd')
ds_names.remove('trial3')
ds_names.remove('trial6')
#ds_names.remove('danish') #takes time
ds_names.remove('cchs') #takes time

real_path=[]
meta_path=[]
syn_path=[]
for ds_name in ds_names:
    real_path.append(real_dir+f'/{ds_name}.csv')
    meta_path.append(meta_dir+f'/{ds_name}.json')
    syn_path.append(syn_dir+f'/{ds_name}_syn_06.csv')
# Out:
# Extracted the names of 40 real datasets

# %%
# Fuzz
res={'name':[], 'hlngr_mean':[], 'hlngr_median':[], 'hlngr_std_dev':[], 'ecldn_mean':[], 'ecldn_median':[], 'ecldn_std_dev':[] }
queries=[]

for i,ds_name in enumerate(ds_names):
    # if ds_name !='C25':
    #     continue
    scored_queries=fuzz_tabular(3,'twin_aggfltr', real_path[i], meta_path[i],syn_path[i], run_folder=run_folder, printme=True,db_path=db_path,)
    queries.append(scored_queries)
    res['name'].append(ds_name)
    hlngr_stats=calc_stats(scored_queries['hlngr_dist'])
    res['hlngr_mean'].append(hlngr_stats['mean'])
    res['hlngr_median'].append(hlngr_stats['median'])
    res['hlngr_std_dev'].append(hlngr_stats['stddev'])
    ecldn_stats=calc_stats(scored_queries['ecldn_dist'])
    res['ecldn_mean'].append(ecldn_stats['mean'])
    res['ecldn_median'].append(ecldn_stats['median'])
    res['ecldn_std_dev'].append(ecldn_stats['stddev'])

res_df=pd.DataFrame(res)
res_df.to_csv('../.runs/results.csv', index=False)
# Out:
# Table C20 already exists in the database
# Table C20_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C20_1665608150
# Table C4 is created in the database
# Table C4_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C4_1665608150
# Table C26 is created in the database
# Table C26_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C26_1665608150
# Table C21 is created in the database
# Table C21_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C21_1665608151
# Table C24 is created in the database
# Table C24_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C24_1665608151
# Table C17 is created in the database
# Table C17_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C17_1665608151
# Table C25 is created in the database
# Table C25_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C25_1665608152
# Table C9 is created in the database
# Table C9_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C9_1665608152
# Table n0147 is created in the database
# Table n0147_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/n0147_1665608152
# Table C15 is created in the database
# Table C15_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C15_1665608153
# Table C8 is created in the database
# Table C8_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C8_1665608154
# Table trial1 is created in the database
# Table trial1_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/trial1_1665608156
# Table C7 is created in the database
# Table C7_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C7_1665608157
# Table n0147DFS is created in the database
# Table n0147DFS_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# /home/samer/projects/fuzzy_sql/src/fuzzy_sql/fuzzy_sql.py:23: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax=plt.subplots(1,1,figsize=(12, 6))
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/n0147DFS_1665608158
# Table C18 is created in the database
# Table C18_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C18_1665608159
# Table C23 is created in the database
# Table C23_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C23_1665608167
# Table trial2 is created in the database
# Table trial2_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/trial2_1665608168
# Table C2 is created in the database
# Table C2_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C2_1665608169
# Table n0147OS is created in the database
# Table n0147OS_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/n0147OS_1665608169
# Table C14 is created in the database
# Table C14_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C14_1665608170
# Table C13 is created in the database
# Table C13_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C13_1665608171
# Table C6 is created in the database
# Table C6_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C6_1665608172
# Table C22 is created in the database
# Table C22_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C22_1665608172
# Table C10 is created in the database
# Table C10_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C10_1665608172
# Table C1 already exists in the database
# Table C1_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C1_1665608174
# Table dad is created in the database
# Table dad_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/dad_1665608180
# Table C19 is created in the database
# Table C19_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C19_1665608184
# Table C5 is created in the database
# Table C5_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C5_1665608184
# Table C27 is created in the database
# Table C27_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C27_1665608184
# Table C16 is created in the database
# Table C16_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C16_1665608185
# Table C12 is created in the database
# Table C12_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C12_1665608185
# Table C3 is created in the database
# Table C3_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C3_1665608185
# Table trial4 is created in the database
# Table trial4_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/trial4_1665608185
# Table C11 is created in the database
# Table C11_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C11_1665608186
# Table C28 is created in the database
# Table C28_syn_06 is created in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# Generated 3 random twin queries and saved results in: /home/samer/projects/fuzzy_sql/.runs/C28_1665608186
