# %%
from fuzzy_sql.fuzzy_sql import *
import os

# %%
real_file_path='/home/samer/projects/fuzzy_sql/data/tabular/ready/real/oncovid_dtd.csv'
metadata_file_path='/home/samer/projects/fuzzy_sql/data/tabular/ready/metadata/oncovid_dtd.json'
syn_file_path='None'
run_folder='.runs/'

# %%
fuzz_tabular(3,'single_agg',real_file_path ,metadata_file_path ,syn_file_path, run_folder=run_folder, printme=False)

fuzz_tabular(3,'single_fltr', real_file_path, metadata_file_path, printme=True)
# Out:
# Table oncovid_dtd already exists in the database
# Generated Aggregate Query 0
# Generated Aggregate Query 1
# Generated Aggregate Query 2
#
#
# Table oncovid_dtd already exists in the database
# Generated Filter Query 0
# Generated Filter Query 1
# Generated Filter Query 2
# Generated 3 random queries and saved results in: oncovid_dtd_1664369740
# {'query_real': [      case_status age_group gender date_reported        exposure  \
#   0       Recovered       <20   Male    2020-10-24   Close Contact
#   1       Recovered     50-59   Male    2020-10-01    Not Reported
#   2       Recovered     40-49   Male    2020-10-30  Travel-Related
#   3       Recovered     20-29   Male    2020-10-19   Close Contact
#   4       Recovered       <20   Male    2020-09-23   Close Contact
#   ...           ...       ...    ...           ...             ...
#   43914   Recovered     40-49   Male    2020-11-02   Close Contact
#   43915   Recovered       <20   Male    2020-09-03   Close Contact
# ...

# %%
real_file_path='/home/samer/projects/fuzzy_sql/data/tabular/ready/real/C1.csv'
metadata_file_path='/home/samer/projects/fuzzy_sql/data/tabular/ready/metadata/C1.json'
syn_file_path='/home/samer/projects/fuzzy_sql/data/tabular/ready/synthetic/C1_syn_default_1.csv'
run_folder='.runs/'

# %%
fuzz_tabular(3,'twin_fltr',real_file_path ,metadata_file_path ,syn_file_path)

fuzz_tabular(3,'twin_agg', real_file_path, metadata_file_path,syn_file_path)

fuzz_tabular(3,'twin_aggfltr', real_file_path, metadata_file_path,syn_file_path)
# Out:
# Table C1 already exists in the database
# Table C1_syn_default_1 already exists in the database
# Generated Filter Query 0
# Generated Filter Query 1
# Generated Filter Query 2
# Table C1 already exists in the database
# Table C1_syn_default_1 already exists in the database
# Generated Aggregate Query 0
# Generated Aggregate Query 1
# Generated Aggregate Query 2
#
#
# Table C1 already exists in the database
# Table C1_syn_default_1 already exists in the database
# Generated Conditioned Aggregate Query 0
# Generated Conditioned Aggregate Query 1
# Generated Conditioned Aggregate Query 2
# {'query_real': [      workclass relationship native.country     education     sex income  \
#   0             ?      Husband              ?          12th    Male  <=50K
#   1             ?      Husband              ?       1st-4th    Male  <=50K
#   2             ?      Husband              ?       5th-6th    Male  <=50K
#   3             ?      Husband              ?     Bachelors    Male  <=50K
# ...
